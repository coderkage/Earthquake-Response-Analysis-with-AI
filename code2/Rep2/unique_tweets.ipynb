# %%
import pandas as pd
import hashlib

# %%
df_haiti = pd.read_csv('C:\\Users\\nagar\\OneDrive\\Desktop\\ML\\nlp\\cleaned_haiti.csv')
df_iraq_iran = pd.read_csv("C:\\Users\\nagar\\OneDrive\\Desktop\\ML\\nlp\\cleaned_iraq_iran.csv")
df_japan = pd.read_csv("C:\\Users\\nagar\\OneDrive\\Desktop\\ML\\nlp\\cleaned_japan.csv")
df_maxico = pd.read_csv("C:\\Users\\nagar\\OneDrive\\Desktop\\ML\\nlp\\cleaned_mexico.csv")
df_turkey = pd.read_csv("C:\\Users\\nagar\\OneDrive\\Desktop\\ML\\nlp\\cleaned_turkey.csv")

# %%
# df_haiti['text'] = df_haiti['text'].drop_duplicates()
# df_iraq_iran['text']= df_iraq_iran['text'].drop_duplicates()
# df_japan['text'] = df_japan['text'].drop_duplicates()
# df_maxico['text'] = df_maxico['text'].drop_duplicates()
# df_turkey['text']= df_turkey['text'].drop_duplicates()

# %%
df_unique_haiti = df_haiti.drop_duplicates(subset='text', keep='first')
df_unique_haiti.to_csv("df_unique_haiti.csv",index=False)

# %%
df_unique_iraq_iran = df_iraq_iran.drop_duplicates(subset='text', keep='first')
df_unique_japan= df_japan.drop_duplicates(subset='text', keep='first')
df_unique_maxico= df_maxico.drop_duplicates(subset='text', keep='first')
df_unique_turkey= df_turkey.drop_duplicates(subset='text', keep='first')

# %%
# Save each DataFrame to a CSV file

df_unique_iraq_iran.to_csv('df_unique_iraq_iran.csv', index=False)
df_unique_japan.to_csv('df_japan_unique.csv', index=False)
df_unique_maxico.to_csv('df_maxico_unique.csv', index=False)
df_unique_turkey.to_csv('df_turkey_unique.csv', index=False)

# %%
df_unique_turkey
# Out:
#                                                     text  \
# 0      hey turkish users getting rate limit exceeded ...
# 1      may allah mercy passed away make easy affected...
# 2                                           stand turkey
# 3                  occurred km e min ago local time info
# 4      former newcastle united star christian atsu am...
# ...                                                  ...
# 36771                                    cat saved hours
# 36772  massive thanks entire team continued amazing c...
# 36773  please donate ahbap charity charity helping vi...
# 36774  thought heart would burst grief tears running ...
# 36776  please donate like share raise awareness key l...
#
#                             date
# 0      2023-02-06 13:04:30+00:00
# 1      2023-02-06 13:04:30+00:00
# 2      2023-02-06 13:04:31+00:00
# 3      2023-02-06 13:04:33+00:00
# 4      2023-02-06 13:04:33+00:00
# ...                          ...
# 36771  2023-02-10 23:56:36+00:00
# ...

# %%
df_unique_iraq_iran
# Out:
#                                                   text        date  \
# 0    rt presstv update death toll irans quake rises...  13_11_2017
# 1          rt cafod pray affected earthquake iraq iran  13_11_2017
# 2    rt reutersworld death toll reaches iran earthq...  13_11_2017
# 3    rt laylaalhussein magnitude earthquake struck ...  13_11_2017
# 7    video magnitude earthquake jolts iraniraq bord...  13_11_2017
# ..                                                 ...         ...
# 592  damage proxy maps cities near epicenter kerman...  18_11_2017
# 593  iran daily us treasury blocks donations earthq...  18_11_2017
# 594  kurdish childrens situation earthquake iran te...  18_11_2017
# 595  irans earthquake exposes political rifts ineff...  18_11_2017
# 596  victims last weeks earthquake gather outdoors ...  18_11_2017
#
#                                    category
# 0                    injured_or_dead_people
# 1                          not_humanitarian
# ...
