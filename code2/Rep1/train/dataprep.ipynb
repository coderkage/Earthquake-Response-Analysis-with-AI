# %%
import pandas as pd


data = {
    "tweets": [
        {"id": 1, "text": "Earthquake felt in {location}. Stay safe! #earthquake", "user": "@quakeWatcher1"},
        {"id": 2, "text": "Strong tremors reported in {location}. #quakeAlert", "user": "@earthquakeToday2"},
        {"id": 3, "text": "Aftershocks shaking {location} following a massive earthquake. #disaster", "user": "@geoExpert3"},
        {"id": 4, "text": "Residents of {location} feel strong quake tremors. #StaySafe", "user": "@quakeNews4"},
        {"id": 5, "text": "Earthquake reported near {location}. Hope everyone is okay! #earthquakeRescue", "user": "@earthquakeAlert5"},
        {"id": 6, "text": "Massive earthquake in {location}, stay safe everyone! #disasterAlert", "user": "@geoUpdates6"},
        {"id": 7, "text": "Strong quake hits {location}. Emergency services are on high alert. #earthquake", "user": "@quakeRescue7"},
        {"id": 8, "text": "Shaking felt across {location} due to earthquake. Prayers for safety. #quakeAlert", "user": "@earthquakeToday8"},
        {"id": 9, "text": "Aftershocks in {location} after a massive quake. #disasterAlert", "user": "@geoNews9"},
        {"id": 10, "text": "Earthquake just shook {location}. Everyone, please be safe! #StayAlert", "user": "@quakeAlert10"},
        {"id": 11, "text": "Severe earthquake felt in {location}. Take precautions! #quakeAlert", "user": "@quakeWatcher11"},
        {"id": 12, "text": "Reports of tremors in {location}. Stay indoors! #earthquake", "user": "@earthquakeToday12"},
        {"id": 13, "text": "Aftershocks rocking {location} post-earthquake. #disaster", "user": "@geoExpert13"},
        {"id": 14, "text": "Residents in {location} urged to stay calm. #StaySafe", "user": "@quakeNews14"},
        {"id": 15, "text": "Earthquake detected near {location}. Check on your neighbors! #earthquakeRescue", "user": "@earthquakeAlert15"},
        {"id": 16, "text": "Massive quake shakes {location}. Stay alert! #disasterAlert", "user": "@geoUpdates16"},
        {"id": 17, "text": "New tremors reported in {location}. Emergency services activated. #earthquake", "user": "@quakeRescue17"},
        {"id": 18, "text": "Residents of {location} shaken again. Stay safe! #quakeAlert", "user": "@earthquakeToday18"},
        {"id": 19, "text": "Aftershocks in {location}. Be cautious! #disasterAlert", "user": "@geoNews19"},
        {"id": 20, "text": "Tremors felt in {location}. Everyone, please be cautious! #StayAlert", "user": "@quakeAlert20"},
        {"id": 21, "text": "Aftershock warnings for {location} residents. Stay prepared! #earthquake", "user": "@quakeWatcher21"},
        {"id": 22, "text": "Reports of tremors in {location}. Check local updates! #quakeAlert", "user": "@earthquakeToday22"},
        {"id": 23, "text": "Strong aftershocks in {location} following last night's quake. #disaster", "user": "@geoExpert23"},
        {"id": 24, "text": "Residents in {location} advised to stay calm. #StaySafe", "user": "@quakeNews24"},
        {"id": 25, "text": "Tremors felt in {location}. Everyone stay vigilant! #earthquakeRescue", "user": "@earthquakeAlert25"},
        {"id": 26, "text": "Severe earthquake impacts {location}. Emergency services activated! #disasterAlert", "user": "@geoUpdates26"},
        {"id": 27, "text": "Aftershocks felt in {location}. Stay indoors! #earthquake", "user": "@quakeRescue27"},
        {"id": 28, "text": "Tremors reported in {location}. Stay safe! #quakeAlert", "user": "@earthquakeToday28"},
        {"id": 29, "text": "Residents of {location} feel strong shaking. Be cautious! #disasterAlert", "user": "@geoNews29"},
        {"id": 30, "text": "Another earthquake just shook {location}. Everyone, please be safe! #StayAlert", "user": "@quakeAlert30"},
        {"id": 31, "text": "Tremors felt in {location}. Stay prepared for aftershocks! #earthquake", "user": "@quakeWatcher31"},
        {"id": 32, "text": "Reports of tremors in {location}. Stay safe! #quakeAlert", "user": "@earthquakeToday32"},
        {"id": 33, "text": "Aftershocks reported in {location}. Stay vigilant! #disaster", "user": "@geoExpert33"},
        {"id": 34, "text": "Residents of {location} urged to remain calm. #StaySafe", "user": "@quakeNews34"},
        {"id": 35, "text": "Earthquake detected near {location}. Check on your neighbors! #earthquakeRescue", "user": "@earthquakeAlert35"},
        {"id": 36, "text": "Massive quake shakes {location}. Stay alert! #disasterAlert", "user": "@geoUpdates36"},
        {"id": 37, "text": "Tremors felt in {location}. Emergency services on standby. #earthquake", "user": "@quakeRescue37"},
        {"id": 38, "text": "Residents of {location} shaken again. Stay safe! #quakeAlert", "user": "@earthquakeToday38"},
        {"id": 39, "text": "Aftershocks in {location}. Be cautious! #disasterAlert", "user": "@geoNews39"},
        {"id": 40, "text": "Tremors felt in {location}. Everyone, please be cautious! #StayAlert", "user": "@quakeAlert40"},
        {"id": 41, "text": "New tremors in {location}. Stay alert and safe! #earthquake", "user": "@quakeWatcher41"},
        {"id": 42, "text": "Tremors reported in {location}. Stay indoors and safe! #quakeAlert", "user": "@earthquakeToday42"},
        {"id": 43, "text": "Aftershocks felt in {location}. Remain vigilant! #disaster", "user": "@geoExpert43"},
        {"id": 44, "text": "Residents in {location} should stay calm and prepared. #StaySafe", "user": "@quakeNews44"},
        {"id": 45, "text": "Tremors detected near {location}. Check on neighbors! #earthquakeRescue", "user": "@earthquakeAlert45"},
        {"id": 46, "text": "Strong quake impacts {location}. Emergency services are on high alert! #disasterAlert", "user": "@geoUpdates46"},
        {"id": 47, "text": "Aftershocks reported in {location}. Stay indoors! #earthquake", "user": "@quakeRescue47"},
        {"id": 48, "text": "Residents of {location} feel strong tremors again. Stay safe! #quakeAlert", "user": "@earthquakeToday48"},
        {"id": 49, "text": "Aftershocks in {location}. Be cautious and safe! #disasterAlert", "user": "@geoNews49"},
        {"id": 50, "text": "Tremors felt in {location}. Everyone, please stay safe! #StayAlert", "user": "@quakeAlert50"},
        {"id": 51, "text": "Another earthquake felt in {location}. Stay safe everyone! #earthquake", "user": "@quakeWatcher51"},
        {"id": 52, "text": "Strong tremors reported in {location} today. Be alert! #quakeAlert", "user": "@earthquakeToday52"},
        {"id": 53, "text": "Aftershocks shaking {location}. Everyone, please stay cautious! #disaster", "user": "@geoExpert53"},
        {"id": 54, "text": "Residents of {location} feel the tremors again. #StaySafe", "user": "@quakeNews54"},
        {"id": 55, "text": "Earthquake reported near {location}. Hope all are okay! #earthquakeRescue", "user": "@earthquakeAlert55"},
        {"id": 56, "text": "Massive quake shakes {location}. Emergency services on standby! #disasterAlert", "user": "@geoUpdates56"},
        {"id": 57, "text": "Tremors felt in {location}. Stay indoors and safe! #earthquake", "user": "@quakeRescue57"},
        {"id": 58, "text": "Residents of {location} are experiencing strong aftershocks. #quakeAlert", "user": "@earthquakeToday58"},
        {"id": 59, "text": "Aftershocks in {location} following last night's quake. Stay alert! #disasterAlert", "user": "@geoNews59"},
        {"id": 60, "text": "Tremors felt across {location}. Everyone, please be careful! #StayAlert", "user": "@quakeAlert60"},
        {"id": 61, "text": "Reports of tremors in {location}. Stay safe and prepared! #earthquake", "user": "@quakeWatcher61"},
        {"id": 62, "text": "Shaking reported in {location}. Stay updated! #quakeAlert", "user": "@earthquakeToday62"},
        {"id": 63, "text": "Aftershocks continue in {location}. Remain vigilant! #disaster", "user": "@geoExpert63"},
        {"id": 64, "text": "Residents in {location} advised to stay calm. #StaySafe", "user": "@quakeNews64"},
        {"id": 65, "text": "Earthquake detected near {location}. Please check on your neighbors! #earthquakeRescue", "user": "@earthquakeAlert65"},
        {"id": 66, "text": "Severe tremors reported in {location}. Emergency services activated! #disasterAlert", "user": "@geoUpdates66"},
        {"id": 67, "text": "Residents of {location} shaken by aftershocks. Stay safe! #quakeAlert", "user": "@quakeRescue67"},
        {"id": 68, "text": "Tremors felt in {location}. Be aware of your surroundings! #earthquake", "user": "@earthquakeToday68"},
        {"id": 69, "text": "Aftershocks shaking {location} following a significant quake. #disasterAlert", "user": "@geoNews69"},
        {"id": 70, "text": "Tremors felt in {location}. Everyone, stay cautious! #StayAlert", "user": "@quakeAlert70"},
        {"id": 71, "text": "Reports of strong shaking in {location}. Stay indoors! #earthquake", "user": "@quakeWatcher71"},
        {"id": 72, "text": "Residents of {location} urged to prepare for aftershocks. #quakeAlert", "user": "@earthquakeToday72"},
        {"id": 73, "text": "Aftershocks reported in {location}. Keep emergency kits handy! #disaster", "user": "@geoExpert73"},
        {"id": 74, "text": "Tremors felt in {location}. Stay safe, everyone! #StaySafe", "user": "@quakeNews74"},
        {"id": 75, "text": "Earthquake detected in {location}. Check on your neighbors! #earthquakeRescue", "user": "@earthquakeAlert75"},
        {"id": 76, "text": "Massive quake shakes {location}. Emergency services on high alert! #disasterAlert", "user": "@geoUpdates76"},
        {"id": 77, "text": "Strong aftershocks reported in {location}. Stay safe! #quakeAlert", "user": "@quakeRescue77"},
        {"id": 78, "text": "Shaking felt across {location}. Please stay indoors! #earthquake", "user": "@earthquakeToday78"},
        {"id": 79, "text": "Aftershocks in {location}. Remain vigilant and safe! #disasterAlert", "user": "@geoNews79"},
        {"id": 80, "text": "Tremors felt in {location}. Everyone, please stay alert! #StayAlert", "user": "@quakeAlert80"},
        {"id": 81, "text": "Tremors reported in {location}. Stay safe and prepared! #earthquake", "user": "@quakeWatcher81"},
        {"id": 82, "text": "Reports of strong shaking in {location}. Be vigilant! #quakeAlert", "user": "@earthquakeToday82"},
        {"id": 83, "text": "Aftershocks shaking {location}. Please stay safe! #disaster", "user": "@geoExpert83"},
        {"id": 84, "text": "Residents in {location} advised to stay calm and indoors. #StaySafe", "user": "@quakeNews84"},
        {"id": 85, "text": "Earthquake detected near {location}. Stay aware! #earthquakeRescue", "user": "@earthquakeAlert85"},
        {"id": 86, "text": "Tremors felt in {location}. Emergency services are on alert! #disasterAlert", "user": "@geoUpdates86"},
        {"id": 87, "text": "Aftershocks reported in {location}. Stay safe! #quakeAlert", "user": "@quakeRescue87"},
        {"id": 88, "text": "Residents of {location} feel strong tremors again. Stay cautious! #earthquake", "user": "@earthquakeToday88"},
        {"id": 89, "text": "Aftershocks in {location}. Be prepared! #disasterAlert", "user": "@geoNews89"},
        {"id": 90, "text": "Tremors felt in {location}. Everyone, please be careful! #StayAlert", "user": "@quakeAlert90"},
        {"id": 91, "text": "Reports of shaking in {location}. Stay indoors and safe! #earthquake", "user": "@quakeWatcher91"},
        {"id": 92, "text": "Strong tremors felt in {location}. Stay alert! #quakeAlert", "user": "@earthquakeToday92"},
        {"id": 93, "text": "Aftershocks in {location}. Please remain vigilant! #disaster", "user": "@geoExpert93"},
        {"id": 94, "text": "Residents in {location} advised to remain calm. #StaySafe", "user": "@quakeNews94"},
        {"id": 95, "text": "Earthquake detected near {location}. Check on your neighbors! #earthquakeRescue", "user": "@earthquakeAlert95"},
        {"id": 96, "text": "Severe tremors reported in {location}. Emergency services activated! #disasterAlert", "user": "@geoUpdates96"},
        {"id": 97, "text": "Tremors felt in {location}. Everyone stay cautious! #quakeAlert", "user": "@quakeRescue97"},
        {"id": 98, "text": "Residents of {location} shaken by aftershocks. Stay safe! #earthquake", "user": "@earthquakeToday98"},
        {"id": 99, "text": "Aftershocks in {location}. Be aware and safe! #disasterAlert", "user": "@geoNews99"},
        {"id": 100, "text": "Tremors felt in {location}. Everyone, please stay alert! #StayAlert", "user": "@quakeAlert100"},
         {"id": 101, "text": "Another tremor felt in {location}. Stay safe! #earthquake", "user": "@quakeWatcher101"},
        {"id": 102, "text": "Shaking reported in {location}. Please stay indoors! #quakeAlert", "user": "@earthquakeToday102"},
        {"id": 103, "text": "Aftershocks shaking {location}. Keep emergency kits ready! #disaster", "user": "@geoExpert103"},
        {"id": 104, "text": "Residents of {location} urged to stay calm during aftershocks. #StaySafe", "user": "@quakeNews104"},
        {"id": 105, "text": "Earthquake detected near {location}. Check on your loved ones! #earthquakeRescue", "user": "@earthquakeAlert105"},
        {"id": 106, "text": "Massive tremors felt in {location}. Emergency services on alert! #disasterAlert", "user": "@geoUpdates106"},
        {"id": 107, "text": "Strong aftershocks reported in {location}. Stay aware! #quakeAlert", "user": "@quakeRescue107"},
        {"id": 108, "text": "Tremors felt across {location}. Everyone should be cautious! #earthquake", "user": "@earthquakeToday108"},
        {"id": 109, "text": "Aftershocks in {location} following recent events. Stay safe! #disasterAlert", "user": "@geoNews109"},
        {"id": 110, "text": "Tremors reported in {location}. Please be careful! #StayAlert", "user": "@quakeAlert110"},
        {"id": 111, "text": "Reports of shaking in {location}. Stay informed and safe! #earthquake", "user": "@quakeWatcher111"},
        {"id": 112, "text": "Shaking felt in {location}. Stay prepared for aftershocks! #quakeAlert", "user": "@earthquakeToday112"},
        {"id": 113, "text": "Aftershocks shaking {location}. Remain vigilant! #disaster", "user": "@geoExpert113"},
        {"id": 114, "text": "Residents in {location} advised to stay indoors. #StaySafe", "user": "@quakeNews114"},
        {"id": 115, "text": "Earthquake detected near {location}. Stay alert! #earthquakeRescue", "user": "@earthquakeAlert115"},
        {"id": 116, "text": "Severe tremors felt in {location}. Emergency services on standby! #disasterAlert", "user": "@geoUpdates116"},
        {"id": 117, "text": "Aftershocks reported in {location}. Please stay safe! #quakeAlert", "user": "@quakeRescue117"},
        {"id": 118, "text": "Residents of {location} shaken by aftershocks again. Stay cautious! #earthquake", "user": "@earthquakeToday118"},
        {"id": 119, "text": "Aftershocks in {location}. Be prepared for anything! #disasterAlert", "user": "@geoNews119"},
        {"id": 120, "text": "Tremors felt in {location}. Everyone, please remain alert! #StayAlert", "user": "@quakeAlert120"},
        {"id": 121, "text": "Reports of strong shaking in {location}. Stay safe indoors! #earthquake", "user": "@quakeWatcher121"},
        {"id": 122, "text": "Tremors reported in {location}. Stay cautious and alert! #quakeAlert", "user": "@earthquakeToday122"},
        {"id": 123, "text": "Aftershocks shaking {location}. Stay prepared! #disaster", "user": "@geoExpert123"},
        {"id": 124, "text": "Residents in {location} advised to stay calm and indoors. #StaySafe", "user": "@quakeNews124"},
        {"id": 125, "text": "Earthquake detected near {location}. Check on your friends! #earthquakeRescue", "user": "@earthquakeAlert125"},
        {"id": 126, "text": "Severe tremors reported in {location}. Emergency services activated! #disasterAlert", "user": "@geoUpdates126"},
        {"id": 127, "text": "Tremors felt in {location}. Everyone should stay safe! #quakeAlert", "user": "@quakeRescue127"},
        {"id": 128, "text": "Residents of {location} experiencing aftershocks. Stay alert! #earthquake", "user": "@earthquakeToday128"},
        {"id": 129, "text": "Aftershocks in {location}. Remain vigilant and prepared! #disasterAlert", "user": "@geoNews129"},
        {"id": 130, "text": "Tremors felt in {location}. Everyone, please stay cautious! #StayAlert", "user": "@quakeAlert130"},
        {"id": 131, "text": "Another tremor reported in {location}. Stay safe! #earthquake", "user": "@quakeWatcher131"},
        {"id": 132, "text": "Shaking reported in {location}. Please be careful! #quakeAlert", "user": "@earthquakeToday132"},
        {"id": 133, "text": "Aftershocks shaking {location}. Keep your emergency kits ready! #disaster", "user": "@geoExpert133"},
        {"id": 134, "text": "Residents of {location} urged to stay calm during the aftershocks. #StaySafe", "user": "@quakeNews134"},
        {"id": 135, "text": "Earthquake detected near {location}. Check on your community! #earthquakeRescue", "user": "@earthquakeAlert135"},
        {"id": 136, "text": "Massive tremors felt in {location}. Emergency services on high alert! #disasterAlert", "user": "@geoUpdates136"},
        {"id": 137, "text": "Strong aftershocks reported in {location}. Stay safe! #quakeAlert", "user": "@quakeRescue137"},
        {"id": 138, "text": "Tremors felt across {location}. Please stay indoors! #earthquake", "user": "@earthquakeToday138"},
        {"id": 139, "text": "Aftershocks in {location}. Be prepared for anything! #disasterAlert", "user": "@geoNews139"},
        {"id": 140, "text": "Tremors felt in {location}. Everyone, please stay alert! #StayAlert", "user": "@quakeAlert140"},
        {"id": 141, "text": "We just felt a strong tremor in {location}. Everyone stay indoors until it's safe! #earthquake", "user": "@quakeWatcher141"},
        {"id": 142, "text": "Reports of significant shaking in {location}. Please check on your neighbors and stay safe! #quakeAlert", "user": "@earthquakeToday142"},
        {"id": 143, "text": "Residents in {location}, aftershocks have been detected. Keep your emergency kits handy! #disasterPreparedness", "user": "@geoExpert143"},
        {"id": 144, "text": "Feeling the tremors in {location}? It’s crucial to remain calm and alert! #StaySafe", "user": "@quakeNews144"},
        {"id": 145, "text": "Earthquake alerts for {location}. Stay tuned for updates and take precautions! #earthquakeRescue", "user": "@earthquakeAlert145"},
        {"id": 146, "text": "Just received reports of aftershocks in {location}. Please avoid unnecessary travel! #disasterAlert", "user": "@geoUpdates146"},
        {"id": 147, "text": "Tremors felt in {location} indicate seismic activity. Stay informed and safe! #quakeAlert", "user": "@quakeRescue147"},
        {"id": 148, "text": "A series of aftershocks has hit {location}. Remain vigilant and look out for one another! #earthquake", "user": "@earthquakeToday148"},
        {"id": 149, "text": "Seismic activity reported in {location}. Prepare for potential disruptions! #disasterAlert", "user": "@geoNews149"},
        {"id": 150, "text": "Residents of {location} are experiencing tremors. Secure heavy furniture and stay safe! #StayAlert", "user": "@quakeAlert150"},
        {"id": 151, "text": "Strong aftershocks felt in {location}. Make sure your emergency supplies are ready! #earthquakeSafety", "user": "@quakeWatcher151"},
        {"id": 152, "text": "Reports confirm shaking in {location}. Stay indoors and avoid panic! #quakeAlert", "user": "@earthquakeToday152"},
        {"id": 153, "text": "The ground is shaking in {location}. Follow safety protocols and stay calm! #disasterPreparedness", "user": "@geoExpert153"},
        {"id": 154, "text": "Tremors have been detected in {location}. Check on vulnerable neighbors! #StaySafe", "user": "@quakeNews154"},
        {"id": 155, "text": "Emergency alerts for {location}. Prepare for aftershocks and stay informed! #earthquakeRescue", "user": "@earthquakeAlert155"},
        {"id": 156, "text": "Aftershocks in {location} are causing concern. Stay updated through reliable sources! #disasterAlert", "user": "@geoUpdates156"},
        {"id": 157, "text": "Shaking felt across {location}. Ensure your emergency plans are in place! #quakeAlert", "user": "@quakeRescue157"},
        {"id": 158, "text": "Reports indicate tremors in {location}. Stay inside and stay safe! #earthquake", "user": "@earthquakeToday158"},
        {"id": 159, "text": "Seismic events are affecting {location}. Prepare for potential disruptions! #disasterAlert", "user": "@geoNews159"},
        {"id": 160, "text": "Residents in {location}, please stay alert for aftershocks and check on each other! #StayAlert", "user": "@quakeAlert160"},
        {"id": 161, "text": "Shaking reported in {location}. Keep calm and follow safety protocols! #earthquake", "user": "@quakeWatcher161"},
        {"id": 162, "text": "Tremors felt in {location} are causing some concern. Stay indoors until further notice! #quakeAlert", "user": "@earthquakeToday162"},
        {"id": 163, "text": "Aftershocks have been felt in {location}. Ensure you have your emergency kits ready! #disasterPreparedness", "user": "@geoExpert163"},
        {"id": 164, "text": "Reports of significant shaking in {location}. Check in on your neighbors! #StaySafe", "user": "@quakeNews164"},
        {"id": 165, "text": "A series of aftershocks have been reported near {location}. Stay alert and be prepared! #earthquakeRescue", "user": "@earthquakeAlert165"},
        {"id": 166, "text": "Shaking reported in {location}. Secure heavy items and stay safe! #disasterAlert", "user": "@geoUpdates166"},
        {"id": 167, "text": "Tremors have been felt in {location}. Follow local safety guidelines! #quakeAlert", "user": "@quakeRescue167"},
        {"id": 168, "text": "Residents in {location}, ensure you are prepared for possible aftershocks! #earthquake", "user": "@earthquakeToday168"},
        {"id": 169, "text": "Seismic activity in {location} has been reported. Stay informed and vigilant! #disasterAlert", "user": "@geoNews169"},
        {"id": 170, "text": "The ground is shaking in {location}. Please follow safety procedures! #StayAlert", "user": "@quakeAlert170"},
         {"id": 171, "text": "Just felt a significant tremor in {location}. Stay calm and be prepared for aftershocks! #earthquake", "user": "@quakeWatcher171"},
        {"id": 172, "text": "Tremors reported in {location}. Make sure to check on vulnerable community members! #quakeAlert", "user": "@earthquakeToday172"},
        {"id": 173, "text": "Aftershocks shaking {location}. Stay safe and follow local advisories! #disasterPreparedness", "user": "@geoExpert173"},
        {"id": 174, "text": "Residents of {location}, ensure you have your emergency supplies ready. Stay alert! #StaySafe", "user": "@quakeNews174"},
        {"id": 175, "text": "Earthquake activity detected near {location}. Please remain indoors until cleared! #earthquakeRescue", "user": "@earthquakeAlert175"},
        {"id": 176, "text": "Shaking felt in {location}. Keep your phones charged and stay updated! #disasterAlert", "user": "@geoUpdates176"},
        {"id": 177, "text": "Strong aftershocks in {location}. Remain cautious and look out for your neighbors! #quakeAlert", "user": "@quakeRescue177"},
        {"id": 178, "text": "Reports confirm tremors in {location}. Stay indoors and avoid any distractions! #earthquake", "user": "@earthquakeToday178"},
        {"id": 179, "text": "Seismic disturbances have been noted in {location}. Keep your emergency kits accessible! #disasterAlert", "user": "@geoNews179"},
        {"id": 180, "text": "Residents in {location} should be on high alert for possible aftershocks. Stay safe! #StayAlert", "user": "@quakeAlert180"},
        {"id": 181, "text": "Aftershocks felt in {location}. Ensure you know your emergency evacuation routes! #earthquakeSafety", "user": "@quakeWatcher181"},
        {"id": 182, "text": "Tremors reported in {location}. Stay tuned to local news for updates! #quakeAlert", "user": "@earthquakeToday182"},
        {"id": 183, "text": "Shaking detected in {location}. Please secure your belongings and stay indoors! #disasterPreparedness", "user": "@geoExpert183"},
        {"id": 184, "text": "Reports of seismic activity in {location}. Stay calm and check on your loved ones! #StaySafe", "user": "@quakeNews184"},
        {"id": 185, "text": "Earthquake alerts for {location}. Prepare for possible disruptions! #earthquakeRescue", "user": "@earthquakeAlert185"},
        {"id": 186, "text": "Tremors have hit {location}. Stay vigilant and keep an eye on updates! #disasterAlert", "user": "@geoUpdates186"},
        {"id": 187, "text": "Residents of {location}, please check on elderly neighbors during these tremors! #quakeAlert", "user": "@quakeRescue187"},
        {"id": 188, "text": "Aftershocks in {location} may continue for some time. Stay prepared! #earthquake", "user": "@earthquakeToday188"},
        {"id": 189, "text": "Significant shaking reported in {location}. Please avoid unnecessary travel! #disasterAlert", "user": "@geoNews189"},
        {"id": 190, "text": "Tremors felt across {location}. Everyone, please stay indoors and remain alert! #StayAlert", "user": "@quakeAlert190"},
        {"id": 191, "text": "Strong aftershocks felt in {location}. Check in on friends and family! #earthquakeSafety", "user": "@quakeWatcher191"},
        {"id": 192, "text": "Reports indicate tremors in {location}. Stay informed and follow safety guidelines! #quakeAlert", "user": "@earthquakeToday192"},
        {"id": 193, "text": "Seismic activity detected in {location}. Secure your belongings and be prepared! #disasterPreparedness", "user": "@geoExpert193"},
        {"id": 194, "text": "Residents in {location}, ensure your emergency kits are ready for aftershocks! #StaySafe", "user": "@quakeNews194"},
        {"id": 195, "text": "Earthquake activity in {location}. Stay safe and avoid panic! #earthquakeRescue", "user": "@earthquakeAlert195"},
        {"id": 196, "text": "Aftershocks have been reported in {location}. Please stay alert and cautious! #disasterAlert", "user": "@geoUpdates196"},
        {"id": 197, "text": "Tremors felt in {location}. Make sure your family has a safety plan! #quakeAlert", "user": "@quakeRescue197"},
        {"id": 198, "text": "Reports of significant shaking in {location}. Check your emergency supplies! #earthquake", "user": "@earthquakeToday198"},
        {"id": 199, "text": "Seismic disturbances noted in {location}. Follow local safety protocols! #disasterAlert", "user": "@geoNews199"},
        {"id": 200, "text": "Residents of {location}, stay alert for aftershocks and keep emergency numbers handy! #StayAlert", "user": "@quakeAlert200"},
         {"id": 201, "text": "Tremors felt in {location}. Make sure to check on your emergency plans! #earthquake", "user": "@quakeWatcher201"},
        {"id": 202, "text": "Strong shaking reported in {location}. Stay indoors and remain calm! #quakeAlert", "user": "@earthquakeToday202"},
        {"id": 203, "text": "Aftershocks in {location} could follow. Keep your emergency supplies handy! #disasterPreparedness", "user": "@geoExpert203"},
        {"id": 204, "text": "Residents of {location}, ensure your pets are safe during these tremors! #StaySafe", "user": "@quakeNews204"},
        {"id": 205, "text": "Reports of an earthquake near {location}. Stay alert for updates! #earthquakeRescue", "user": "@earthquakeAlert205"},
        {"id": 206, "text": "Tremors have been detected in {location}. Keep calm and follow safety measures! #disasterAlert", "user": "@geoUpdates206"},
        {"id": 207, "text": "Significant shaking reported in {location}. Check your surroundings for safety! #quakeAlert", "user": "@quakeRescue207"},
        {"id": 208, "text": "Aftershocks likely in {location}. Stay updated and be prepared! #earthquake", "user": "@earthquakeToday208"},
        {"id": 209, "text": "Seismic activity in {location} has been reported. Keep emergency kits accessible! #disasterAlert", "user": "@geoNews209"},
        {"id": 210, "text": "Residents in {location}, stay alert and follow local safety guidelines! #StayAlert", "user": "@quakeAlert210"},
        {"id": 211, "text": "Tremors reported in {location}. Stay indoors until further notice! #earthquakeSafety", "user": "@quakeWatcher211"},
        {"id": 212, "text": "Reports confirm shaking in {location}. Secure your belongings and stay safe! #quakeAlert", "user": "@earthquakeToday212"},
        {"id": 213, "text": "The ground is shaking in {location}. Keep emergency contacts handy! #disasterPreparedness", "user": "@geoExpert213"},
        {"id": 214, "text": "Tremors felt in {location}. Stay close to your loved ones during this time! #StaySafe", "user": "@quakeNews214"},
        {"id": 215, "text": "Earthquake activity detected near {location}. Prepare for possible aftershocks! #earthquakeRescue", "user": "@earthquakeAlert215"},
        {"id": 216, "text": "Shaking reported in {location}. Please avoid moving around unnecessarily! #disasterAlert", "user": "@geoUpdates216"},
        {"id": 217, "text": "Tremors felt in {location}. Make sure your family has a safety plan ready! #quakeAlert", "user": "@quakeRescue217"},
        {"id": 218, "text": "Reports indicate seismic activity in {location}. Stay informed through reliable sources! #earthquake", "user": "@earthquakeToday218"},
        {"id": 219, "text": "Residents of {location}, stay calm and prepare for potential aftershocks! #disasterAlert", "user": "@geoNews219"},
        {"id": 220, "text": "Strong aftershocks felt in {location}. Check in on friends and family! #StayAlert", "user": "@quakeAlert220"},
        {"id": 221, "text": "Earthquake reports in {location}. Ensure you have an emergency kit ready! #earthquakeSafety", "user": "@quakeWatcher221"},
        {"id": 222, "text": "Tremors have been felt in {location}. Stay tuned for updates from local authorities! #quakeAlert", "user": "@earthquakeToday222"},
        {"id": 223, "text": "Aftershocks detected in {location}. Keep your phone charged and stay alert! #disasterPreparedness", "user": "@geoExpert223"},
        {"id": 224, "text": "Reports confirm shaking in {location}. Remain calm and follow safety procedures! #StaySafe", "user": "@quakeNews224"},
        {"id": 225, "text": "Seismic disturbances have hit {location}. Prepare for possible aftershocks! #earthquakeRescue", "user": "@earthquakeAlert225"},
        {"id": 226, "text": "Residents in {location}, be aware of your surroundings and stay safe! #disasterAlert", "user": "@geoUpdates226"},
        {"id": 227, "text": "Tremors reported in {location}. Secure heavy items and stay indoors! #quakeAlert", "user": "@quakeRescue227"},
        {"id": 228, "text": "Earthquake activity detected in {location}. Stay indoors and avoid panic! #earthquake", "user": "@earthquakeToday228"},
        {"id": 229, "text": "Reports of significant shaking in {location}. Keep emergency contacts handy! #disasterAlert", "user": "@geoNews229"},
        {"id": 230, "text": "Strong aftershocks expected in {location}. Stay prepared and informed! #StayAlert", "user": "@quakeAlert230"},
         {"id": 231, "text": "Tremors felt in {location}. Check your emergency plans and stay safe! #earthquake", "user": "@quakeWatcher231"},
        {"id": 232, "text": "Significant shaking reported in {location}. Stay calm and follow local guidance! #quakeAlert", "user": "@earthquakeToday232"},
        {"id": 233, "text": "Aftershocks may follow in {location}. Keep emergency supplies within reach! #disasterPreparedness", "user": "@geoExpert233"},
        {"id": 234, "text": "Residents of {location}, ensure your families are safe during these tremors! #StaySafe", "user": "@quakeNews234"},
        {"id": 235, "text": "Reports of an earthquake near {location}. Stay tuned for updates and alerts! #earthquakeRescue", "user": "@earthquakeAlert235"},
        {"id": 236, "text": "Tremors detected in {location}. Please remain indoors and avoid crowded areas! #disasterAlert", "user": "@geoUpdates236"},
        {"id": 237, "text": "Strong shaking reported in {location}. Make sure your loved ones are accounted for! #quakeAlert", "user": "@quakeRescue237"},
        {"id": 238, "text": "Aftershocks expected in {location}. Prepare yourself and your family! #earthquake", "user": "@earthquakeToday238"},
        {"id": 239, "text": "Seismic activity noted in {location}. Ensure your emergency kit is ready! #disasterAlert", "user": "@geoNews239"},
        {"id": 240, "text": "Residents in {location}, stay alert and check for any damage! #StayAlert", "user": "@quakeAlert240"},
        {"id": 241, "text": "Tremors felt in {location}. Remember to stay calm and follow safety protocols! #earthquakeSafety", "user": "@quakeWatcher241"},
        {"id": 242, "text": "Reports confirm shaking in {location}. Avoid moving around if possible! #quakeAlert", "user": "@earthquakeToday242"},
        {"id": 243, "text": "The ground is shaking in {location}. Stay informed and keep emergency numbers handy! #disasterPreparedness", "user": "@geoExpert243"},
        {"id": 244, "text": "Tremors reported in {location}. Ensure your family knows what to do during quakes! #StaySafe", "user": "@quakeNews244"},
        {"id": 245, "text": "Earthquake activity detected near {location}. Stay alert for potential aftershocks! #earthquakeRescue", "user": "@earthquakeAlert245"},
        {"id": 246, "text": "Shaking felt in {location}. Keep emergency contacts within reach! #disasterAlert", "user": "@geoUpdates246"},
        {"id": 247, "text": "Tremors in {location}. Secure heavy furniture and stay alert for updates! #quakeAlert", "user": "@quakeRescue247"},
        {"id": 248, "text": "Reports of significant shaking in {location}. Make sure to check on your neighbors! #earthquake", "user": "@earthquakeToday248"},
        {"id": 249, "text": "Seismic disturbances noted in {location}. Stay informed and prepared! #disasterAlert", "user": "@geoNews249"},
        {"id": 250, "text": "Residents of {location}, stay calm and follow local safety measures! #StayAlert", "user": "@quakeAlert250"},
        {"id": 251, "text": "Tremors felt in {location}. Make sure your pets are safe during this time! #earthquakeSafety", "user": "@quakeWatcher251"},
        {"id": 252, "text": "Strong shaking reported in {location}. Ensure your family is safe and secure! #quakeAlert", "user": "@earthquakeToday252"},
        {"id": 253, "text": "Aftershocks may occur in {location}. Keep your emergency supplies handy! #disasterPreparedness", "user": "@geoExpert253"},
        {"id": 254, "text": "Residents in {location}, stay safe and be aware of your surroundings! #StaySafe", "user": "@quakeNews254"},
        {"id": 255, "text": "Reports of an earthquake near {location}. Stay informed and follow updates! #earthquakeRescue", "user": "@earthquakeAlert255"},
        {"id": 256, "text": "Tremors detected in {location}. Secure your belongings and stay indoors! #disasterAlert", "user": "@geoUpdates256"},
        {"id": 257, "text": "Strong shaking reported in {location}. Check in with friends and family! #quakeAlert", "user": "@quakeRescue257"},
        {"id": 258, "text": "Aftershocks expected in {location}. Be prepared for any emergencies! #earthquake", "user": "@earthquakeToday258"},
        {"id": 259, "text": "Seismic activity noted in {location}. Ensure your emergency kit is accessible! #disasterAlert", "user": "@geoNews259"},
        {"id": 260, "text": "Residents of {location}, stay calm and be ready for updates! #StayAlert", "user": "@quakeAlert260"},
         {"id": 261, "text": "Tremors felt in {location}. Review your emergency plans today! #earthquakePreparedness", "user": "@quakeWatcher261"},
        {"id": 262, "text": "Strong shaking reported in {location}. Stay safe and avoid moving around! #quakeAlert", "user": "@earthquakeToday262"},
        {"id": 263, "text": "Aftershocks may hit {location}. Keep your emergency supplies stocked! #disasterReady", "user": "@geoExpert263"},
        {"id": 264, "text": "Residents of {location}, ensure your safety and check on neighbors! #StaySafe", "user": "@quakeNews264"},
        {"id": 265, "text": "Reports of an earthquake near {location}. Follow local safety protocols! #earthquakeRescue", "user": "@earthquakeAlert265"},
        {"id": 266, "text": "Tremors detected in {location}. Stay indoors and monitor updates! #disasterAlert", "user": "@geoUpdates266"},
        {"id": 267, "text": "Significant shaking reported in {location}. Make sure everyone is accounted for! #quakeAlert", "user": "@quakeRescue267"},
        {"id": 268, "text": "Aftershocks likely in {location}. Be prepared and stay vigilant! #earthquakeSafety", "user": "@earthquakeToday268"},
        {"id": 269, "text": "Seismic activity in {location}. Have your emergency kit ready! #disasterPreparedness", "user": "@geoNews269"},
        {"id": 270, "text": "Residents in {location}, stay alert and follow instructions from local authorities! #StayAlert", "user": "@quakeAlert270"},
        {"id": 271, "text": "Tremors felt in {location}. Stay calm and avoid panic! #earthquakeAwareness", "user": "@quakeWatcher271"},
        {"id": 272, "text": "Reports confirm shaking in {location}. Make sure your home is secure! #quakeAlert", "user": "@earthquakeToday272"},
        {"id": 273, "text": "Ground shaking detected in {location}. Keep emergency contacts nearby! #disasterPreparedness", "user": "@geoExpert273"},
        {"id": 274, "text": "Tremors reported in {location}. Ensure your family knows safety procedures! #StaySafe", "user": "@quakeNews274"},
        {"id": 275, "text": "Earthquake activity near {location}. Stay informed and be prepared! #earthquakeRescue", "user": "@earthquakeAlert275"},
        {"id": 276, "text": "Shaking reported in {location}. Secure heavy objects and stay safe! #disasterAlert", "user": "@geoUpdates276"},
        {"id": 277, "text": "Tremors in {location}. Keep emergency kits accessible and stay indoors! #quakeAlert", "user": "@quakeRescue277"},
        {"id": 278, "text": "Reports of significant shaking in {location}. Check on your loved ones! #earthquake", "user": "@earthquakeToday278"},
        {"id": 279, "text": "Seismic disturbances noted in {location}. Stay aware and prepared! #disasterAlert", "user": "@geoNews279"},
        {"id": 280, "text": "Residents of {location}, remain calm and stay tuned for updates! #StayAlert", "user": "@quakeAlert280"},
        {"id": 281, "text": "Tremors felt in {location}. Make sure to have a safety plan in place! #earthquakePreparedness", "user": "@quakeWatcher281"},
        {"id": 282, "text": "Strong shaking reported in {location}. Stay indoors and avoid crowded places! #quakeAlert", "user": "@earthquakeToday282"},
        {"id": 283, "text": "Aftershocks may occur in {location}. Keep emergency supplies within reach! #disasterReady", "user": "@geoExpert283"},
        {"id": 284, "text": "Residents of {location}, check your surroundings for safety! #StaySafe", "user": "@quakeNews284"},
        {"id": 285, "text": "Reports of an earthquake near {location}. Stay updated with local news! #earthquakeRescue", "user": "@earthquakeAlert285"},
        {"id": 286, "text": "Tremors detected in {location}. Remain calm and stay indoors! #disasterAlert", "user": "@geoUpdates286"},
        {"id": 287, "text": "Strong shaking reported in {location}. Ensure your family is safe and secure! #quakeAlert", "user": "@quakeRescue287"},
        {"id": 288, "text": "Aftershocks expected in {location}. Be prepared and stay informed! #earthquakeSafety", "user": "@earthquakeToday288"},
        {"id": 289, "text": "Seismic activity noted in {location}. Ensure your emergency kit is accessible! #disasterPreparedness", "user": "@geoNews289"},
        {"id": 290, "text": "Residents of {location}, stay calm and follow local safety measures! #StayAlert", "user": "@quakeAlert290"},
          {"id": 291, "text": "Tremors felt in {location}. Ensure your family has a safety plan ready! #earthquakePreparedness", "user": "@quakeWatcher291"},
        {"id": 292, "text": "Strong shaking reported in {location}. Stay safe and check on your neighbors! #quakeAlert", "user": "@earthquakeToday292"},
        {"id": 293, "text": "Aftershocks may follow in {location}. Keep emergency supplies stocked and accessible! #disasterReady", "user": "@geoExpert293"},
        {"id": 294, "text": "Residents of {location}, remember to stay indoors during tremors! #StaySafe", "user": "@quakeNews294"},
        {"id": 295, "text": "Reports of an earthquake near {location}. Stay tuned for safety updates! #earthquakeRescue", "user": "@earthquakeAlert295"},
        {"id": 296, "text": "Tremors detected in {location}. Check your emergency plan with family! #disasterAlert", "user": "@geoUpdates296"},
        {"id": 297, "text": "Significant shaking reported in {location}. Make sure everyone is safe! #quakeAlert", "user": "@quakeRescue297"},
        {"id": 298, "text": "Aftershocks expected in {location}. Stay prepared and keep your emergency kit handy! #earthquakeSafety", "user": "@earthquakeToday298"},
        {"id": 299, "text": "Seismic activity in {location}. Ensure you have essential supplies ready! #disasterPreparedness", "user": "@geoNews299"},
        {"id": 300, "text": "Residents in {location}, stay alert and monitor local news for updates! #StayAlert", "user": "@quakeAlert300"},
        {"id": 301, "text": "Tremors felt in {location}. Avoid panic and follow safety protocols! #earthquakeAwareness", "user": "@quakeWatcher301"},
        {"id": 302, "text": "Reports confirm shaking in {location}. Secure your belongings and stay safe! #quakeAlert", "user": "@earthquakeToday302"},
        {"id": 303, "text": "Ground shaking detected in {location}. Keep emergency contacts accessible! #disasterPreparedness", "user": "@geoExpert303"},
        {"id": 304, "text": "Tremors reported in {location}. Make sure your family knows what to do! #StaySafe", "user": "@quakeNews304"},
        {"id": 305, "text": "Earthquake activity noted near {location}. Stay informed and prepared! #earthquakeRescue", "user": "@earthquakeAlert305"},
        {"id": 306, "text": "Shaking reported in {location}. Secure heavy objects to prevent damage! #disasterAlert", "user": "@geoUpdates306"},
        {"id": 307, "text": "Tremors in {location}. Have your emergency plan in place and stay indoors! #quakeAlert", "user": "@quakeRescue307"},
        {"id": 308, "text": "Reports of significant shaking in {location}. Check on your loved ones and stay safe! #earthquake", "user": "@earthquakeToday308"},
        {"id": 309, "text": "Seismic disturbances noted in {location}. Stay aware and prepared for aftershocks! #disasterAlert", "user": "@geoNews309"},
        {"id": 310, "text": "Residents of {location}, remain calm and be ready for updates from authorities! #StayAlert", "user": "@quakeAlert310"},
        {"id": 311, "text": "Tremors felt in {location}. Ensure your emergency kit is ready for any situation! #earthquakePreparedness", "user": "@quakeWatcher311"},
        {"id": 312, "text": "Strong shaking reported in {location}. Stay indoors and avoid moving around unnecessarily! #quakeAlert", "user": "@earthquakeToday312"},
        {"id": 313, "text": "Aftershocks may occur in {location}. Keep your family close and safe! #disasterReady", "user": "@geoExpert313"},
        {"id": 314, "text": "Residents of {location}, check your surroundings for safety and report any issues! #StaySafe", "user": "@quakeNews314"},
        {"id": 315, "text": "Reports of an earthquake near {location}. Stay updated and follow local guidance! #earthquakeRescue", "user": "@earthquakeAlert315"},
        {"id": 316, "text": "Tremors detected in {location}. Remain calm and monitor your local news! #disasterAlert", "user": "@geoUpdates316"},
        {"id": 317, "text": "Strong shaking reported in {location}. Ensure your home is prepared for emergencies! #quakeAlert", "user": "@quakeRescue317"},
        {"id": 318, "text": "Aftershocks expected in {location}. Be prepared and keep emergency contacts handy! #earthquakeSafety", "user": "@earthquakeToday318"},
        {"id": 319, "text": "Seismic activity noted in {location}. Keep your emergency supplies stocked! #disasterPreparedness", "user": "@geoNews319"},
        {"id": 320, "text": "Residents of {location}, stay calm and be ready to respond to updates! #StayAlert", "user": "@quakeAlert320"},
          {"id": 321, "text": "Tremors felt in {location}. Stay informed about safety measures! #earthquakePreparedness", "user": "@quakeWatcher321"},
        {"id": 322, "text": "Reports of shaking in {location}. Ensure your family knows the safety plan! #quakeAlert", "user": "@earthquakeToday322"},
        {"id": 323, "text": "Aftershocks may follow in {location}. Check your emergency kit today! #disasterReady", "user": "@geoExpert323"},
        {"id": 324, "text": "Residents of {location}, stay indoors and stay safe during these tremors! #StaySafe", "user": "@quakeNews324"},
        {"id": 325, "text": "Earthquake detected near {location}. Stay tuned for safety updates from officials! #earthquakeRescue", "user": "@earthquakeAlert325"},
        {"id": 326, "text": "Tremors reported in {location}. Secure heavy items to prevent accidents! #disasterAlert", "user": "@geoUpdates326"},
        {"id": 327, "text": "Significant shaking felt in {location}. Make sure your loved ones are safe! #quakeAlert", "user": "@quakeRescue327"},
        {"id": 328, "text": "Aftershocks expected in {location}. Stay prepared and stay close to family! #earthquakeSafety", "user": "@earthquakeToday328"},
        {"id": 329, "text": "Seismic activity reported in {location}. Have a communication plan ready! #disasterPreparedness", "user": "@geoNews329"},
        {"id": 330, "text": "Residents of {location}, monitor local news for updates and safety instructions! #StayAlert", "user": "@quakeAlert330"},
        {"id": 331, "text": "Tremors felt in {location}. Remember to stay calm and follow safety guidelines! #earthquakeAwareness", "user": "@quakeWatcher331"},
        {"id": 332, "text": "Reports confirm shaking in {location}. Double-check your emergency supplies! #quakeAlert", "user": "@earthquakeToday332"},
        {"id": 333, "text": "Ground shaking detected in {location}. Keep emergency contacts handy! #disasterPreparedness", "user": "@geoExpert333"},
        {"id": 334, "text": "Tremors reported in {location}. Discuss safety procedures with your family! #StaySafe", "user": "@quakeNews334"},
        {"id": 335, "text": "Earthquake activity near {location}. Stay updated and prepare for aftershocks! #earthquakeRescue", "user": "@earthquakeAlert335"},
        {"id": 336, "text": "Shaking reported in {location}. Check on your neighbors and offer help! #disasterAlert", "user": "@geoUpdates336"},
        {"id": 337, "text": "Tremors in {location}. Have your emergency plan in place and stay indoors! #quakeAlert", "user": "@quakeRescue337"},
        {"id": 338, "text": "Reports of significant shaking in {location}. Stay connected and share updates! #earthquake", "user": "@earthquakeToday338"},
        {"id": 339, "text": "Seismic disturbances noted in {location}. Stay aware and monitor for updates! #disasterAlert", "user": "@geoNews339"},
        {"id": 340, "text": "Residents of {location}, remain calm and follow instructions from local authorities! #StayAlert", "user": "@quakeAlert340"},
        {"id": 341, "text": "Tremors felt in {location}. Ensure your emergency supplies are ready to go! #earthquakePreparedness", "user": "@quakeWatcher341"},
        {"id": 342, "text": "Strong shaking reported in {location}. Stay inside and avoid crowded places! #quakeAlert", "user": "@earthquakeToday342"},
        {"id": 343, "text": "Aftershocks may occur in {location}. Keep your family close and secure! #disasterReady", "user": "@geoExpert343"},
        {"id": 344, "text": "Residents of {location}, check your safety plans and stay alert! #StaySafe", "user": "@quakeNews344"},
        {"id": 345, "text": "Reports of an earthquake near {location}. Stay updated with safety information! #earthquakeRescue", "user": "@earthquakeAlert345"},
        {"id": 346, "text": "Tremors detected in {location}. Remain calm and monitor local news for updates! #disasterAlert", "user": "@geoUpdates346"},
        {"id": 347, "text": "Strong shaking reported in {location}. Ensure your home is ready for emergencies! #quakeAlert", "user": "@quakeRescue347"},
        {"id": 348, "text": "Aftershocks expected in {location}. Be prepared and keep emergency supplies handy! #earthquakeSafety", "user": "@earthquakeToday348"},
        {"id": 349, "text": "Seismic activity noted in {location}. Keep your emergency kit accessible! #disasterPreparedness", "user": "@geoNews349"},
        {"id": 350, "text": "Residents of {location}, stay calm and be ready to respond to updates! #StayAlert", "user": "@quakeAlert350"},
         {"id": 351, "text": "Tremors reported in {location}. Stay calm and check on your family! #earthquakePreparedness", "user": "@quakeWatcher351"},
        {"id": 352, "text": "Strong shaking felt in {location}. Ensure your emergency plan is in place! #quakeAlert", "user": "@earthquakeToday352"},
        {"id": 353, "text": "Aftershocks possible in {location}. Keep your emergency contacts ready! #disasterReady", "user": "@geoExpert353"},
        {"id": 354, "text": "Residents of {location}, make sure to secure your belongings! #StaySafe", "user": "@quakeNews354"},
        {"id": 355, "text": "Earthquake detected near {location}. Stay tuned for safety updates! #earthquakeRescue", "user": "@earthquakeAlert355"},
        {"id": 356, "text": "Tremors felt in {location}. Be prepared and stay informed! #disasterAlert", "user": "@geoUpdates356"},
        {"id": 357, "text": "Significant shaking reported in {location}. Check on your neighbors! #quakeAlert", "user": "@quakeRescue357"},
        {"id": 358, "text": "Aftershocks expected in {location}. Stay vigilant and ready! #earthquakeSafety", "user": "@earthquakeToday358"},
        {"id": 359, "text": "Seismic activity reported in {location}. Have a plan and be prepared! #disasterPreparedness", "user": "@geoNews359"},
        {"id": 360, "text": "Residents of {location}, follow local news for updates and instructions! #StayAlert", "user": "@quakeAlert360"},
        {"id": 361, "text": "Tremors felt in {location}. Discuss safety protocols with your family! #earthquakeAwareness", "user": "@quakeWatcher361"},
        {"id": 362, "text": "Reports confirm shaking in {location}. Secure your emergency supplies! #quakeAlert", "user": "@earthquakeToday362"},
        {"id": 363, "text": "Ground shaking detected in {location}. Keep emergency numbers handy! #disasterPreparedness", "user": "@geoExpert363"},
        {"id": 364, "text": "Tremors reported in {location}. Stay inside and avoid unnecessary movement! #StaySafe", "user": "@quakeNews364"},
        {"id": 365, "text": "Earthquake activity near {location}. Be prepared for updates from authorities! #earthquakeRescue", "user": "@earthquakeAlert365"},
        {"id": 366, "text": "Shaking reported in {location}. Have a communication plan with your family! #disasterAlert", "user": "@geoUpdates366"},
        {"id": 367, "text": "Tremors in {location}. Have your emergency kit accessible and stay informed! #quakeAlert", "user": "@quakeRescue367"},
        {"id": 368, "text": "Reports of significant shaking in {location}. Check in with your loved ones! #earthquake", "user": "@earthquakeToday368"},
        {"id": 369, "text": "Seismic disturbances noted in {location}. Stay alert and follow local guidance! #disasterAlert", "user": "@geoNews369"},
        {"id": 370, "text": "Residents of {location}, stay calm and wait for instructions from officials! #StayAlert", "user": "@quakeAlert370"},
        {"id": 371, "text": "Tremors felt in {location}. Ensure your emergency plan is communicated! #earthquakePreparedness", "user": "@quakeWatcher371"},
        {"id": 372, "text": "Strong shaking reported in {location}. Avoid crowded places until it's safe! #quakeAlert", "user": "@earthquakeToday372"},
        {"id": 373, "text": "Aftershocks may occur in {location}. Stay prepared and keep your family close! #disasterReady", "user": "@geoExpert373"},
        {"id": 374, "text": "Residents of {location}, check your emergency plans and stay vigilant! #StaySafe", "user": "@quakeNews374"},
        {"id": 375, "text": "Reports of an earthquake near {location}. Stay updated with local authorities! #earthquakeRescue", "user": "@earthquakeAlert375"},
        {"id": 376, "text": "Tremors detected in {location}. Remain calm and stay tuned for updates! #disasterAlert", "user": "@geoUpdates376"},
        {"id": 377, "text": "Strong shaking reported in {location}. Ensure your home is secure! #quakeAlert", "user": "@quakeRescue377"},
        {"id": 378, "text": "Aftershocks expected in {location}. Be ready and keep essentials on hand! #earthquakeSafety", "user": "@earthquakeToday378"},
        {"id": 379, "text": "Seismic activity noted in {location}. Keep your emergency supplies stocked! #disasterPreparedness", "user": "@geoNews379"},
        {"id": 380, "text": "Residents of {location}, stay calm and be ready for updates from authorities! #StayAlert", "user": "@quakeAlert380"},
        {"id": 381, "text": "Tremors felt in {location}. Check on your neighbors and stay safe! #earthquakePreparedness", "user": "@quakeWatcher381"},
        {"id": 382, "text": "Strong shaking reported in {location}. Remember to stay indoors until it’s safe! #quakeAlert", "user": "@earthquakeToday382"},
        {"id": 383, "text": "Aftershocks may occur in {location}. Have a safety plan ready! #disasterReady", "user": "@geoExpert383"},
        {"id": 384, "text": "Residents of {location}, make sure your emergency supplies are stocked! #StaySafe", "user": "@quakeNews384"},
        {"id": 385, "text": "Earthquake detected near {location}. Follow local news for updates! #earthquakeRescue", "user": "@earthquakeAlert385"},
        {"id": 386, "text": "Tremors reported in {location}. Stay calm and check your emergency kits! #disasterAlert", "user": "@geoUpdates386"},
        {"id": 387, "text": "Significant shaking felt in {location}. Ensure your family knows safety procedures! #quakeAlert", "user": "@quakeRescue387"},
        {"id": 388, "text": "Aftershocks expected in {location}. Be prepared and stay informed! #earthquakeSafety", "user": "@earthquakeToday388"},
        {"id": 389, "text": "Seismic activity reported in {location}. Keep emergency contacts accessible! #disasterPreparedness", "user": "@geoNews389"},
        {"id": 390, "text": "Residents of {location}, remain indoors and stay safe until further notice! #StayAlert", "user": "@quakeAlert390"},
        {"id": 391, "text": "Tremors felt in {location}. Discuss safety protocols with your family today! #earthquakeAwareness", "user": "@quakeWatcher391"},
        {"id": 392, "text": "Reports confirm shaking in {location}. Secure heavy furniture and stay safe! #quakeAlert", "user": "@earthquakeToday392"},
        {"id": 393, "text": "Ground shaking detected in {location}. Keep your emergency plan updated! #disasterPreparedness", "user": "@geoExpert393"},
        {"id": 394, "text": "Tremors reported in {location}. Stay informed and follow safety instructions! #StaySafe", "user": "@quakeNews394"},
        {"id": 395, "text": "Earthquake activity near {location}. Check on your loved ones and stay alert! #earthquakeRescue", "user": "@earthquakeAlert395"},
        {"id": 396, "text": "Shaking reported in {location}. Stay indoors and avoid unnecessary travel! #disasterAlert", "user": "@geoUpdates396"},
        {"id": 397, "text": "Tremors in {location}. Have your emergency kit ready and stay safe! #quakeAlert", "user": "@quakeRescue397"},
        {"id": 398, "text": "Reports of significant shaking in {location}. Keep emergency supplies close! #earthquake", "user": "@earthquakeToday398"},
        {"id": 399, "text": "Seismic disturbances noted in {location}. Stay alert and monitor local news! #disasterAlert", "user": "@geoNews399"},
        {"id": 400, "text": "Residents of {location}, stay calm and wait for further instructions! #StayAlert", "user": "@quakeAlert400"},
         {"id": 401, "text": "Tremors reported in {location}. Remember to drop, cover, and hold on! #earthquakePreparedness", "user": "@quakeWatcher401"},
        {"id": 402, "text": "Strong shaking felt in {location}. Stay updated with local emergency services! #quakeAlert", "user": "@earthquakeToday402"},
        {"id": 403, "text": "Aftershocks possible in {location}. Ensure your family knows the safety exits! #disasterReady", "user": "@geoExpert403"},
        {"id": 404, "text": "Residents of {location}, check your emergency kits and supplies! #StaySafe", "user": "@quakeNews404"},
        {"id": 405, "text": "Earthquake detected near {location}. Stay tuned for updates from local authorities! #earthquakeRescue", "user": "@earthquakeAlert405"},
        {"id": 406, "text": "Tremors felt in {location}. Stay indoors and avoid panicking! #disasterAlert", "user": "@geoUpdates406"},
        {"id": 407, "text": "Significant shaking reported in {location}. Make sure to check on elderly neighbors! #quakeAlert", "user": "@quakeRescue407"},
        {"id": 408, "text": "Aftershocks expected in {location}. Keep your emergency plan at hand! #earthquakeSafety", "user": "@earthquakeToday408"},
        {"id": 409, "text": "Seismic activity noted in {location}. Stay aware of your surroundings! #disasterPreparedness", "user": "@geoNews409"},
        {"id": 410, "text": "Residents of {location}, prepare for potential aftershocks and stay safe! #StayAlert", "user": "@quakeAlert410"},
        {"id": 411, "text": "Tremors felt in {location}. Make sure your pets are safe and secure! #earthquakeAwareness", "user": "@quakeWatcher411"},
        {"id": 412, "text": "Reports confirm shaking in {location}. Follow safety guidelines from local officials! #quakeAlert", "user": "@earthquakeToday412"},
        {"id": 413, "text": "Ground shaking detected in {location}. Keep a radio handy for updates! #disasterPreparedness", "user": "@geoExpert413"},
        {"id": 414, "text": "Tremors reported in {location}. Stay calm and help others if you can! #StaySafe", "user": "@quakeNews414"},
        {"id": 415, "text": "Earthquake activity near {location}. Be vigilant and check your supplies! #earthquakeRescue", "user": "@earthquakeAlert415"},
        {"id": 416, "text": "Shaking reported in {location}. Avoid using elevators and stay on the ground floor! #disasterAlert", "user": "@geoUpdates416"},
        {"id": 417, "text": "Tremors in {location}. Prepare for possible evacuation and keep essentials ready! #quakeAlert", "user": "@quakeRescue417"},
        {"id": 418, "text": "Reports of significant shaking in {location}. Connect with your loved ones! #earthquake", "user": "@earthquakeToday418"},
        {"id": 419, "text": "Seismic disturbances noted in {location}. Stay tuned for safety announcements! #disasterAlert", "user": "@geoNews419"},
        {"id": 420, "text": "Residents of {location}, remain vigilant and stay informed about the situation! #StayAlert", "user": "@quakeAlert420"},
          {"id": 421, "text": "Tremors felt in {location}. Prepare your emergency kit and stay indoors! #earthquakePreparedness", "user": "@quakeWatcher421"},
        {"id": 422, "text": "Strong shaking reported in {location}. Stay away from windows and glass doors! #quakeAlert", "user": "@earthquakeToday422"},
        {"id": 423, "text": "Aftershocks possible in {location}. Practice safety drills with your family! #disasterReady", "user": "@geoExpert423"},
        {"id": 424, "text": "Residents of {location}, ensure your gas lines are secure and avoid open flames! #StaySafe", "user": "@quakeNews424"},
        {"id": 425, "text": "Earthquake detected near {location}. Stay informed through official channels! #earthquakeRescue", "user": "@earthquakeAlert425"},
        {"id": 426, "text": "Tremors felt in {location}. If you’re outside, find an open area away from buildings! #disasterAlert", "user": "@geoUpdates426"},
        {"id": 427, "text": "Significant shaking reported in {location}. Check on friends and family nearby! #quakeAlert", "user": "@quakeRescue427"},
        {"id": 428, "text": "Aftershocks expected in {location}. Have a communication plan in place! #earthquakeSafety", "user": "@earthquakeToday428"},
        {"id": 429, "text": "Seismic activity reported in {location}. Know your evacuation routes! #disasterPreparedness", "user": "@geoNews429"},
        {"id": 430, "text": "Residents of {location}, stay calm and listen for emergency updates! #StayAlert", "user": "@quakeAlert430"},
        {"id": 431, "text": "Tremors felt in {location}. Move to a safe location and stay low! #earthquakeAwareness", "user": "@quakeWatcher431"},
        {"id": 432, "text": "Reports confirm shaking in {location}. Be ready for further instructions from authorities! #quakeAlert", "user": "@earthquakeToday432"},
        {"id": 433, "text": "Ground shaking detected in {location}. Avoid panic and follow safety protocols! #disasterPreparedness", "user": "@geoExpert433"},
        {"id": 434, "text": "Tremors reported in {location}. Stay updated on local news for safety information! #StaySafe", "user": "@quakeNews434"},
        {"id": 435, "text": "Earthquake activity near {location}. Ensure your family knows how to react! #earthquakeRescue", "user": "@earthquakeAlert435"},
        {"id": 436, "text": "Shaking reported in {location}. Keep emergency numbers easily accessible! #disasterAlert", "user": "@geoUpdates436"},
        {"id": 437, "text": "Tremors in {location}. Have your go-bag ready in case of evacuation! #quakeAlert", "user": "@quakeRescue437"},
        {"id": 438, "text": "Reports of significant shaking in {location}. Stay connected with your community! #earthquake", "user": "@earthquakeToday438"},
        {"id": 439, "text": "Seismic disturbances noted in {location}. Follow local authorities for guidance! #disasterAlert", "user": "@geoNews439"},
        {"id": 440, "text": "Residents of {location}, stay vigilant and check on vulnerable neighbors! #StayAlert", "user": "@quakeAlert440"},
         {"id": 441, "text": "Tremors felt in {location}. Keep your emergency kit accessible and stay calm! #earthquakePreparedness", "user": "@quakeWatcher441"},
        {"id": 442, "text": "Strong shaking reported in {location}. Secure your belongings and stay indoors! #quakeAlert", "user": "@earthquakeToday442"},
        {"id": 443, "text": "Aftershocks may occur in {location}. Familiarize yourself with safety procedures! #disasterReady", "user": "@geoExpert443"},
        {"id": 444, "text": "Residents of {location}, make sure to check on elderly and disabled neighbors! #StaySafe", "user": "@quakeNews444"},
        {"id": 445, "text": "Earthquake detected near {location}. Follow updates from local authorities! #earthquakeRescue", "user": "@earthquakeAlert445"},
        {"id": 446, "text": "Tremors felt in {location}. If you're in a vehicle, pull over safely and stay put! #disasterAlert", "user": "@geoUpdates446"},
        {"id": 447, "text": "Significant shaking reported in {location}. Prepare for potential evacuations! #quakeAlert", "user": "@quakeRescue447"},
        {"id": 448, "text": "Aftershocks expected in {location}. Stay informed and have a communication plan! #earthquakeSafety", "user": "@earthquakeToday448"},
        {"id": 449, "text": "Seismic activity reported in {location}. Know your exits and stay aware! #disasterPreparedness", "user": "@geoNews449"},
        {"id": 450, "text": "Residents of {location}, remain indoors until you receive the all-clear! #StayAlert", "user": "@quakeAlert450"},
        {"id": 451, "text": "Tremors felt in {location}. Move away from heavy furniture and glass! #earthquakeAwareness", "user": "@quakeWatcher451"},
        {"id": 452, "text": "Reports confirm shaking in {location}. Ensure you have a backup power source! #quakeAlert", "user": "@earthquakeToday452"},
        {"id": 453, "text": "Ground shaking detected in {location}. Stay low and protect your head and neck! #disasterPreparedness", "user": "@geoExpert453"},
        {"id": 454, "text": "Tremors reported in {location}. Keep your loved ones informed about your status! #StaySafe", "user": "@quakeNews454"},
        {"id": 455, "text": "Earthquake activity near {location}. Maintain communication with family and friends! #earthquakeRescue", "user": "@earthquakeAlert455"},
        {"id": 456, "text": "Shaking reported in {location}. Stay alert for emergency instructions! #disasterAlert", "user": "@geoUpdates456"},
        {"id": 457, "text": "Tremors in {location}. Be ready for potential aftershocks and stay prepared! #quakeAlert", "user": "@quakeRescue457"},
        {"id": 458, "text": "Reports of significant shaking in {location}. Help those in need if safe to do so! #earthquake", "user": "@earthquakeToday458"},
        {"id": 459, "text": "Seismic disturbances noted in {location}. Stay safe and check for updates! #disasterAlert", "user": "@geoNews459"},
        {"id": 460, "text": "Residents of {location}, stay strong and look out for each other! #StayAlert", "user": "@quakeAlert460"},
         {"id": 461, "text": "Tremors felt in {location}. Stay away from tall structures and find cover! #earthquakePreparedness", "user": "@quakeWatcher461"},
        {"id": 462, "text": "Strong shaking reported in {location}. Keep your phone charged for updates! #quakeAlert", "user": "@earthquakeToday462"},
        {"id": 463, "text": "Aftershocks may occur in {location}. Review your emergency plans! #disasterReady", "user": "@geoExpert463"},
        {"id": 464, "text": "Residents of {location}, check your emergency supplies and stay alert! #StaySafe", "user": "@quakeNews464"},
        {"id": 465, "text": "Earthquake detected near {location}. Stay tuned for safety instructions! #earthquakeRescue", "user": "@earthquakeAlert465"},
        {"id": 466, "text": "Tremors felt in {location}. If you’re at work, follow your company's safety protocol! #disasterAlert", "user": "@geoUpdates466"},
        {"id": 467, "text": "Significant shaking reported in {location}. Be cautious and look out for others! #quakeAlert", "user": "@quakeRescue467"},
        {"id": 468, "text": "Aftershocks expected in {location}. Stay in a safe location and keep informed! #earthquakeSafety", "user": "@earthquakeToday468"},
        {"id": 469, "text": "Seismic activity reported in {location}. Make sure you have a family meeting point! #disasterPreparedness", "user": "@geoNews469"},
        {"id": 470, "text": "Residents of {location}, stay indoors until you receive updates! #StayAlert", "user": "@quakeAlert470"},
        {"id": 471, "text": "Tremors felt in {location}. Check on your pets and ensure their safety! #earthquakeAwareness", "user": "@quakeWatcher471"},
        {"id": 472, "text": "Reports confirm shaking in {location}. Make sure to stay informed through reliable sources! #quakeAlert", "user": "@earthquakeToday472"},
        {"id": 473, "text": "Ground shaking detected in {location}. Protect yourself and those around you! #disasterPreparedness", "user": "@geoExpert473"},
        {"id": 474, "text": "Tremors reported in {location}. Have a first aid kit ready and accessible! #StaySafe", "user": "@quakeNews474"},
        {"id": 475, "text": "Earthquake activity near {location}. Stay connected with neighbors for mutual support! #earthquakeRescue", "user": "@earthquakeAlert475"},
        {"id": 476, "text": "Shaking reported in {location}. Remain calm and follow safety measures! #disasterAlert", "user": "@geoUpdates476"},
        {"id": 477, "text": "Tremors in {location}. Have an evacuation plan in place just in case! #quakeAlert", "user": "@quakeRescue477"},
        {"id": 478, "text": "Reports of significant shaking in {location}. Help those who may need assistance! #earthquake", "user": "@earthquakeToday478"},
        {"id": 479, "text": "Seismic disturbances noted in {location}. Keep essential documents in a safe place! #disasterAlert", "user": "@geoNews479"},
        {"id": 480, "text": "Residents of {location}, stay aware and prioritize your safety! #StayAlert", "user": "@quakeAlert480"},
          {"id": 481, "text": "Tremors felt in {location}. Secure your valuables and stay low! #earthquakePreparedness", "user": "@quakeWatcher481"},
        {"id": 482, "text": "Strong shaking reported in {location}. Keep emergency contacts handy! #quakeAlert", "user": "@earthquakeToday482"},
        {"id": 483, "text": "Aftershocks may occur in {location}. Review your family’s emergency plan! #disasterReady", "user": "@geoExpert483"},
        {"id": 484, "text": "Residents of {location}, check your emergency kits and stay indoors! #StaySafe", "user": "@quakeNews484"},
        {"id": 485, "text": "Earthquake detected near {location}. Stay updated via local news channels! #earthquakeRescue", "user": "@earthquakeAlert485"},
        {"id": 486, "text": "Tremors felt in {location}. If you’re outdoors, move to an open space! #disasterAlert", "user": "@geoUpdates486"},
        {"id": 487, "text": "Significant shaking reported in {location}. Stay alert for further instructions! #quakeAlert", "user": "@quakeRescue487"},
        {"id": 488, "text": "Aftershocks expected in {location}. Ensure you have adequate supplies at home! #earthquakeSafety", "user": "@earthquakeToday488"},
        {"id": 489, "text": "Seismic activity reported in {location}. Prepare for potential evacuations! #disasterPreparedness", "user": "@geoNews489"},
        {"id": 490, "text": "Residents of {location}, remain indoors until the situation stabilizes! #StayAlert", "user": "@quakeAlert490"},
        {"id": 491, "text": "Tremors felt in {location}. Ensure your children know safety protocols! #earthquakeAwareness", "user": "@quakeWatcher491"},
        {"id": 492, "text": "Reports confirm shaking in {location}. Stay calm and check for injuries! #quakeAlert", "user": "@earthquakeToday492"},
        {"id": 493, "text": "Ground shaking detected in {location}. Have a flashlight and batteries ready! #disasterPreparedness", "user": "@geoExpert493"},
        {"id": 494, "text": "Tremors reported in {location}. Stay informed through official updates! #StaySafe", "user": "@quakeNews494"},
        {"id": 495, "text": "Earthquake activity near {location}. Check in with neighbors to ensure their safety! #earthquakeRescue", "user": "@earthquakeAlert495"},
        {"id": 496, "text": "Shaking reported in {location}. Follow safety guidelines and stay cautious! #disasterAlert", "user": "@geoUpdates496"},
        {"id": 497, "text": "Tremors in {location}. Have an emergency exit plan ready at work and home! #quakeAlert", "user": "@quakeRescue497"},
        {"id": 498, "text": "Reports of significant shaking in {location}. Look out for fallen debris! #earthquake", "user": "@earthquakeToday498"},
        {"id": 499, "text": "Seismic disturbances noted in {location}. Stay tuned for alerts and updates! #disasterAlert", "user": "@geoNews499"},
        {"id": 500, "text": "Residents of {location}, prioritize your safety and help others in need! #StayAlert", "user": "@quakeAlert500"},
         {"id": 501, "text": "Tremors felt in {location}. Stay vigilant and check on your loved ones! #earthquakePreparedness", "user": "@quakeWatcher501"},
        {"id": 502, "text": "Strong shaking reported in {location}. Make sure you have an emergency plan! #quakeAlert", "user": "@earthquakeToday502"},
        {"id": 503, "text": "Aftershocks may occur in {location}. Keep a battery-powered radio handy! #disasterReady", "user": "@geoExpert503"},
        {"id": 504, "text": "Residents of {location}, stay indoors and away from windows! #StaySafe", "user": "@quakeNews504"},
        {"id": 505, "text": "Earthquake detected near {location}. Follow local authorities for safety updates! #earthquakeRescue", "user": "@earthquakeAlert505"},
        {"id": 506, "text": "Tremors felt in {location}. If you’re driving, pull over to a safe location! #disasterAlert", "user": "@geoUpdates506"},
        {"id": 507, "text": "Significant shaking reported in {location}. Remember to stay low and protect your head! #quakeAlert", "user": "@quakeRescue507"},
        {"id": 508, "text": "Aftershocks expected in {location}. Ensure your emergency supplies are stocked! #earthquakeSafety", "user": "@earthquakeToday508"},
        {"id": 509, "text": "Seismic activity reported in {location}. Discuss emergency procedures with family! #disasterPreparedness", "user": "@geoNews509"},
        {"id": 510, "text": "Residents of {location}, stay updated through local news and community channels! #StayAlert", "user": "@quakeAlert510"},
        {"id": 511, "text": "Tremors felt in {location}. Make sure your pets are safe and calm! #earthquakeAwareness", "user": "@quakeWatcher511"},
        {"id": 512, "text": "Reports confirm shaking in {location}. Help those who might need assistance! #quakeAlert", "user": "@earthquakeToday512"},
        {"id": 513, "text": "Ground shaking detected in {location}. Keep your emergency kit accessible! #disasterPreparedness", "user": "@geoExpert513"},
        {"id": 514, "text": "Tremors reported in {location}. Review your emergency contact list! #StaySafe", "user": "@quakeNews514"},
        {"id": 515, "text": "Earthquake activity near {location}. Ensure your family knows how to react! #earthquakeRescue", "user": "@earthquakeAlert515"},
        {"id": 516, "text": "Shaking reported in {location}. Stay cautious and monitor your surroundings! #disasterAlert", "user": "@geoUpdates516"},
        {"id": 517, "text": "Tremors in {location}. Prepare for potential disruptions in services! #quakeAlert", "user": "@quakeRescue517"},
        {"id": 518, "text": "Reports of significant shaking in {location}. Stay connected with neighbors! #earthquake", "user": "@earthquakeToday518"},
        {"id": 519, "text": "Seismic disturbances noted in {location}. Know the locations of safe spots in your home! #disasterAlert", "user": "@geoNews519"},
        {"id": 520, "text": "Residents of {location}, support one another and check for injuries! #StayAlert", "user": "@quakeAlert520"},
         {"id": 521, "text": "Tremors felt in {location}. Remain calm and take necessary precautions! #earthquakePreparedness", "user": "@quakeWatcher521"},
        {"id": 522, "text": "Strong shaking reported in {location}. Make sure your family knows safety procedures! #quakeAlert", "user": "@earthquakeToday522"},
        {"id": 523, "text": "Aftershocks may occur in {location}. Have a flashlight ready in case of power outages! #disasterReady", "user": "@geoExpert523"},
        {"id": 524, "text": "Residents of {location}, check on elderly neighbors to ensure they are safe! #StaySafe", "user": "@quakeNews524"},
        {"id": 525, "text": "Earthquake detected near {location}. Stay informed through emergency services! #earthquakeRescue", "user": "@earthquakeAlert525"},
        {"id": 526, "text": "Tremors felt in {location}. Move away from heavy furniture and stay safe! #disasterAlert", "user": "@geoUpdates526"},
        {"id": 527, "text": "Significant shaking reported in {location}. Follow your emergency action plan! #quakeAlert", "user": "@quakeRescue527"},
        {"id": 528, "text": "Aftershocks expected in {location}. Check your first aid kit and supplies! #earthquakeSafety", "user": "@earthquakeToday528"},
        {"id": 529, "text": "Seismic activity reported in {location}. Stay aware of your surroundings! #disasterPreparedness", "user": "@geoNews529"},
        {"id": 530, "text": "Residents of {location}, remain indoors and listen for further updates! #StayAlert", "user": "@quakeAlert530"},
        {"id": 531, "text": "Tremors felt in {location}. Secure your pets and keep them calm! #earthquakeAwareness", "user": "@quakeWatcher531"},
        {"id": 532, "text": "Reports confirm shaking in {location}. Stay safe and check your surroundings for hazards! #quakeAlert", "user": "@earthquakeToday532"},
        {"id": 533, "text": "Ground shaking detected in {location}. Be ready for potential evacuation! #disasterPreparedness", "user": "@geoExpert533"},
        {"id": 534, "text": "Tremors reported in {location}. Make sure to have a communication plan with family! #StaySafe", "user": "@quakeNews534"},
        {"id": 535, "text": "Earthquake activity near {location}. Prepare for possible service disruptions! #earthquakeRescue", "user": "@earthquakeAlert535"},
        {"id": 536, "text": "Shaking reported in {location}. Monitor local news for updates and instructions! #disasterAlert", "user": "@geoUpdates536"},
        {"id": 537, "text": "Tremors in {location}. Ensure your emergency kit is easily accessible! #quakeAlert", "user": "@quakeRescue537"},
        {"id": 538, "text": "Reports of significant shaking in {location}. Help others if it’s safe to do so! #earthquake", "user": "@earthquakeToday538"},
        {"id": 539, "text": "Seismic disturbances noted in {location}. Stay indoors and keep away from windows! #disasterAlert", "user": "@geoNews539"},
        {"id": 540, "text": "Residents of {location}, stay alert and be prepared for aftershocks! #StayAlert", "user": "@quakeAlert540"},
         {"id": 541, "text": "Tremors felt in {location}. Gather your family and review safety protocols! #earthquakePreparedness", "user": "@quakeWatcher541"},
        {"id": 542, "text": "Strong shaking reported in {location}. Keep your phone charged for updates! #quakeAlert", "user": "@earthquakeToday542"},
        {"id": 543, "text": "Aftershocks may occur in {location}. Know your nearest exit routes! #disasterReady", "user": "@geoExpert543"},
        {"id": 544, "text": "Residents of {location}, check your emergency supplies and stay indoors! #StaySafe", "user": "@quakeNews544"},
        {"id": 545, "text": "Earthquake detected near {location}. Stay connected with neighbors for safety! #earthquakeRescue", "user": "@earthquakeAlert545"},
        {"id": 546, "text": "Tremors felt in {location}. If you're outdoors, find an open space away from buildings! #disasterAlert", "user": "@geoUpdates546"},
        {"id": 547, "text": "Significant shaking reported in {location}. Remember to duck and cover! #quakeAlert", "user": "@quakeRescue547"},
        {"id": 548, "text": "Aftershocks expected in {location}. Keep essential documents in a safe place! #earthquakeSafety", "user": "@earthquakeToday548"},
        {"id": 549, "text": "Seismic activity reported in {location}. Have a plan for reuniting with family! #disasterPreparedness", "user": "@geoNews549"},
        {"id": 550, "text": "Residents of {location}, avoid using elevators and stay on lower floors! #StayAlert", "user": "@quakeAlert550"},
        {"id": 551, "text": "Tremors felt in {location}. Encourage friends and family to check in on each other! #earthquakeAwareness", "user": "@quakeWatcher551"},
        {"id": 552, "text": "Reports confirm shaking in {location}. Be mindful of aftershocks and stay prepared! #quakeAlert", "user": "@earthquakeToday552"},
        {"id": 553, "text": "Ground shaking detected in {location}. Ensure your children know what to do! #disasterPreparedness", "user": "@geoExpert553"},
        {"id": 554, "text": "Tremors reported in {location}. Follow local authorities for instructions and updates! #StaySafe", "user": "@quakeNews554"},
        {"id": 555, "text": "Earthquake activity near {location}. Ensure your vehicle is ready for possible evacuation! #earthquakeRescue", "user": "@earthquakeAlert555"},
        {"id": 556, "text": "Shaking reported in {location}. Take a moment to secure loose items in your home! #disasterAlert", "user": "@geoUpdates556"},
        {"id": 557, "text": "Tremors in {location}. Have a backup plan for communication with loved ones! #quakeAlert", "user": "@quakeRescue557"},
        {"id": 558, "text": "Reports of significant shaking in {location}. Check on pets and keep them calm! #earthquake", "user": "@earthquakeToday558"},
        {"id": 559, "text": "Seismic disturbances noted in {location}. Have a safe spot identified in your home! #disasterAlert", "user": "@geoNews559"},
        {"id": 560, "text": "Residents of {location}, take care and stay informed through community resources! #StayAlert", "user": "@quakeAlert560"},
         {"id": 561, "text": "Tremors felt in {location}. Remind your family to stay low and stay safe! #earthquakePreparedness", "user": "@quakeWatcher561"},
        {"id": 562, "text": "Strong shaking reported in {location}. Review your emergency exit routes! #quakeAlert", "user": "@earthquakeToday562"},
        {"id": 563, "text": "Aftershocks may follow in {location}. Keep your emergency kit within reach! #disasterReady", "user": "@geoExpert563"},
        {"id": 564, "text": "Residents of {location}, make sure to check on your neighbors after the shaking! #StaySafe", "user": "@quakeNews564"},
        {"id": 565, "text": "Earthquake detected near {location}. Follow the guidance of local authorities! #earthquakeRescue", "user": "@earthquakeAlert565"},
        {"id": 566, "text": "Tremors felt in {location}. If you're in a high-rise, move to a lower floor! #disasterAlert", "user": "@geoUpdates566"},
        {"id": 567, "text": "Significant shaking reported in {location}. Stay aware of your surroundings and hazards! #quakeAlert", "user": "@quakeRescue567"},
        {"id": 568, "text": "Aftershocks expected in {location}. Check your supplies and stay updated! #earthquakeSafety", "user": "@earthquakeToday568"},
        {"id": 569, "text": "Seismic activity reported in {location}. Know how to turn off utilities if necessary! #disasterPreparedness", "user": "@geoNews569"},
        {"id": 570, "text": "Residents of {location}, remain indoors until it's safe to go outside! #StayAlert", "user": "@quakeAlert570"},
        {"id": 571, "text": "Tremors felt in {location}. Encourage those around you to stay calm and prepared! #earthquakeAwareness", "user": "@quakeWatcher571"},
        {"id": 572, "text": "Reports confirm shaking in {location}. Make sure everyone knows the safety protocols! #quakeAlert", "user": "@earthquakeToday572"},
        {"id": 573, "text": "Ground shaking detected in {location}. Ensure your emergency contacts are updated! #disasterPreparedness", "user": "@geoExpert573"},
        {"id": 574, "text": "Tremors reported in {location}. Gather your family and discuss safety plans! #StaySafe", "user": "@quakeNews574"},
        {"id": 575, "text": "Earthquake activity near {location}. Have your first aid kit ready for emergencies! #earthquakeRescue", "user": "@earthquakeAlert575"},
        {"id": 576, "text": "Shaking reported in {location}. Stay in a safe area and avoid risky locations! #disasterAlert", "user": "@geoUpdates576"},
        {"id": 577, "text": "Tremors in {location}. Stay informed through community alerts and news updates! #quakeAlert", "user": "@quakeRescue577"},
        {"id": 578, "text": "Reports of significant shaking in {location}. Help those in need if it's safe! #earthquake", "user": "@earthquakeToday578"},
        {"id": 579, "text": "Seismic disturbances noted in {location}. Be prepared for possible disruptions! #disasterAlert", "user": "@geoNews579"},
        {"id": 580, "text": "Residents of {location}, stay aware and be ready for further instructions! #StayAlert", "user": "@quakeAlert580"},
          {"id": 581, "text": "Tremors felt in {location}. Stay indoors and check for any damage! #earthquakePreparedness", "user": "@quakeWatcher581"},
        {"id": 582, "text": "Strong shaking reported in {location}. Secure your pets and stay calm! #quakeAlert", "user": "@earthquakeToday582"},
        {"id": 583, "text": "Aftershocks may occur in {location}. Ensure you have a battery-operated radio! #disasterReady", "user": "@geoExpert583"},
        {"id": 584, "text": "Residents of {location}, keep a list of emergency contacts handy! #StaySafe", "user": "@quakeNews584"},
        {"id": 585, "text": "Earthquake detected near {location}. Review your family emergency plan today! #earthquakeRescue", "user": "@earthquakeAlert585"},
        {"id": 586, "text": "Tremors felt in {location}. Stay away from glass and heavy furniture! #disasterAlert", "user": "@geoUpdates586"},
        {"id": 587, "text": "Significant shaking reported in {location}. Stay alert and listen for updates! #quakeAlert", "user": "@quakeRescue587"},
        {"id": 588, "text": "Aftershocks expected in {location}. Have your evacuation plan ready to go! #earthquakeSafety", "user": "@earthquakeToday588"},
        {"id": 589, "text": "Seismic activity reported in {location}. Check your emergency kit for essentials! #disasterPreparedness", "user": "@geoNews589"},
        {"id": 590, "text": "Residents of {location}, maintain communication with loved ones during this time! #StayAlert", "user": "@quakeAlert590"},
        {"id": 591, "text": "Tremors felt in {location}. Ensure you know how to turn off gas and electricity safely! #earthquakeAwareness", "user": "@quakeWatcher591"},
        {"id": 592, "text": "Reports confirm shaking in {location}. Make sure to help those who may be injured! #quakeAlert", "user": "@earthquakeToday592"},
        {"id": 593, "text": "Ground shaking detected in {location}. Stay low and protect your head and neck! #disasterPreparedness", "user": "@geoExpert593"},
        {"id": 594, "text": "Tremors reported in {location}. Gather important documents in case of evacuation! #StaySafe", "user": "@quakeNews594"},
        {"id": 595, "text": "Earthquake activity near {location}. Stay updated with local news channels! #earthquakeRescue", "user": "@earthquakeAlert595"},
        {"id": 596, "text": "Shaking reported in {location}. Practice your emergency drills with family! #disasterAlert", "user": "@geoUpdates596"},
        {"id": 597, "text": "Tremors in {location}. Be prepared for potential aftershocks later! #quakeAlert", "user": "@quakeRescue597"},
        {"id": 598, "text": "Reports of significant shaking in {location}. Stay informed and calm! #earthquake", "user": "@earthquakeToday598"},
        {"id": 599, "text": "Seismic disturbances noted in {location}. Ensure your family has a communication plan! #disasterAlert", "user": "@geoNews599"},
        {"id": 600, "text": "Residents of {location}, stay together and look out for each other! #StayAlert", "user": "@quakeAlert600"},
          {"id": 601, "text": "Tremors felt in {location}. Ensure everyone knows the safest spots in your home! #earthquakePreparedness", "user": "@quakeWatcher601"},
        {"id": 602, "text": "Strong shaking reported in {location}. Stay alert for further updates from local authorities! #quakeAlert", "user": "@earthquakeToday602"},
        {"id": 603, "text": "Aftershocks may occur in {location}. Keep your emergency supplies accessible! #disasterReady", "user": "@geoExpert603"},
        {"id": 604, "text": "Residents of {location}, ensure your children understand what to do during an earthquake! #StaySafe", "user": "@quakeNews604"},
        {"id": 605, "text": "Earthquake detected near {location}. Stay indoors and avoid unnecessary travel! #earthquakeRescue", "user": "@earthquakeAlert605"},
        {"id": 606, "text": "Tremors felt in {location}. If you're in bed, stay there and cover your head! #disasterAlert", "user": "@geoUpdates606"},
        {"id": 607, "text": "Significant shaking reported in {location}. Keep a flashlight handy for power outages! #quakeAlert", "user": "@quakeRescue607"},
        {"id": 608, "text": "Aftershocks expected in {location}. Review your emergency plan with family! #earthquakeSafety", "user": "@earthquakeToday608"},
        {"id": 609, "text": "Seismic activity reported in {location}. Keep your mobile devices charged for alerts! #disasterPreparedness", "user": "@geoNews609"},
        {"id": 610, "text": "Residents of {location}, stay connected through community groups for updates! #StayAlert", "user": "@quakeAlert610"},
        {"id": 611, "text": "Tremors felt in {location}. Remind others to stay calm and avoid panic! #earthquakeAwareness", "user": "@quakeWatcher611"},
        {"id": 612, "text": "Reports confirm shaking in {location}. Gather important items in case of evacuation! #quakeAlert", "user": "@earthquakeToday612"},
        {"id": 613, "text": "Ground shaking detected in {location}. Stay low and move to an interior wall! #disasterPreparedness", "user": "@geoExpert613"},
        {"id": 614, "text": "Tremors reported in {location}. Ensure you have a list of emergency contacts ready! #StaySafe", "user": "@quakeNews614"},
        {"id": 615, "text": "Earthquake activity near {location}. Secure heavy furniture and appliances! #earthquakeRescue", "user": "@earthquakeAlert615"},
        {"id": 616, "text": "Shaking reported in {location}. Stay informed about potential aftershocks! #disasterAlert", "user": "@geoUpdates616"},
        {"id": 617, "text": "Tremors in {location}. Prepare your family for possible disruptions to services! #quakeAlert", "user": "@quakeRescue617"},
        {"id": 618, "text": "Reports of significant shaking in {location}. Follow local news for safety tips! #earthquake", "user": "@earthquakeToday618"},
        {"id": 619, "text": "Seismic disturbances noted in {location}. Help those around you stay safe! #disasterAlert", "user": "@geoNews619"},
        {"id": 620, "text": "Residents of {location}, check in on the elderly and those who need assistance! #StayAlert", "user": "@quakeAlert620"},
          {"id": 621, "text": "Tremors felt in {location}. Stay alert and monitor local news for updates! #earthquakePreparedness", "user": "@quakeWatcher621"},
        {"id": 622, "text": "Strong shaking reported in {location}. Ensure you have a first aid kit accessible! #quakeAlert", "user": "@earthquakeToday622"},
        {"id": 623, "text": "Aftershocks may occur in {location}. Keep your phone charged for emergency notifications! #disasterReady", "user": "@geoExpert623"},
        {"id": 624, "text": "Residents of {location}, talk to your family about emergency plans today! #StaySafe", "user": "@quakeNews624"},
        {"id": 625, "text": "Earthquake detected near {location}. Avoid crowded places and seek shelter! #earthquakeRescue", "user": "@earthquakeAlert625"},
        {"id": 626, "text": "Tremors felt in {location}. If you're driving, pull over and stay inside the vehicle! #disasterAlert", "user": "@geoUpdates626"},
        {"id": 627, "text": "Significant shaking reported in {location}. Know the safest places to drop, cover, and hold on! #quakeAlert", "user": "@quakeRescue627"},
        {"id": 628, "text": "Aftershocks expected in {location}. Keep your emergency supplies stocked and ready! #earthquakeSafety", "user": "@earthquakeToday628"},
        {"id": 629, "text": "Seismic activity reported in {location}. Have a backup plan for food and water supplies! #disasterPreparedness", "user": "@geoNews629"},
        {"id": 630, "text": "Residents of {location}, check on neighbors who may need assistance after the quake! #StayAlert", "user": "@quakeAlert630"},
        {"id": 631, "text": "Tremors felt in {location}. Make sure to stay informed through trusted sources! #earthquakeAwareness", "user": "@quakeWatcher631"},
        {"id": 632, "text": "Reports confirm shaking in {location}. Gather essential documents in a safe place! #quakeAlert", "user": "@earthquakeToday632"},
        {"id": 633, "text": "Ground shaking detected in {location}. Avoid using elevators during aftershocks! #disasterPreparedness", "user": "@geoExpert633"},
        {"id": 634, "text": "Tremors reported in {location}. Plan to meet family in a designated safe location! #StaySafe", "user": "@quakeNews634"},
        {"id": 635, "text": "Earthquake activity near {location}. Review your insurance policies and coverage! #earthquakeRescue", "user": "@earthquakeAlert635"},
        {"id": 636, "text": "Shaking reported in {location}. Remind children to drop and cover during tremors! #disasterAlert", "user": "@geoUpdates636"},
        {"id": 637, "text": "Tremors in {location}. Be cautious of potential landslides or rockfalls! #quakeAlert", "user": "@quakeRescue637"},
        {"id": 638, "text": "Reports of significant shaking in {location}. Help those around you who may be scared! #earthquake", "user": "@earthquakeToday638"},
        {"id": 639, "text": "Seismic disturbances noted in {location}. Stay aware of changing conditions in your area! #disasterAlert", "user": "@geoNews639"},
        {"id": 640, "text": "Residents of {location}, keep a radio handy for emergency broadcasts! #StayAlert", "user": "@quakeAlert640"},
          {"id": 641, "text": "Tremors felt in {location}. Prepare for possible power outages and have flashlights ready! #earthquakePreparedness", "user": "@quakeWatcher641"},
        {"id": 642, "text": "Strong shaking reported in {location}. Ensure your pets are safe and secure! #quakeAlert", "user": "@earthquakeToday642"},
        {"id": 643, "text": "Aftershocks may occur in {location}. Stay tuned for updates from local authorities! #disasterReady", "user": "@geoExpert643"},
        {"id": 644, "text": "Residents of {location}, check your emergency kits and ensure they are stocked! #StaySafe", "user": "@quakeNews644"},
        {"id": 645, "text": "Earthquake detected near {location}. Stay calm and assist those who may need help! #earthquakeRescue", "user": "@earthquakeAlert645"},
        {"id": 646, "text": "Tremors felt in {location}. Remember to stay away from windows during shaking! #disasterAlert", "user": "@geoUpdates646"},
        {"id": 647, "text": "Significant shaking reported in {location}. Review your family’s evacuation plan! #quakeAlert", "user": "@quakeRescue647"},
        {"id": 648, "text": "Aftershocks expected in {location}. Maintain communication with family members! #earthquakeSafety", "user": "@earthquakeToday648"},
        {"id": 649, "text": "Seismic activity reported in {location}. Be ready to help neighbors who may be affected! #disasterPreparedness", "user": "@geoNews649"},
        {"id": 650, "text": "Residents of {location}, keep your emergency contact list updated and accessible! #StayAlert", "user": "@quakeAlert650"},
        {"id": 651, "text": "Tremors felt in {location}. Secure your home and be aware of potential hazards! #earthquakeAwareness", "user": "@quakeWatcher651"},
        {"id": 652, "text": "Reports confirm shaking in {location}. Know where to find your fire extinguisher! #quakeAlert", "user": "@earthquakeToday652"},
        {"id": 653, "text": "Ground shaking detected in {location}. Keep emergency supplies in an easily reachable spot! #disasterPreparedness", "user": "@geoExpert653"},
        {"id": 654, "text": "Tremors reported in {location}. Make sure your family knows how to drop, cover, and hold on! #StaySafe", "user": "@quakeNews654"},
        {"id": 655, "text": "Earthquake activity near {location}. Plan for possible interruptions to services! #earthquakeRescue", "user": "@earthquakeAlert655"},
        {"id": 656, "text": "Shaking reported in {location}. Help those around you stay calm and collected! #disasterAlert", "user": "@geoUpdates656"},
        {"id": 657, "text": "Tremors in {location}. Stay away from heavy furniture that could tip over! #quakeAlert", "user": "@quakeRescue657"},
        {"id": 658, "text": "Reports of significant shaking in {location}. Follow guidance from emergency services! #earthquake", "user": "@earthquakeToday658"},
        {"id": 659, "text": "Seismic disturbances noted in {location}. Gather with your family in a safe area! #disasterAlert", "user": "@geoNews659"},
        {"id": 660, "text": "Residents of {location}, stay informed through reliable sources and community alerts! #StayAlert", "user": "@quakeAlert660"},
           {"id": 661, "text": "Tremors felt in {location}. Stay indoors until the shaking stops! #earthquakePreparedness", "user": "@quakeWatcher661"},
        {"id": 662, "text": "Strong shaking reported in {location}. Keep your phone charged for emergency alerts! #quakeAlert", "user": "@earthquakeToday662"},
        {"id": 663, "text": "Aftershocks may occur in {location}. Have a plan for communication with your family! #disasterReady", "user": "@geoExpert663"},
        {"id": 664, "text": "Residents of {location}, review your emergency evacuation routes today! #StaySafe", "user": "@quakeNews664"},
        {"id": 665, "text": "Earthquake detected near {location}. Stay calm and assess your surroundings! #earthquakeRescue", "user": "@earthquakeAlert665"},
        {"id": 666, "text": "Tremors felt in {location}. Secure important documents and keep them safe! #disasterAlert", "user": "@geoUpdates666"},
        {"id": 667, "text": "Significant shaking reported in {location}. Remember to stay low and cover your head! #quakeAlert", "user": "@quakeRescue667"},
        {"id": 668, "text": "Aftershocks expected in {location}. Help your neighbors stay informed about safety measures! #earthquakeSafety", "user": "@earthquakeToday668"},
        {"id": 669, "text": "Seismic activity reported in {location}. Be mindful of road conditions if traveling! #disasterPreparedness", "user": "@geoNews669"},
        {"id": 670, "text": "Residents of {location}, prepare a go-bag with essentials in case of evacuation! #StayAlert", "user": "@quakeAlert670"},
        {"id": 671, "text": "Tremors felt in {location}. If you’re outside, move to an open area away from buildings! #earthquakeAwareness", "user": "@quakeWatcher671"},
        {"id": 672, "text": "Reports confirm shaking in {location}. Monitor local channels for updates! #quakeAlert", "user": "@earthquakeToday672"},
        {"id": 673, "text": "Ground shaking detected in {location}. Be ready to respond to any emergency situation! #disasterPreparedness", "user": "@geoExpert673"},
        {"id": 674, "text": "Tremors reported in {location}. Stay away from anything that could fall during shaking! #StaySafe", "user": "@quakeNews674"},
        {"id": 675, "text": "Earthquake activity near {location}. Check your emergency supplies and restock if needed! #earthquakeRescue", "user": "@earthquakeAlert675"},
        {"id": 676, "text": "Shaking reported in {location}. Stay connected with family through group chats! #disasterAlert", "user": "@geoUpdates676"},
        {"id": 677, "text": "Tremors in {location}. Practice your emergency plan with your family regularly! #quakeAlert", "user": "@quakeRescue677"},
        {"id": 678, "text": "Reports of significant shaking in {location}. Be prepared for aftershocks and stay vigilant! #earthquake", "user": "@earthquakeToday678"},
        {"id": 679, "text": "Seismic disturbances noted in {location}. Keep a battery-powered radio handy for news updates! #disasterAlert", "user": "@geoNews679"},
        {"id": 680, "text": "Residents of {location}, organize community drills to prepare for earthquakes! #StayAlert", "user": "@quakeAlert680"},
          {"id": 681, "text": "Tremors felt in {location}. Review your safety protocols and stay vigilant! #earthquakePreparedness", "user": "@quakeWatcher681"},
        {"id": 682, "text": "Strong shaking reported in {location}. Check in with family and friends to ensure their safety! #quakeAlert", "user": "@earthquakeToday682"},
        {"id": 683, "text": "Aftershocks may occur in {location=. Have a list of emergency contacts ready! #disasterReady", "user": "@geoExpert683"},
        {"id": 684, "text": "Residents of {location}, ensure your emergency kits are accessible and ready! #StaySafe", "user": "@quakeNews684"},
        {"id": 685, "text": "Earthquake detected near {location}. Stay informed through official sources! #earthquakeRescue", "user": "@earthquakeAlert685"},
        {"id": 686, "text": "Tremors felt in {location}. Move away from heavy furniture that could topple! #disasterAlert", "user": "@geoUpdates686"},
        {"id": 687, "text": "Significant shaking reported in {location}. Remember to have a backup power source ready! #quakeAlert", "user": "@quakeRescue687"},
        {"id": 688, "text": "Aftershocks expected in {location}. Gather your loved ones and discuss your plan! #earthquakeSafety", "user": "@earthquakeToday688"},
        {"id": 689, "text": "Seismic activity reported in {location}. Stay clear of windows during tremors! #disasterPreparedness", "user": "@geoNews689"},
        {"id": 690, "text": "Residents of {location}, consider forming a neighborhood watch for emergencies! #StayAlert", "user": "@quakeAlert690"},
        {"id": 691, "text": "Tremors felt in {location}. Practice your drop, cover, and hold on technique regularly! #earthquakeAwareness", "user": "@quakeWatcher691"},
        {"id": 692, "text": "Reports confirm shaking in {location}. Keep your emergency contacts updated! #quakeAlert", "user": "@earthquakeToday692"},
        {"id": 693, "text": "Ground shaking detected in {location}. Discuss your evacuation routes with family members! #disasterPreparedness", "user": "@geoExpert693"},
        {"id": 694, "text": "Tremors reported in {location}. Help neighbors who may need assistance during this time! #StaySafe", "user": "@quakeNews694"},
        {"id": 695, "text": "Earthquake activity near {location}. Check your smoke detectors and emergency alarms! #earthquakeRescue", "user": "@earthquakeAlert695"},
        {"id": 696, "text": "Shaking reported in {location}. Be aware of your surroundings and stay calm! #disasterAlert", "user": "@geoUpdates696"},
        {"id": 697, "text": "Tremors in {location}. Stock up on non-perishable food and water supplies! #quakeAlert", "user": "@quakeRescue697"},
        {"id": 698, "text": "Reports of significant shaking in {location}. Create a family communication plan for emergencies! #earthquake", "user": "@earthquakeToday698"},
        {"id": 699, "text": "Seismic disturbances noted in {location}. Keep a fire extinguisher handy in case of emergencies! #disasterAlert", "user": "@geoNews699"},
        {"id": 700, "text": "Residents of {location}, hold regular community meetings to discuss emergency preparedness! #StayAlert", "user": "@quakeAlert700"},
           {"id": 701, "text": "Tremors felt in {location}. Stay informed and check local news for updates! #earthquakePreparedness", "user": "@quakeWatcher701"},
        {"id": 702, "text": "Strong shaking reported in {location}. Check your first aid supplies and be ready! #quakeAlert", "user": "@earthquakeToday702"},
        {"id": 703, "text": "Aftershocks may occur in {location}. Have a plan for where to meet your family! #disasterReady", "user": "@geoExpert703"},
        {"id": 704, "text": "Residents of {location}, ensure your vehicles are fueled and ready for evacuation! #StaySafe", "user": "@quakeNews704"},
        {"id": 705, "text": "Earthquake detected near {location}. Stay close to loved ones and support each other! #earthquakeRescue", "user": "@earthquakeAlert705"},
        {"id": 706, "text": "Tremors felt in {location}. Avoid using elevators during an earthquake! #disasterAlert", "user": "@geoUpdates706"},
        {"id": 707, "text": "Significant shaking reported in {location}. Stay updated through social media alerts! #quakeAlert", "user": "@quakeRescue707"},
        {"id": 708, "text": "Aftershocks expected in {location}. Maintain a clear exit path in your home! #earthquakeSafety", "user": "@earthquakeToday708"},
        {"id": 709, "text": "Seismic activity reported in {location}. Gather emergency supplies and check their expiration dates! #disasterPreparedness", "user": "@geoNews709"},
        {"id": 710, "text": "Residents of {location}, have a designated meeting place outside your home! #StayAlert", "user": "@quakeAlert710"},
        {"id": 711, "text": "Tremors felt in {location}. Encourage neighbors to stay alert and communicate! #earthquakeAwareness", "user": "@quakeWatcher711"},
        {"id": 712, "text": "Reports confirm shaking in {location}. Prepare to assist those with special needs! #quakeAlert", "user": "@earthquakeToday712"},
        {"id": 713, "text": "Ground shaking detected in {location}. Discuss your family's emergency plan regularly! #disasterPreparedness", "user": "@geoExpert713"},
        {"id": 714, "text": "Tremors reported in {location}. Encourage everyone to stay calm and collected! #StaySafe", "user": "@quakeNews714"},
        {"id": 715, "text": "Earthquake activity near {location}. Be mindful of potential road hazards! #earthquakeRescue", "user": "@earthquakeAlert715"},
        {"id": 716, "text": "Shaking reported in {location}. Ensure your children know what to do during an earthquake! #disasterAlert", "user": "@geoUpdates716"},
        {"id": 717, "text": "Tremors in {location}. Familiarize yourself with the nearest emergency shelters! #quakeAlert", "user": "@quakeRescue717"},
        {"id": 718, "text": "Reports of significant shaking in {location}. Keep your pets secured during tremors! #earthquake", "user": "@earthquakeToday718"},
        {"id": 719, "text": "Seismic disturbances noted in {location}. Follow local authorities for guidance! #disasterAlert", "user": "@geoNews719"},
        {"id": 720, "text": "Residents of {location}, participate in local disaster drills to stay prepared! #StayAlert", "user": "@quakeAlert720"},
           {"id": 721, "text": "Tremors felt in {location}. Ensure your emergency kits are well-stocked! #earthquakePreparedness", "user": "@quakeWatcher721"},
        {"id": 722, "text": "Strong shaking reported in {location}. Be alert for potential aftershocks! #quakeAlert", "user": "@earthquakeToday722"},
        {"id": 723, "text": "Aftershocks may occur in {location}. Review your family's emergency plan! #disasterReady", "user": "@geoExpert723"},
        {"id": 724, "text": "Residents of {location}, check in with elderly neighbors to ensure their safety! #StaySafe", "user": "@quakeNews724"},
        {"id": 725, "text": "Earthquake detected near {location}. Stay tuned for updates from local authorities! #earthquakeRescue", "user": "@earthquakeAlert725"},
        {"id": 726, "text": "Tremors felt in {location}. Keep your emergency contacts easily accessible! #disasterAlert", "user": "@geoUpdates726"},
        {"id": 727, "text": "Significant shaking reported in {location}. Have a flashlight ready in case of power outages! #quakeAlert", "user": "@quakeRescue727"},
        {"id": 728, "text": "Aftershocks expected in {location}. Stay away from buildings that may be unstable! #earthquakeSafety", "user": "@earthquakeToday728"},
        {"id": 729, "text": "Seismic activity reported in {location}. Keep your phone charged for emergency notifications! #disasterPreparedness", "user": "@geoNews729"},
        {"id": 730, "text": "Residents of {location}, prepare a checklist of items to grab in case of evacuation! #StayAlert", "user": "@quakeAlert730"},
        {"id": 731, "text": "Tremors felt in {location}. Review your home’s structural safety features! #earthquakeAwareness", "user": "@quakeWatcher731"},
        {"id": 732, "text": "Reports confirm shaking in {location}. Make sure your family knows the emergency plan! #quakeAlert", "user": "@earthquakeToday732"},
        {"id": 733, "text": "Ground shaking detected in {location}. Communicate your whereabouts with loved ones! #disasterPreparedness", "user": "@geoExpert733"},
        {"id": 734, "text": "Tremors reported in {location}. Stay clear of heavy furniture and hanging objects! #StaySafe", "user": "@quakeNews734"},
        {"id": 735, "text": "Earthquake activity near {location}. Check that your smoke detectors are functioning! #earthquakeRescue", "user": "@earthquakeAlert735"},
        {"id": 736, "text": "Shaking reported in {location}. Stay low and cover your head during tremors! #disasterAlert", "user": "@geoUpdates736"},
        {"id": 737, "text": "Tremors in {location}. Encourage local businesses to promote emergency preparedness! #quakeAlert", "user": "@quakeRescue737"},
        {"id": 738, "text": "Reports of significant shaking in {location}. Review community resources for disaster response! #earthquake", "user": "@earthquakeToday738"},
        {"id": 739, "text": "Seismic disturbances noted in {location}. Share your safety tips with friends and family! #disasterAlert", "user": "@geoNews739"},
        {"id": 740, "text": "Residents of {location}, create a buddy system to check on each other during emergencies! #StayAlert", "user": "@quakeAlert740"},
         {"id": 741, "text": "Tremors felt in {location}. Make sure your family has a communication plan! #earthquakePreparedness", "user": "@quakeWatcher741"},
        {"id": 742, "text": "Strong shaking reported in {location}. Store essential supplies in an easily accessible place! #quakeAlert", "user": "@earthquakeToday742"},
        {"id": 743, "text": "Aftershocks may occur in {location}. Ensure everyone knows their safe spots! #disasterReady", "user": "@geoExpert743"},
        {"id": 744, "text": "Residents of {location}, double-check your emergency kits for expired items! #StaySafe", "user": "@quakeNews744"},
        {"id": 745, "text": "Earthquake detected near {location}. Stay informed and follow local emergency updates! #earthquakeRescue", "user": "@earthquakeAlert745"},
        {"id": 746, "text": "Tremors felt in {location}. Have a backup plan for communication in case of phone outages! #disasterAlert", "user": "@geoUpdates746"},
        {"id": 747, "text": "Significant shaking reported in {location}. Gather important documents in a safe place! #quakeAlert", "user": "@quakeRescue747"},
        {"id": 748, "text": "Aftershocks expected in {location}. Discuss your neighborhood's emergency response plan! #earthquakeSafety", "user": "@earthquakeToday748"},
        {"id": 749, "text": "Seismic activity reported in {location}. Keep a portable charger handy for emergencies! #disasterPreparedness", "user": "@geoNews749"},
        {"id": 750, "text": "Residents of {location}, plan regular drills to practice your emergency procedures! #StayAlert", "user": "@quakeAlert750"},
        {"id": 751, "text": "Tremors felt in {location}. Encourage your community to participate in preparedness training! #earthquakeAwareness", "user": "@quakeWatcher751"},
        {"id": 752, "text": "Reports confirm shaking in {location}. Ensure children know how to respond during quakes! #quakeAlert", "user": "@earthquakeToday752"},
        {"id": 753, "text": "Ground shaking detected in {location}. Check your home for potential hazards! #disasterPreparedness", "user": "@geoExpert753"},
        {"id": 754, "text": "Tremors reported in {location}. Keep a list of nearby shelters and their contact info! #StaySafe", "user": "@quakeNews754"},
        {"id": 755, "text": "Earthquake activity near {location}. Review safety procedures for school-aged children! #earthquakeRescue", "user": "@earthquakeAlert755"},
        {"id": 756, "text": "Shaking reported in {location}. Remind everyone to stay calm and follow safety protocols! #disasterAlert", "user": "@geoUpdates756"},
        {"id": 757, "text": "Tremors in {location}. Organize community gatherings to discuss disaster preparedness! #quakeAlert", "user": "@quakeRescue757"},
        {"id": 758, "text": "Reports of significant shaking in {location}. Share resources about earthquake safety online! #earthquake", "user": "@earthquakeToday758"},
        {"id": 759, "text": "Seismic disturbances noted in {location}. Encourage families to create a disaster plan together! #disasterAlert", "user": "@geoNews759"},
        {"id": 760, "text": "Residents of {location}, check local resources for emergency assistance programs! #StayAlert", "user": "@quakeAlert760"},

    ]
}
# Create DataFrame
dff = pd.DataFrame(data['tweets'])

# Display the DataFrame
print(dff)

csv_file_path1 = "general_tweet_dataset.csv"
dff.to_csv(csv_file_path1, index=False)
# Out:
#       id                                               text  \
# 0      1  Earthquake felt in {location}. Stay safe! #ear...
# 1      2  Strong tremors reported in {location}. #quakeA...
# 2      3  Aftershocks shaking {location} following a mas...
# 3      4  Residents of {location} feel strong quake trem...
# 4      5  Earthquake reported near {location}. Hope ever...
# ..   ...                                                ...
# 755  756  Shaking reported in {location}. Remind everyon...
# 756  757  Tremors in {location}. Organize community gath...
# 757  758  Reports of significant shaking in {location}. ...
# 758  759  Seismic disturbances noted in {location}. Enco...
# 759  760  Residents of {location}, check local resources...
#
#                     user
# 0         @quakeWatcher1
# 1      @earthquakeToday2
# 2            @geoExpert3
# 3            @quakeNews4
# 4      @earthquakeAlert5
# ..                   ...
# 755       @geoUpdates756
# 756      @quakeRescue757
# ...

# %%
# Import necessary library
import pandas as pd
import random

# List of locations
locations = [
    "Ahmedabad", "Bengaluru", "Bhopal", "Bhubaneswar", "Chandigarh", "Chennai",
    "Coimbatore", "Dehradun", "Delhi", "Gandhinagar", "Ghaziabad", "Gwalior",
    "Hyderabad", "Indore", "Jaipur", "Jodhpur", "Kanpur", "Kochi", "Kolkata",
    "Lucknow", "Ludhiana", "Madurai", "Mumbai", "Mysuru", "Nagpur", "Nashik",
    "Patna", "Pune", "Raipur", "Rajkot", "Ranchi", "Salem", "Surat", "Thane",
    "Tiruchirappalli", "Vadodara", "Varanasi", "Visakhapatnam", "Agra", "Aligarh",
    "Allahabad", "Aurangabad", "Bikaner", "Bilaspur", "Dhanbad", "Durgapur",
    "Guntur", "Haridwar", "Imphal", "Jamshedpur", "Jammu", "Kalyan", "Kanpur Nagar",
    "Kolhapur", "Kottayam", "Kozhikode", "Madhurai", "Mangalore", "Meerut",
    "Moradabad", "Nagapattinam", "Nanded", "Nashik", "Nizamabad", "Panaji",
    "Patiala", "Ranchi", "Rourkela", "Siliguri", "Solapur", "Srinagar", "Surat",
    "Thiruvananthapuram", "Tirupati", "Udaipur", "Ujjain", "Vadodara", "Vellore",
    "Warangal", "Amritsar", "Asansol", "Bhatinda", "Bhilai", "Bhuj",
    "Chittorgarh", "Dibrugarh", "Erode", "Haldwani", "Howrah", "Jhansi",
    "Jodhpur", "Kanchipuram", "Kharagpur", "Mathura", "Morbi", "Muzaffarpur",
    "Nadiad", "Rourkela", "Sagar", "Silchar"
]


# Generate tweets dataset
tweets_list = []
for i in range(100):
    tweet_template = random.choice(data["tweets"])  # Select a random tweet template
    location = locations[i % len(locations)]  # Cycle through locations
    tweet_text = tweet_template["text"].replace("{location}", location)
    
    tweets_list.append({
        "id": i + 1,
        "text": tweet_text
    })

# Create DataFrame
df = pd.DataFrame(tweets_list)

# Store data in CSV file
csv_file_path = "tweets_dataset.csv"
df.to_csv(csv_file_path, index=False)

print(f"Data saved to {csv_file_path}")
# Out:
# Data saved to tweets_dataset.csv
