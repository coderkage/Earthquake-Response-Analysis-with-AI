# %%
import pandas as pd

columns = ['geonameid', 'name', 'asciiname', 'alternatenames', 'latitude', 'longitude', 
           'feature_class', 'feature_code', 'country_code', 'cc2', 'population', 'elevation', 
           'dem', 'timezone', 'modification_date']

japan_data = pd.read_csv('JP/JP.txt', sep='\t', header=None, names=columns)

japan_data.head()
# Out:
# C:\Users\deepp\AppData\Local\Temp\ipykernel_3764\4197333747.py:7: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   japan_data = pd.read_csv('JP/JP.txt', sep='\t', header=None, names=columns)
#                                                                                                 geonameid  \
# 1847943 Yotsuhama         Yotsuhama         Yotsuhama                                            33.41604
# 1847944 Tahara-mura       Tahara-mura       Tahara-mura,Tawara-mura                              35.45000
# 1847945 Tatsuno-shi       Tatsuno-shi       Tatsuno,Tatsuno-cho,Tatsuno-chō,Tatsuno-machi,T...   34.88804
# 1847946 Shimo-funaka-mura Shimo-funaka-mura Shimo-funaka-mura                                    35.28333
# 1847947 Shingū            Shingu            Schingu,Shingu,Shingui,Shingū,Sing,Singu,Singu-...   33.73333
#
# ...

# %%
japan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 102919 entries, (1847943, 'Yotsuhama', 'Yotsuhama', 'Yotsuhama') to (13117777, 'Fukuoka Chūō Parking Lot, 20241014', 'Fukuoka Chuo Parking Lot, 20241014', 'fu gang di yi zi dong che zhu che chang,fu gang zhong yang zi dong che zhu che chang,fukuokashichuuoujidoushachuushajou,fukuwokashichiyuuaujidoushiyachiyuushiyadjiyau,ふくおかしちゅうおうじどうしゃちゅうしゃじょう,ふくをかしちゆうあうじどうしやちゆうしやぢやう,福岡中央自動車駐車場,福岡第一自動車駐車場')
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   geonameid          102919 non-null  float64
#  1   name               102919 non-null  float64
#  2   asciiname          102919 non-null  object
#  3   alternatenames     102919 non-null  object
#  4   latitude           102919 non-null  object
#  5   longitude          10 non-null      object
#  6   feature_class      102843 non-null  float64
#  7   feature_code       84118 non-null   float64
# ...

# %%
japan_data
# Out:
#                                                                                                                                    geonameid  \
# 1847943  Yotsuhama                          Yotsuhama                          Yotsuhama                                            33.41604
# 1847944  Tahara-mura                        Tahara-mura                        Tahara-mura,Tawara-mura                              35.45000
# 1847945  Tatsuno-shi                        Tatsuno-shi                        Tatsuno,Tatsuno-cho,Tatsuno-chō,Tatsuno-machi,T...   34.88804
# 1847946  Shimo-funaka-mura                  Shimo-funaka-mura                  Shimo-funaka-mura                                    35.28333
# 1847947  Shingū                             Shingu                             Schingu,Shingu,Shingui,Shingū,Sing,Singu,Singu-...   33.73333
# ...

# %%
japan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102919 entries, 0 to 102918
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   geonameid          102919 non-null  int64
#  1   name               102918 non-null  object
#  2   asciiname          102918 non-null  object
#  3   alternatenames     94255 non-null   object
#  4   latitude           102919 non-null  float64
#  5   longitude          102919 non-null  float64
#  6   feature_class      102919 non-null  object
#  7   feature_code       102919 non-null  object
#  8   country_code       102919 non-null  object
#  9   cc2                10 non-null      object
#  10  admin1_code        102843 non-null  float64
#  11  admin2_code        84118 non-null   float64
#  12  admin3_code        34009 non-null   float64
#  13  admin4_code        139 non-null     float64
#  14  population         102919 non-null  int64
# ...

# %%
filtered_data = japan_data[~japan_data['feature_class'].isin(['U','V','T','H'])]

# %%
filtered_data['feature_class'].unique()
# Out:
# array(['P', 'A', 'S', 'L', 'R'], dtype=object)

# %%
"""feature classes:
A: country, state, region,...
H: stream, lake, ...
L: parks,area, ...
P: city, village,...
R: road, railroad 
S: spot, building, farm
T: mountain,hill,rock,... 
U: undersea
V: forest,heath,..."""
# Out:
# 'feature classes:\nA: country, state, region,...\nH: stream, lake, ...\nL: parks,area, ...\nP: city, village,...\nR: road, railroad \nS: spot, building, farm\nT: mountain,hill,rock,... \nU: undersea\nV: forest,heath,...'

# %%
filtered_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80889 entries, 0 to 102918
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   geonameid          80889 non-null  int64
#  1   name               80888 non-null  object
#  2   asciiname          80888 non-null  object
#  3   alternatenames     74150 non-null  object
#  4   latitude           80889 non-null  float64
#  5   longitude          80889 non-null  float64
#  6   feature_class      80889 non-null  object
#  7   feature_code       80889 non-null  object
#  8   country_code       80889 non-null  object
#  9   cc2                0 non-null      object
#  10  admin1_code        80858 non-null  float64
#  11  admin2_code        75041 non-null  float64
#  12  admin3_code        29899 non-null  float64
#  13  admin4_code        139 non-null    float64
#  14  population         80889 non-null  int64
#  15  elevation          313 non-null    float64
# ...

# %%
japan_data.to_csv('raw_gazetteer.csv')

# %%
filtered_data.to_csv('filtered_gazetteer.csv')
