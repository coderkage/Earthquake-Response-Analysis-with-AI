# %%
import os
import requests
import zipfile
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("gazetteer/filtered_gazetteer.csv")

location_df = df[['asciiname']]

location_names = location_df['asciiname'].dropna().tolist()
location_names = [name for name in location_names if isinstance(name, str)]

print(f"Extracted {len(location_names)} location names.")
# Out:
# Extracted 80888 location names.

# %%
location_names
# Out:
# ['Yotsuhama',
#  'Tahara-mura',
#  'Tatsuno-shi',
#  'Shimo-funaka-mura',
#  'Shingu',
#  'Naha Air Base',
#  'Naegi-cho',
#  'Mimitsu',
#  'Katayamazu',
#  'Kadena Air Base',
#  'Gonotao',
#  'Futenma Marine Corps Air Station',
#  'Atsugi',
#  'Akiaga-eki',
#  'Akashi',
#  'Zushi',
#  'Zukeran',
#  'Zozo',
#  'Zoshuku',
#  'Awazucho',
#  'Zeze-eki',
#  'Zeze',
#  'Zentsuji Shi',
#  'Zentsujicho',
#  'Ikawadanicho-zenkai',
#  'Zengi',
#  'Zenda',
#  'Zeidani',
#  'Zazare',
#  'Zaomachi',
#  'Zama Shi',
#  'Zamami Son',
#  'Zamami',
#  'Azumacho-zama',
#  'Zama',
#  'Zakimi',
#  'Zaisho-mura',
#  'Zaisho',
#  'Kamitakaracho-zaike',
#  'Zahana',
#  'Zaha',
#  'Yuzuriha',
#  'Yuzawa',
#  'Yuza',
#  'Yuyama',
#  'Yuyama',
#  'Amagasemachi-yuyama',
#  'Yuwan',
#  'Yutorino',
#  'Yuto-cho',
#  'Yutamaminami',
#  'Yutaka-mura',
#  'Yusuhara',
#  'Yushima-mura',
#  'Yurugi',
#  'Yurakucho',
#  'Yura Cho',
#  'Yura',
#  'Yura',
#  'Yura',
#  'Yuracho-yura',
#  'Yunoyama',
#  'Yunotsuru-onsen',
#  'Yunotsucho-kohama',
#  'Gero',
#  'Yunoo',
#  'Yunoo',
#  'Katsumotocho-yunomotoura',
#  'Yunomae Machi',
#  'Yunomae',
#  'Yunokuchi',
#  'Yunokicho',
#  'Yunokawachi',
#  'Yunokami',
#  'Yunohama',
#  'Yunogo',
#  'Yuno',
#  'Yona',
#  'Yumura',
#  'Kisukicho-yumura',
#  'Yumugi',
#  'Yumoto-machi',
#  'Yumoto',
#  'Yumoto',
#  'Yumoto',
#  'Yumikino',
#  'Tamayucho-yumachi',
#  'Yukuhashi Shi',
#  'Yukuhashi',
#  'Yuki Shi',
#  'Yukinoura',
#  'Yukinobe',
#  'Yuki-gun',
#  'Yuki-cho',
#  'Yuki-cho',
#  'Yuki',
#  'Yuki',
#  'Higashiyuki',
#  'Yujuku',
#  'Yui',
#  'Yui',
#  'Yuge-mura',
#  'Yuge',
#  'Yugawara',
#  'Yugawa Mura',
#  'Yugawa',
#  'Yugashima',
#  'Yufuin-cho',
#  'Yudomari',
#  'Yude',
#  'Yudanaka',
#  'Yuda',
#  'Yubara-cho',
#  'Yuba',
#  'Yuasa',
#  'Yamadayu',
#  'Yumachi',
#  'Yoza',
#  'Yoyogi-sanyacho,Tokyo',
#  'Yowara',
#  'Yotsuya',
#  'Yotsuya',
#  'Yotsuya',
#  'Yotsuura',
#  'Yotsutsuji',
#  'Yotsugoya',
#  'Yotsugama',
#  'Yoshizuka-eki',
#  'Yoshizu',
#  'Yoshiwara',
#  'Yoshiura',
#  'Yoshiura-ikenouracho',
#  'Hiyoshicho-yoshitoshi',
#  'Yoshitomi Machi',
#  'Yoshioka Machi',
#  'Yoshinoyama',
#  'Yoshinotani-mura',
#  'Yoshino Mura',
#  'Yoshino-Kumano-kokuritsu-koen',
#  'Yoshino-gun',
#  'Yoshinocho',
#  'Yoshino-cho',
#  'Yoshino-cho',
#  'Yoshino-cho',
#  'Yoshinobu-eki',
#  'Yoshino',
#  'Yoshinagacho-yoshinaganaka',
#  'Yoshinaga',
#  'Yoshimo',
#  'Yoshimo',
#  'Yoshimi Machi',
#  'Yoshimi',
#  'Yoshimi',
#  'Yoshimi-honmachi',
#  'Nakatsugawa',
#  'Yoshiki-gun',
#  'Yoshikawa-mura',
#  'Yoshikawa-machi',
#  'Yoshikawa',
#  'Yoshikawa',
#  'Yoshii-machi',
#  'Yoshii',
#  'Yoshii',
#  'Yoshiimachi-fukumasu',
#  'Yoshihara',
#  'Yoshihama',
#  'Mitsushimacho-yoshigaura',
#  'Yoshigase',
#  'Yoshie',
#  'Yoshidacho-yoshida',
#  'Yoshida-machi',
#  'Yoshida-machi',
#  'Yoshida Cho',
#  'Yoshida-kasugacho',
#  'Yoshida',
#  'Yoshida',
#  'Yoshida',
#  'Yoshida',
#  'Minecho-yoshida',
#  'Yoshida',
#  'Kamiyoshida',
#  'Yoshida',
#  'Yose',
#  'Yosami-mura',
#  'Yosa-gun',
#  'Yoron Cho',
#  'Miimachi-yoromi',
#  'Yoro Cho',
#  'Yoro',
#  'Yorishimacho',
#  'Yoriki',
#  'Yorii',
#  'Yorii',
#  'Yoriaido',
#  'Yonozu-mura',
#  'Yonozu',
#  'Yonouzu-mura',
#  'Yono',
#  'Yonekura',
#  'Yonekura',
#  'Yoneda-cho',
#  'Yonamine',
#  'Yonama',
#  'Yonaguni Cho',
#  'Yonakuni',
#  'Yonaha',
#  'Yonaha',
#  'Yonagusuku-son',
#  'Yonashiro',
#  'Yonagusuku',
#  'Yonagushiku',
#  'Yonago Shi',
#  'Yonago',
#  'Yonabaru Cho',
#  'Yonabaru',
#  'Yomitan Son',
#  'Yomi-son',
#  'Yomi-shinden',
#  'Yomikaki-mura',
#  'Yokura',
#  'Yokuda',
#  'Yokoyama-mura',
#  'Yokoyama',
#  'Yokoyama',
#  'Toyotamacho-yokoura',
#  'Yokotani',
#  'Yokota',
#  'Yokotamachi',
#  'Yokota',
#  'Yokota',
#  'Yokosuna-nakacho',
#  'Yokosuka Shi',
#  'Yokosuka Eki',
#  'Yokosuka',
#  'Yokosuka',
#  'Yokosuka',
#  'Yokoshima',
#  'Yokoshima',
#  'Yokose',
#  'Saikaicho-yokosego',
#  'Yokooka',
#  'Yokoocho',
#  'Yokoo',
#  "Une-yoko'o",
#  'Yokoo',
#  'Yokono-mura',
#  'Iinancho-yokono',
#  'Yokono',
#  'Yokomi',
#  'Yokomakura',
#  'Yokokura',
#  'Yokokura',
#  'Yokokawa-eki',
#  'Matsuida-yokokawa',
#  'Yokohane-sen',
#  'Yokohama Shi',
#  'Yokohama Eki',
#  'Yokohama',
#  'Yokohama',
#  'Yokohama',
#  'Yokogoshi-chuo',
#  'Yokokawa',
#  'Yokogawa-eki',
#  'Yokogawa',
#  'Yokogawa',
#  'Yokodani',
#  'Yokodaido',
#  'Yokobuki',
#  'Yokobayashi',
#  'Yokkamachi',
#  'Yokkaichi-shi',
#  'Yokkaichi-eki',
#  'Yokkaichi',
#  'Yokkaichi',
#  'Yokkaichi',
#  'Yokinosato',
#  'Yokawa-cho',
#  'Yokata-araya',
#  'Yokamachi',
#  'Yokaichi-shi',
#  'Youkaichi',
#  'Yokaichi',
#  'Yoka',
#  'Yoita-machi',
#  'Yoitamachi-yoita',
#  'Yohena',
#  'Yogo-cho',
#  'Yogi',
#  'Yogi',
#  'Yofuke',
#  'Yodoecho-yodoe',
#  'Yodobashi',
#  'Yodo',
#  'Yodayama',
#  'Yobuno',
#  'Yobukocho-yobuko',
#  'Yobimatsu',
#  'Yobiko-cho',
#  'Yobe-ku',
#  'Yoan',
#  'Yoake-mura',
#  'Yo',
#  'Yazu-gun',
#  'Yayoi',
#  'Yawataya',
#  'Yawatano',
#  'Yawata-mura',
#  'Yawata-mura',
#  'Yawata-mura',
#  'Yawatahama',
#  'Yahata',
#  'Yawata',
#  'Yawata',
#  'Yawata',
#  'Yawata',
#  'Yahata',
#  'Yawata',
#  'Yawata',
#  'Yatsuzawa',
#  'Yatsushiro Shi',
#  'Yatsushiro-gun',
#  'Yatsushiro',
#  'Honmachi',
#  'Yatsuomachi-higashikumisaka',
#  'Yatsuka-son',
#  'Yatsuka-gun',
#  'Yatsuaicho',
#  'Yatsu',
#  'Yatomi-shi',
#  'Yatoko',
#  'Tetsutacho-yato',
#  'Yatani',
#  'Yata-mura',
#  'Hohokucho-yatama',
#  'Yatagai',
#  'Fushiki-Yata',
#  'Yatacho',
#  'Mabicho-yata',
#  'Yasuzuka-machi',
#  'Yasuzuka',
#  'Yasuoka Mura',
#  'Yasuokacho',
#  'Yasuno-son',
#  'Ankiyaba',
#  'Yasuishuku',
#  'Yasu-gun',
#  'Yasugicho',
#  'Yasuda-mura',
#  'Yasuda',
#  'Yasuda',
#  'Yasuda',
#  'Yasu-cho',
#  'Yasu-shi',
#  'Yasucho-chigire',
#  'Yaso',
#  'Yashiro-cho',
#  'Yashiro',
#  'Yashiro',
#  'Yashio',
#  'Yasaka',
#  'Yasaka',
#  'Yarimizu',
#  'Yara',
#  'Yaotsu Cho',
#  'Yaotsu',
#  'Yao-shi',
#  'Yao-machi',
#  'Yao-cho',
#  'Yao',
#  'Yanokuchi',
#  'Yanohara',
#  'Yanohama',
#  'Yano',
#  'Yani',
#  'Yanaze',
#  'Yanase',
#  'Yanase',
#  'Zakaja',
#  'Yanase',
#  'Yana-mura',
#  'Yanami',
#  'Yanaka-mura',
#  'Yanaka',
#  'Yanaizu Machi',
#  'Yanaizu-cho',
#  'Yanaizu',
#  'Yanaizucho',
#  'Yanai Shi',
#  'Yanaike',
#  'Yanai',
#  'Yanahara-cho',
#  'Yanahara',
#  'Yanagyudo',
#  'Yana-gun',
#  'Yanagimotocho',
#  'Yanagihara-mura',
#  'Yanagigaura-machi',
#  'Yanagigatani',
#  'Yanagida-mura',
#  'Yanagida-mura',
#  'Yanagidamen',
#  'Yanagida',
#  'Yanagida',
#  'Yanagicho',
#  'Yanagibashi-eki',
#  'Yanagibashi',
#  'Yanagi',
#  'Yanagi',
#  'Yanagawa Shi',
#  'Yanagawa',
#  'Yanadani',
#  'Yanadacho',
#  'Yamura-machi',
#  'Yame Shi',
#  'Yame-gun',
#  'Yamazoe-mura',
#  'Yamazato',
#  'Yamazato',
#  'Maruokacho-yamazaki-sanga',
#  'Yamazaki',
#  'Yamazaki',
#  'Toyonomachi-yamasaki',
#  'Yamawaki',
#  'Yamaura',
#  'Akimachi-yamaura',
#  'Yamauchi',
#  'Yamatotakada-shi',
#  'Yamato-Takada',
#  'Yamato Son',
#  'Yamato-shi',
#  'Yamato-mura',
#  'Yamatominami',
#  'Yamato-machi',
#  'Yamato-machi',
#  'Yamatokoriyama-shi',
#  'Yamatohama',
#  'Yamato-gun',
#  'Yamatomachi',
#  'Yamatomachi-mitsuai',
#  'Yamate-son',
#  'Yamata-mura',
#  'Yamata',
#  'Yamasuwara',
#  'Yamashitacho',
#  'Yamashitacho',
#  'Yamashitacho',
#  'Yamashita',
#  'Tomiemachi-yamashita',
#  'Yamashita',
#  'Yamashiro-cho',
#  'Yamashiro',
#  'Yamashiro',
#  'Yamashina-eki',
#  'Yamashina',
#  'Yamagawacho-suwa',
#  'Yamasato-mura',
#  'Yamasa-mura',
#  'Yamasaki-cho',
#  'Yamasaki',
#  'Yamasaki',
#  'Yamazakicho-nakabirose',
#  'Yamasaki',
#  'Yamaoka-cho',
#  'Nakayama',
#  'Yamanoha',
#  'Yamanoue',
#  'Yamanouchi Machi',
#  'Yamanouchi',
#  'Yamanote',
#  'Yamanoshitamachi',
#  'Yamanoku-cho',
#  'Yamanokuchi',
#  'Yamanokuchi',
#  'Yamanokami',
#  'Okuchi-yamano',
#  'Yamanashi Shi',
#  'Yamanashi',
#  'Yamanashi',
#  'Yamanakako Mura',
#  'Yamanaka',
#  'Yamanakacho',
#  'Tomiyamacho-yamanaka',
#  'Yamamoto-mura',
#  'Yamamoto',
#  'Yamamotocho',
#  'Nejime-yamamoto',
#  'Yamakuni-machi',
#  'Yamakumata',
#  'Yamakoshi-mura',
#  'Yamakita',
#  'Yamakawa-cho',
#  'Yamakami',
#  'Yamajo',
#  'Yama-ikarashi',
#  'Yamahara',
#  'Ishikawa-Yamashiro',
#  'Yamagusuku',
#  'Yamagusuku',
#  'Yama-gun',
#  'Yamaguchi Shi',
#  'Yamaguchi-mura',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaguchicho-yamaguchi',
#  'Yamaguchi',
#  'Yamaguchi-nishi',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Yamaguchi',
#  'Ainouracho',
#  'Yamage',
#  'Yamagawa-cho',
#  'Yama-gawachi',
#  'Kagamicho-yamagawa',
#  'Yamagata-gun',
#  'Yamagasu',
#  'Yamagano',
#  'Yamaga-machi',
#  'Yamaga',
#  'Yamaga',
#  'Yamaga',
#  'Yamae',
#  'Yamadani-maki',
#  'Yamada-mura',
#  'Yamada-mura',
#  'Yamada-mura',
#  'Yamada-mura',
#  'Kamiokacho-yamada',
#  'Yamada',
#  'Yamada',
#  'Tosayamadacho-nakano',
#  'Yamada',
#  'Yamada',
#  'Ikitsukicho-yamadamen',
#  'Yamauchi',
#  'Yakuwa',
#  'Yakutsu',
#  'Yakumo-mura',
#  'Yakumocho',
#  'Yakuin-Horibata',
#  'Yaku-cho',
#  'Yako',
#  'Yagiyama',
#  'Yakezaki',
#  'Yakeyama',
#  'Yonashiro-yakena',
#  'Yakami-shin',
#  'Yakami-machi',
#  'Yakage-cho',
#  'Yakage',
#  'Yakata',
#  'Yaka',
#  'Yaka',
#  'Yaizu Shi',
#  'Yaizu',
#  'Yaita Shi',
#  'Yaita',
#  'Yaishi',
#  'Yahiko',
#  'Yahata-ku',
#  'Yahata Eki',
#  'Yahata',
#  'Yahagi',
#  'Yahagi',
#  'Yahagi',
#  'Yagyu-shimocho',
#  'Yagyu-mura',
#  'Yagyu-go',
#  'Yagyucho',
#  'Seihicho-yagiharago',
#  'Yagi-mura',
#  'Yagi',
#  'Yagicho',
#  'Yagi',
#  'Yagami',
#  'Yagami',
#  'Yagaji-son',
#  'Yaga',
#  'Yafuso',
#  'Yaeyama-gun',
#  'Yaeji',
#  'Yae',
#  'Yadon',
#  'Yadomi-shimo',
#  'Yadacho',
#  'Tetsuseicho-yada',
#  'Yachiyo-machi',
#  'Yachiyo-cho',
#  'Yachiho-mura',
#  'Yachiho-mura',
#  'Yabuzukahon-machi',
#  'Yabutani',
#  'Yabu-son',
#  'Yabunami-mura',
#  'Yabu-shi',
#  'Yabukami-mura',
#  'Yabuhara',
#  'Yabuhana',
#  'Yabu-gun',
#  'Yabu-eki',
#  'Yabu',
#  'Yabu',
#  'Yabitsu',
#  'Yabiku',
#  'Yabiku',
#  'Yabe-machi',
#  'Yabase',
#  'Watase',
#  'Wakaho-watauchi',
#  'Watashiba',
#  'Yokawacho-watase',
#  'Watase',
#  'Watariba',
#  'Watari',
#  'Watari',
#  'Watarai-gun',
#  'Shimowatada',
#  'Washizu-cho',
#  'Washizu',
#  'Washizaki',
#  'Washimiya-machi',
#  'Washika',
#  'Waseda',
#  'Wara-mura',
#  'Warabyo',
#  'Warabo',
#  'Warabioka-mura',
#  'Warabi-shi',
#  'Wano-mura',
#  'Wano',
#  'Kamitsushimacho-waniura',
#  'Wan',
#  'Wakuramachi',
#  'Wakugawa',
#  'Waku',
#  'Wako-shi',
#  'Wakita',
#  'Wakinomachi',
#  'Wakinohamacho',
#  'Waki-mura',
#  'Wakimoto',
#  'Wakimoto',
#  'Wakimisaki',
#  'Waki Cho',
#  'Waki-cho',
#  'Waki',
#  'Wakicho',
#  'Waki',
#  'Waki',
#  'Wakimachi',
#  'Waki',
#  'Wake',
#  'Wakayama Shi',
#  'Wakayama',
#  'Wakaura-naka',
#  'Wakatsu',
#  'Wakasato',
#  'Wakasa',
#  'Wakasa',
#  'Wakamiya-cho',
#  'Wakami-machi',
#  'Wakamiko',
#  'Wakami',
#  'Wakamatsu Ku',
#  'Wakamatsucho',
#  'Wakamatsu Eki',
#  'Wakamatsu',
#  'Wakamatsugo',
#  'Wakakuri',
#  'Wakago',
#  'Wakagi-mura',
#  'Wakagimachi-kawago',
#  'Higashiiya-wakabayashi',
#  'Wajiro-mura',
#  'Wajima Shi',
#  'Wajima',
#  'Wajiki',
#  'Wajiki',
#  'Waji',
#  'Waifu',
#  'Wagu',
#  'Wago-mura',
#  'Wago-machi',
#  'Wadomari Town',
#  'Wadomari',
#  'Wadayamadori',
#  'Wadayama-cho',
#  'Wadayama',
#  'Wadajimacho',
#  'Wadasakicho',
#  'Wada-mura',
#  'Wadamachi',
#  'Wada',
#  'Wadacho',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Hatsusemachi-wada',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Wada',
#  'Wachino',
#  'Wachi-cho',
#  'Wachi-eki',
#  'Wabuka',
#  'Uzuto',
#  'Uzukawa',
#  'Uza',
#  'Uyagawa',
#  'Uwayama',
#  'Uwaura',
#  'Uwano',
#  'Uwano',
#  'Uwano',
#  'Uwa',
#  'Uwajima-shi',
#  'Uwaino',
#  'Uwagi',
#  'Uwadana',
#  'Uwada',
#  'Uttaki',
#  'Utsunomiya Shi',
#  'Utsunomiya',
#  'Utsunobara',
#  'Utsuno',
#  'Utsumi',
#  'Utsuishi',
#  'Utsui-kami',
#  'Utsubo',
#  'Miyagawacho-utsubo',
#  'Uto Shi',
#  'Utonkochi',
#  'Uto-gun',
#  'Biseicho-utodani',
#  'Uto',
#  'Uto',
#  'Uchihana',
#  'Utazu',
#  'Utatonami-mura',
#  'Uta-machi',
#  'Shikamachicho-shimoutagaura',
#  'Utagaki-mura',
#  'Uta',
#  'Uta',
#  'Ususuki',
#  'Kosazacho-usunoura',
#  'Usuki Shi',
#  'Usuki-machi',
#  'Usuki',
#  'Yatsuomachi-usujima',
#  'Usui-gun',
#  'Usui',
#  'Usugi',
#  'Usuda-machi',
#  'Usuda',
#  'Ushuku',
#  'Ushizuma',
#  'Ushizucho-ushizu',
#  'Ushijima',
#  'Yuya-ushirobata',
#  'Ushiroo',
#  'Ushiodacho',
#  'Ushiomura',
#  'Ushinoya',
#  'Ushimadocho-ushimado',
#  'Ushicho',
#  'Ushibukamachi',
#  'Ushitsu',
#  'Usen',
#  'Usa Shi',
#  'Uzanbaru',
#  'Usa-machi',
#  'Usa-gun',
#  'Usacho',
#  'Usa',
#  'Uryuno',
#  'Urushiyama-mura',
#  'Urushiyama',
#  'Urushi',
#  'Urumi',
#  'Uruido',
#  'Urugi Mura',
#  'Uro',
#  'Uro',
#  'Urigocho',
#  'Ureshinomachi-shimojuku',
#  'Urasoe Shi',
#  'Urayasu-shi',
#  'Urayasu',
#  'Saitama-shi',
#  'Urawa-ku',
#  'Urauchi',
#  'Urada',
#  'Urata',
#  'Urasoko',
#  'Urasho-son',
#  'Yonozu-urashiroura',
#  'Urasaki',
#  'Urasa',
#  'Uranosaki',
#  'Takaokacho-uranomyo',
#  'Urankochi',
#  'Ura Nihon',
#  'Uranaka',
#  'Urakamimachi',
#  'Urajiro',
#  'Uraji',
#  'Uraharu',
#  'Urago-machi',
#  'Urago',
#  'Uragawara',
#  'Urankashira',
#  'Uragami',
#  'Uraga',
#  'Uradome',
#  'Urado',
#  'Urada-mura',
#  'Urada',
#  'Ura',
#  'Ura',
#  'Ura',
#  'Ura',
#  'Ura',
#  'Uozu Shi',
#  'Uozu',
#  'Uojima-mura',
#  'Unzen National Park',
#  'Unzen',
#  'Uniumachi',
#  'Unuma-cho',
#  'Unten',
#  'Untenbaru',
#  'Umusa',
#  'Unoshima Eki',
#  'Unoshima',
#  'Unoke',
#  'Uno',
#  'Uno',
#  'Uneharu',
#  'Une-hara',
#  'Unedomari',
#  'Unebicho',
#  'Une',
#  'Unazuki-onsen',
#  'Unami',
#  'Unami',
#  'Onaha',
#  'Onaga',
#  'Uminokuchi',
#  'Umi-machi',
#  'Umi',
#  'Umeura',
#  'Umesato-mura',
#  'Umekoji-kamotsueki',
#  'Umeki',
#  'Umeki',
#  'Umehara',
#  'Umegashima',
#  'Umedocho',
#  'Umeda',
#  'Umaze',
#  'Shingucho-umatate',
#  'Umanoue',
#  'Ikedacho-umaji',
#  'Uma-gun',
#  'Umagaeshi',
#  'Ukyo Ku',
#  'Uku-cho',
#  'Ukitsu',
#  'Ukitsu',
#  'Ukishima-mura',
#  'Ukishima',
#  'Uken',
#  'Uki',
#  'Uken',
#  'Ukegawa',
#  'Ukawa',
#  'Minakuchicho-ukawa',
#  'Ukaji',
#  'Horyumachi-ukai',
#  'Uka',
#  'Uka',
#  'Uji-tawara Cho',
#  'Uji Shi',
#  'Ujinamachi',
#  'Ujiie',
#  'Uji-gun',
#  'Uji-cho',
#  'Uji',
#  'Uji',
#  'Kamiunten',
#  'Uinouchi',
#  'Uechi',
#  'Ugusu',
#  'Ugui-mura',
#  'Ugui',
#  'Ugi',
#  'Ukazuka',
#  'Ugata',
#  'Ugashi-mura',
#  'Uga',
#  'Ota',
#  'Okobori',
#  'Ufudo',
#  'Uezu',
#  'Uezu',
#  'Uesugicho',
#  'Ueno-son',
#  'Ueno-shi',
#  'Ueno-mura',
#  'Uenoji',
#  'Uenohara-shi',
#  'Uenohara',
#  'Ueno-cho',
#  'Ueno',
#  'Ueno',
#  'Ueno',
#  'Ueno',
#  'Ueno',
#  'Ueno-ebisumachi',
#  'Ueno',
#  'Ueno',
#  'Ueno',
#  'Uenagata',
#  'Ue-mura',
#  'Uemmachi',
#  'Uemisaki',
#  'Uematsu',
#  'Ueki',
#  'Uekimachi-mono',
#  'Uegusuku',
#  'Ueda Shi',
#  'Ueda-mura',
#  'Ueda',
#  'Ueda',
#  'Ueta',
#  'Uechi',
#  'Uehara',
#  'Yonashiro-uehara',
#  'Uebaru',
#  'Ue-aratacho',
#  'Udono',
#  'Udo',
#  'Udano-cho',
#  'Uda-gun',
#  'Uchiyama-mura',
#  'Unazukimachi-uchiyama',
#  'Uchiura-mura',
#  'Uchiura-machi',
#  'Uchiura',
#  'Uchiumi',
#  'Uchitomi-mura',
#  'Ujidomari',
#  'Uchita-cho',
#  'Uchisaiwaicho',
#  'Uchinoura-cho',
#  'Uchinoumi',
#  'Uchino-mura',
#  'Uchinomi-cho',
#  'Uchinomaki',
#  'Uchinomachi',
#  'Uchikawauchi',
#  'Uchino',
#  'Uchinashi',
#  'Uchinada Machi',
#  'Uchikawa-mura',
#  'Uchikawa',
#  'Uchihatacho',
#  'Uchigo-mura',
#  'Yamagamachi-uchigawano',
#  'Uchifukuji',
#  'Uchidani',
#  'Uchiage-mura',
#  'Ube Shi',
#  'Ube',
#  'Ubara',
#  'Ubaguchi',
#  'Tsuzurahara',
#  'Tsuzu',
#  'Tsuzawa',
#  'Tsuyazaki',
#  'Tsuyama Shi',
#  'Tsuyama',
#  'Tsuwazakigo',
#  'Tsuwano',
#  'Tsutsunoura',
#  'Tsutsuicho',
#  'Izuharamachi-tsutsu',
#  'Tsushima-shi',
#  'Tsushima',
#  'Goshikicho-tsushi',
#  'Tsu-shi',
#  'Tsusedo',
#  ...]

# %%
def prepare_spacy_training_data(location_names):
    print("Preparing SpaCy training data...")
    training_data = []
    
    for name in location_names:
        sentence = f"{name} was affected severly by earthquake."
        entities = [(0, len(name), "GPE")]  
        training_data.append((sentence, {"entities": entities}))
    
    print(f"Prepared {len(training_data)} sentences for training.")
    return training_data

# %%
training_data = prepare_spacy_training_data(location_names)
# Out:
# Preparing SpaCy training data...
# Prepared 80888 sentences for training.

# %%
training_data_file = os.path.join("train/train_data_1.jsonl")

# %%
import json

with open(training_data_file, 'w') as file:
    for entry in training_data:
        json.dump(entry, file)
        file.write('\n')

print(f"Training data saved to {training_data_file}")
# Out:
# Training data saved to train/train_data_1.jsonl

# %%
import pandas as pd
import json
import unicodedata
import re
from io import StringIO


df = pd.read_csv("data2.csv")

def convert_to_ascii(text):
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8')

def create_custom_format(df):
    records = []
    
    for _, row in df.iterrows():
        text = convert_to_ascii(row['text'])  
        start_loc = row['start_loc']
        end_loc = row['end_loc']

        entities = []
        entities.append([start_loc, end_loc, "GPE"])
        
        disaster_keywords = ["earthquake", "death", "died", "shake", "collapse", "collapses", "collapsed", "shaking", "aftershocks", "tremors", "disturbances", "disaster", "casualty"]
        
        for keyword in disaster_keywords:
            pattern = r'\b' + re.escape(keyword) + r'\b'
            matches = [(m.start(), m.end()) for m in re.finditer(pattern, text.lower())]
            for start, end in matches:
                entities.append([start, end, "DISASTER"])
        
        records.append([text, {"entities": entities}])
    
    return records

custom_records = create_custom_format(df)

output_file = 'train/train_data_2.jsonl'
with open(output_file, 'w') as f:
    for record in custom_records:
        f.write(json.dumps(record) + '\n')

print(f"JSONL data has been saved to {output_file}.")
# Out:
# JSONL data has been saved to train/train_data_2.jsonl.
