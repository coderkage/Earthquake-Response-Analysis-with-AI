# %%
import pandas as pd
import spacy
from tqdm import tqdm
from spacy.matcher import PhraseMatcher

# %%
csv_file = 'preprocessed_0f_turkey.csv'

# %%
df = pd.read_csv(csv_file)

# %%
df
# Out:
#                                                     text  \
# 0      Hey    Turkish users are getting a rate limit ...
# 1      May Allah have mercy on all those who passed a...
# 2                                  We Stand with Turkey
# 3      🔔 ( M3.9 occurred 21 km E of  ( 37 min ago (lo...
# 4      🚨 Former Newcastle United star Christian Atsu ...
# ...                                                  ...
# 36772   Massive thanks to you and the entire  team fo...
# 36773  PLEASE donate to AHBAP charity, the only chari...
# 36774  🙏😭😭😭I thought my heart would burst from grief,...
# 36775  Alhamdulilllah they are safe and sound ❤️     ...
# 36776  Please donate, like share RAISE AWARENESS THAT...
#
#                             date  \
# 0      2023-02-06 13:04:30+00:00
# 1      2023-02-06 13:04:30+00:00
# 2      2023-02-06 13:04:31+00:00
# 3      2023-02-06 13:04:33+00:00
# 4      2023-02-06 13:04:33+00:00
# ...                          ...
# 36772  2023-02-10 23:57:03+00:00
# 36773  2023-02-10 23:58:12+00:00
# 36774  2023-02-10 23:58:20+00:00
# 36775  2023-02-10 23:58:21+00:00
# 36776  2023-02-10 23:58:58+00:00
#
#                                           processed_text
# 0      hey turkish users are getting rate limit excee...
# 1      may allah have mercy on all those who passed a...
# 2                                  we stand with turkey
# 3       occurred km of min ago local time smile more ...
# 4       former newcastle united star christian atsu i...
# ...                                                  ...
# 36772   massive thanks to you and the entire team for...
# 36773  please donate to ahbap charity the only charit...
# 36774   thought my heart would burst from grief tears...
# 36775             alhamdulillah they are safe and sound
# 36776  please donate like share raise awareness that ...
#
# [36777 rows x 3 columns]

# %%
def extract_locations(text):
    nlp = spacy.load("en_core_web_sm")
    matcher = PhraseMatcher(nlp.vocab)
    # Add custom location names to the matcher
    location_patterns = []
    for loc in location_patterns:
        matcher.add("LOCATION", None, nlp(loc))

    doc = nlp(text)
    locations = []
    
    # Extract locations using NER
    for ent in doc.ents:
        if ent.label_ == 'GPE' or ent.label_ == 'LOC':
            locations.append(ent.text)

    # Extract additional locations using the custom matcher
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        locations.append(span.text)
    
    return locations

# %%
all_locations1 = []
flags=[]
for text in tqdm(df['processed_text'], desc="Extracting Locations", total=len(df)):
    locations = extract_locations(text)
    all_locations1.extend(locations)
    
    # Set the flag to 1 if locations were found, otherwise 0
    if locations:
        flags.append(1)
    else:
        flags.append(0)

# Add the flag column to the DataFrame
df['flag1'] = flags
# Print or use the list of all locations
print(all_locations1)
# Out:
# Extracting Locations:   0%|          | 0/36777 [00:00<?, ?it/s]C:\Users\deepp\AppData\Roaming\Python\Python312\site-packages\transformers\utils\generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# C:\Users\deepp\AppData\Roaming\Python\Python312\site-packages\transformers\utils\generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Extracting Locations:   1%|          | 245/36777 [02:09<5:21:07,  1.90it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 flags=[]
#       3 for text in tqdm(df['processed_text'], desc="Extracting Locations", total=len(df)):
# ----> 4     locations = extract_locations(text)
#       5     all_locations1.extend(locations)
#       7     # Set the flag to 1 if locations were found, otherwise 0
#
# Cell In[5], line 2, in extract_locations(text)
#       1 def extract_locations(text):
# ----> 2     nlp = spacy.load("en_core_web_sm")
#       3     matcher = PhraseMatcher(nlp.vocab)
#       4     # Add custom location names to the matcher
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     463     return get_lang_class(name.replace("blank:", ""))()
#     464 if is_package(name):  # installed as package
# --> 465     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     466 if Path(name).exists():  # path to model data directory
#     467     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     484 """Load a model from an installed package.
#     485
#     486 name (str): The package name.
#    (...)
#     498 RETURNS (Language): The loaded nlp object.
#     499 """
#     500 cls = importlib.import_module(name)
# --> 501 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\en_core_web_sm\__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not model_path.exists():
#     681     raise IOError(Errors.E052.format(path=data_path))
# --> 682 return load_model_from_path(
#     683     data_path,
#     684     vocab=vocab,
#     685     meta=meta,
#     686     disable=disable,
#     687     enable=enable,
#     688     exclude=exclude,
#     689     config=config,
#     690 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:547, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     538 config = load_config(config_path, overrides=overrides)
#     539 nlp = load_model_from_config(
#     540     config,
#     541     vocab=vocab,
#    (...)
#     545     meta=meta,
#     546 )
# --> 547 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\language.py:2209, in Language.from_disk(self, path, exclude, overrides)
#    2206 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2207     # Convert to list here in case exclude is (default) tuple
#    2208     exclude = list(exclude) + ["vocab"]
# -> 2209 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2210 self._path = path  # type: ignore[assignment]
#    2211 self._link_components()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\util.py:1390, in from_disk(path, readers, exclude)
#    1387 for key, reader in readers.items():
#    1388     # Split to support file names like meta.json
#    1389     if key.split(".")[0] not in exclude:
# -> 1390         reader(path / key)
#    1391 return path
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\language.py:2185, in Language.from_disk.<locals>.deserialize_vocab(path)
#    2183 def deserialize_vocab(path: Path) -> None:
#    2184     if path.exists():
# -> 2185         self.vocab.from_disk(path, exclude=exclude)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\vocab.pyx:515, in spacy.vocab.Vocab.from_disk()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\spacy\lookups.py:311, in Lookups.from_disk(self, path, filename, **kwargs)
#     309 filepath = path / filename
#     310 if filepath.exists():
# --> 311     with filepath.open("rb") as file_:
#     312         data = file_.read()
#     313     return self.from_bytes(data)
#
# File c:\Program Files\Python312\Lib\pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# KeyboardInterrupt:

# %%
locations_df1 = pd.DataFrame(all_locations1, columns=['Location'])

# %%
locations_df1
# Out:
#      Location
# 0      turkey
# 1         oha
# 2      turkey
# 3      israel
# 4      turkey
# ...       ...
# 2619    syria
# 2620   turkey
# 2621    syria
# 2622   turkey
# 2623    syria
#
# [2624 rows x 1 columns]

# %%
locations_df1.to_csv('extracted_locations_turkey.csv', index=False)

# %%
from geopy.geocoders import Nominatim

# %%
def get_coordinates(location):
    geolocator = Nominatim(user_agent="location_finder")
    try:
        location_info = geolocator.geocode(location)
        if location_info:
            return location_info.latitude, location_info.longitude
        else:
            return None, None
    except:
        return None, None

# %%
locations_data = []

# %%
unique_locations = set(all_locations1)
for location in tqdm(unique_locations, desc="Geocoding Locations"):
    frequency = all_locations1.count(location)
    latitude, longitude = get_coordinates(location)
    if latitude is not None and longitude is not None:
        locations_data.append({'Location': location, 'Frequency': frequency, 'Latitude': latitude, 'Longitude': longitude})
# Out:
# Geocoding Locations: 100%|███████████████████████████████████████████████████████████| 174/174 [02:36<00:00,  1.11it/s]

# %%
locations_coordinate1 = pd.DataFrame(locations_data)

# %%
locations_coordinate1
# Out:
#             Location  Frequency   Latitude   Longitude
# 0            baghdad          1  33.306170   44.387221
# 1    the middle east          5  35.869605  -84.121049
# 2        middle east          7  39.301416  -76.588848
# 3         al arabiya          1  17.015257   54.093151
# 4         california          4  36.701463 -118.755997
# ..               ...        ...        ...         ...
# 142            japan          5  36.574844  139.239418
# 143             bhai          1  32.057482   76.275716
# 144           rojava          1  24.168196  -13.892143
# 145           canada          4  61.066692 -107.991707
# 146           mexico          1  19.432630  -99.133178
#
# [147 rows x 4 columns]

# %%
locations_coordinate1.to_csv('coordinate_turkey.csv', index=False)
