# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import utils1
import utils2
import utils3

# %%
df = pd.read_csv("preprocessed_0f_iraq_iran.csv", low_memory=False)

# %%
df['processed_text'] = df['processed_text'].astype(str)

# %%
df.head()
# Out:
#                                                 text        date  \
# 0  RT @PressTV: UPDATE: Death toll from Iran’s qu...  13_11_2017
# 1  RT @CAFOD: We pray for all those affected by t...  13_11_2017
# 2  RT @ReutersWorld: JUST IN: Death toll reaches ...  13_11_2017
# 3  RT @LaylaAlhussein: A magnitude 7.2 earthquake...  13_11_2017
# 4  RT @LaylaAlhussein: A magnitude 7.2 earthquake...  13_11_2017
#
#                      category  \
# 0      injured_or_dead_people
# 1            not_humanitarian
# 2      injured_or_dead_people
# 3  other_relevant_information
# 4  other_relevant_information
#
#                                       processed_text
# 0  rt update death toll from iran quake rises to ...
# 1  rt we pray for all those affected by the earth...
# 2  rt just in death toll reaches in iran earthqua...
# 3  rt magnitude earthquake struck northern iraq i...
# 4  rt magnitude earthquake struck northern iraq i...

# %%
df['date'] = pd.to_datetime(df['date'],format='%d_%m_%Y')

# %%
df.isna().sum()
# Out:
# text              0
# date              0
# category          0
# processed_text    0
# dtype: int64

# %%
all_text = ' '.join(df['text'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import gensim
import nltk
nltk.download('averaged_perceptron_tagger')

pd.options.mode.chained_assignment = None
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
def process_text(text):
    # Step 1: Tokenize and get POS tags
    tokens = nltk.pos_tag(word_tokenize(text))
    # print(colored("Step 1: Tokenize\n", "blue"), "{}\n".format([w[0] for w in tokens]))
    
    # Step 2: Lemmatize each word 
    tokens = [lemmatizer.lemmatize(w[0], utils2.pos_tag_convert(w[1])) for w in tokens]
    # print(colored("Step 2: Lemmatize\n", "blue"), "{}\n".format(tokens))
    
    return tokens

def process_random_message(df):
    # Apply process_text function to each entry in the processed_text column
    df['tokens'] = df['processed_text'].apply(process_text)
    return df

# Process all entries in the processed_text column and add the tokens column in df
df = process_random_message(df)
df
# Out:
#                                                   text       date  \
# 0    RT @PressTV: UPDATE: Death toll from Iran’s qu... 2017-11-13
# 1    RT @CAFOD: We pray for all those affected by t... 2017-11-13
# 2    RT @ReutersWorld: JUST IN: Death toll reaches ... 2017-11-13
# 3    RT @LaylaAlhussein: A magnitude 7.2 earthquake... 2017-11-13
# 4    RT @LaylaAlhussein: A magnitude 7.2 earthquake... 2017-11-13
# ..                                                 ...        ...
# 592  Damage proxy maps of 5 cities near the epicent... 2017-11-18
# 593  #Iran Daily: US Treasury Blocks Donations for ... 2017-11-18
# 594  #Kurdish children's situation after the #earth... 2017-11-18
# 595  #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A... 2017-11-18
# 596  Victims of last week's earthquake gather outdo... 2017-11-18
#
#                                    category  \
# 0                    injured_or_dead_people
# 1                          not_humanitarian
# 2                    injured_or_dead_people
# 3                other_relevant_information
# 4                other_relevant_information
# ..                                      ...
# 592       infrastructure_and_utility_damage
# 593  rescue_volunteering_or_donation_effort
# 594                    affected_individuals
# 595              other_relevant_information
# 596                    affected_individuals
#
#                                         processed_text  \
# 0    rt update death toll from iran quake rises to ...
# 1    rt we pray for all those affected by the earth...
# 2    rt just in death toll reaches in iran earthqua...
# 3    rt magnitude earthquake struck northern iraq i...
# 4    rt magnitude earthquake struck northern iraq i...
# ..                                                 ...
# 592  damage proxy maps of cities near the epicenter...
# 593   iran daily us treasury blocks donations for e...
# 594   kurdish children situation after the earthqua...
# 595   iran earthquake exposes political rifts and i...
# 596  victims of last week earthquake gather outdoor...
#
#                                                 tokens
# 0    [rt, update, death, toll, from, iran, quake, r...
# 1    [rt, we, pray, for, all, those, affect, by, th...
# 2    [rt, just, in, death, toll, reach, in, iran, e...
# 3    [rt, magnitude, earthquake, strike, northern, ...
# 4    [rt, magnitude, earthquake, strike, northern, ...
# ..                                                 ...
# 592  [damage, proxy, map, of, city, near, the, epic...
# 593  [iran, daily, u, treasury, block, donation, fo...
# 594  [kurdish, child, situation, after, the, earthq...
# 595  [iran, earthquake, expose, political, rift, an...
# 596  [victim, of, last, week, earthquake, gather, o...
#
# [597 rows x 5 columns]

# %%
# Count number of words and save as a column
df["num_words"] = df.processed_text.apply(lambda x: len(x.split(" ")))

# Count number of tokens and save as a column
df["num_tokens"] = df.tokens.apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                                 text       date  \
# 0  RT @PressTV: UPDATE: Death toll from Iran’s qu... 2017-11-13
# 1  RT @CAFOD: We pray for all those affected by t... 2017-11-13
# 2  RT @ReutersWorld: JUST IN: Death toll reaches ... 2017-11-13
# 3  RT @LaylaAlhussein: A magnitude 7.2 earthquake... 2017-11-13
# 4  RT @LaylaAlhussein: A magnitude 7.2 earthquake... 2017-11-13
#
#                      category  \
# 0      injured_or_dead_people
# 1            not_humanitarian
# 2      injured_or_dead_people
# 3  other_relevant_information
# 4  other_relevant_information
#
#                                       processed_text  \
# 0  rt update death toll from iran quake rises to ...
# 1  rt we pray for all those affected by the earth...
# 2  rt just in death toll reaches in iran earthqua...
# 3  rt magnitude earthquake struck northern iraq i...
# 4  rt magnitude earthquake struck northern iraq i...
#
#                                               tokens  num_words  num_tokens
# 0  [rt, update, death, toll, from, iran, quake, r...         11          10
# 1  [rt, we, pray, for, all, those, affect, by, th...         15          14
# 2  [rt, just, in, death, toll, reach, in, iran, e...         13          12
# 3  [rt, magnitude, earthquake, strike, northern, ...         13          12
# 4  [rt, magnitude, earthquake, strike, northern, ...         13          12

# %%
# All of the messages in the dataset
corpus = df.tokens

# Create the Dictionary
corpus_dictionary = gensim.corpora.Dictionary(corpus)

print(colored("Before filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")

# Filter for words that occur more than 5 times overall
corpus_dictionary.filter_extremes(no_below=5)

# Create bag of words out of the full corpus
corpus_bow = [corpus_dictionary.doc2bow(doc) for doc in corpus]

print(colored("After filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")
# Out:
# Before filter:  Dictionary contains a total of 1276 unique words
# After filter:  Dictionary contains a total of 231 unique words

# %%
# Convert bag of words back to text format
corpus_text = [[corpus_dictionary[word_id] for word_id, freq in doc] for doc in corpus_bow]

# Flatten the list of lists
corpus_text_flat = [word for sublist in corpus_text for word in sublist]

# Join the words into a single string
corpus_text_combined = ' '.join(corpus_text_flat)

# Generate word cloud
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(corpus_text_combined)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import random
import gensim
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
corpus
# Out:
# 0      [rt, update, death, toll, from, iran, quake, r...
# 1      [rt, we, pray, for, all, those, affect, by, th...
# 2      [rt, just, in, death, toll, reach, in, iran, e...
# 3      [rt, magnitude, earthquake, strike, northern, ...
# 4      [rt, magnitude, earthquake, strike, northern, ...
#                              ...
# 592    [damage, proxy, map, of, city, near, the, epic...
# 593    [iran, daily, u, treasury, block, donation, fo...
# 594    [kurdish, child, situation, after, the, earthq...
# 595    [iran, earthquake, expose, political, rift, an...
# 596    [victim, of, last, week, earthquake, gather, o...
# Name: tokens, Length: 597, dtype: object

# %%
all_words = list(corpus_dictionary.values())

print(f"Dictionary contains a total of {len(all_words)} unique words")
# Out:
# Dictionary contains a total of 231 unique words

# %%
all_words
# Out:
# ['death',
#  'from',
#  'quake',
#  'rise',
#  'rt',
#  'to',
#  'toll',
#  'update',
#  'all',
#  'and',
#  'by',
#  'for',
#  'in',
#  'iraq',
#  'pray',
#  'the',
#  'we',
#  'just',
#  'news',
#  'magnitude',
#  'northern',
#  'november',
#  'on',
#  'strike',
#  'area',
#  'border',
#  'damage',
#  'report',
#  'video',
#  'break',
#  'dead',
#  'official',
#  'over',
#  'say',
#  'at',
#  'kill',
#  'late',
#  'least',
#  'more',
#  'near',
#  'than',
#  'after',
#  'between',
#  'hit',
#  'hundred',
#  'powerful',
#  'help',
#  'victim',
#  'strong',
#  'rock',
#  'be',
#  'people',
#  'region',
#  'have',
#  'devastate',
#  'felt',
#  'with',
#  'about',
#  'heart',
#  'my',
#  'ὢ',
#  'iraqi',
#  'aftermath',
#  'amp',
#  'deadly',
#  'live',
#  'sulaymaniyah',
#  'kermanshah',
#  'our',
#  'sympathy',
#  'many',
#  'thousand',
#  'km',
#  'kurdish',
#  'wound',
#  'new',
#  'of',
#  'kuwait',
#  'outside',
#  'stand',
#  'heartbreaking',
#  'photo',
#  'ὤf',
#  'a',
#  'injure',
#  'government',
#  'halabja',
#  'major',
#  'no',
#  'turkish',
#  'israel',
#  'iranearthquake',
#  'relief',
#  'visit',
#  'western',
#  'tv',
#  'country',
#  'life',
#  'loss',
#  'that',
#  'this',
#  'world',
#  'city',
#  'kurdistan',
#  'village',
#  'picture',
#  'moment',
#  'leave',
#  'breakingnews',
#  'family',
#  'prayer',
#  'assistance',
#  'iranian',
#  'offer',
#  'blood',
#  'donation',
#  'survivor',
#  'tehran',
#  'west',
#  'pm',
#  'will',
#  'because',
#  'condolence',
#  'express',
#  'his',
#  'president',
#  'morning',
#  'night',
#  'sunday',
#  'do',
#  'now',
#  'most',
#  'get',
#  'medium',
#  'some',
#  'up',
#  'or',
#  'god',
#  'province',
#  'you',
#  'around',
#  'so',
#  'what',
#  'why',
#  'please',
#  'your',
#  'die',
#  'trump',
#  'via',
#  'pic',
#  'yesterday',
#  'follow',
#  'here',
#  'know',
#  'massive',
#  'their',
#  'but',
#  'own',
#  'show',
#  'tragic',
#  'way',
#  'deep',
#  'big',
#  'rescue',
#  'earthquakeiraq',
#  'last',
#  'response',
#  'emerge',
#  'destroy',
#  'sad',
#  'speak',
#  'today',
#  'town',
#  'recent',
#  'effect',
#  'number',
#  'an',
#  'allah',
#  'fuck',
#  'great',
#  'he',
#  'not',
#  'then',
#  'child',
#  'collapse',
#  'house',
#  'see',
#  'it',
#  'زلزله',
#  'sarpol',
#  'zahab',
#  'image',
#  'impact',
#  'day',
#  'these',
#  'aid',
#  'give',
#  'national',
#  'need',
#  'shelter',
#  'how',
#  'order',
#  'solidarity',
#  'home',
#  'soon',
#  'them',
#  'suffer',
#  'who',
#  'action',
#  'which',
#  'can',
#  'may',
#  'any',
#  'rubble',
#  'other',
#  'donate',
#  'down',
#  'homeless',
#  'u',
#  'archaeological',
#  'red',
#  'kurd',
#  'rouhani',
#  'food',
#  'receive',
#  'netanyahu',
#  'ahmadinejad',
#  'turn',
#  'fire',
#  'sleep',
#  'tent']

# %%
lda_2_topics = utils3.train_lda_model(num_topics=2, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(2, lda_2_topics.model)

# %%
lda_3_topics = utils3.train_lda_model(3, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(3, lda_3_topics.model)

# %%
lda_4_topics = utils3.train_lda_model(4, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(4, lda_4_topics.model)

# %%
real_top_words = utils3.get_top_words_lda(2, lda_2_topics.model, num_words=10)

random_topics = [
    random.sample(all_words, 10),
    random.sample(all_words, 10),    
]

print(f"Top words:")
for word_list in real_top_words:
    print(f"    {word_list}")
print(f"Coherence score for the text using calculated topics is: {utils3.compute_coherence_score(real_top_words, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}\n")

print(f"Random words:")
for word_list in random_topics:
    print(f"    {word_list}")
print(f"Coherence score for the text using random topics is: {utils3.compute_coherence_score(random_topics, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}")
# Out:
# Top words:
#     ['in', 'iraq', 'of', 'to', 'from', 'by', 'be', 'help', 'amp', 'for']
#     ['iraq', 'the', 'in', 'to', 'of', 'and', 'after', 'rt', 'be', 'hit']
# Coherence score for the text using calculated topics is: -2.442
#
# Random words:
#     ['here', 'not', 'show', 'heart', 'by', 'halabja', 'iranian', 'kill', 'region', 'help']
#     ['your', 'world', 'recent', 'visit', 'than', 'government', 'halabja', 'moment', 'receive', 'heart']
# Coherence score for the text using random topics is: -19.679

# %%
# Set the number of topics
max_number_of_topics = 10
n_topics_range = range(2, max_number_of_topics + 1)

# Dictionary to save trained models
LDA_models = {}
print(f"Training LDA models from 2 to {max_number_of_topics} topics")

# For number of topics ranging from 2 to max_number_of_topics
for i in n_topics_range:
    # Save model
    LDA_models[i] = utils3.train_lda_model(num_topics=i, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary) # Training all models takes around 2 mins
    print(f"Successfully trained LDA model on {i} topics")
# Out:
# Training LDA models from 2 to 10 topics
# Successfully trained LDA model on 2 topics
# Successfully trained LDA model on 3 topics
# Successfully trained LDA model on 4 topics
# Successfully trained LDA model on 5 topics
# Successfully trained LDA model on 6 topics
# Successfully trained LDA model on 7 topics
# Successfully trained LDA model on 8 topics
# Successfully trained LDA model on 9 topics
# Successfully trained LDA model on 10 topics

# %%
utils3.top_words_plot(LDA_models, max_number_of_topics)
# Out:
# interactive(children=(Dropdown(description='# of topics', options=(2, 3, 4, 5, 6, 7, 8, 9, 10), value=2), Outp…

# %%
# save coherence scores in a list
coherence_scores_lda = [LDA_models[i].coherence_score for i in n_topics_range]

# plot coherence score as a function of number of topics
utils3.plot_coherences_lda(n_topics_range, coherence_scores_lda)

# %%
num_topics = 2

# Select the model from the trained models
lda_model_final = LDA_models[num_topics]

# Plot the top ten words for the selected model again
utils3.plot_top_words_lda(num_topics, lda_model_final.model, num_words=20)

# %%
import seaborn as sns
# import termcolor

# %%
def plot_topic_importance(corpus_bow, data, lda_2_topics, num_topics):
    topics_on_messages = lda_3_topics.model.get_document_topics(corpus_bow, minimum_probability=0.0)

    result = []
    start_date = data['date'].min()  # Minimum date from the DataFrame
    end_date = data['date'].max()  # Maximum date from the DataFrame
    n_days = (end_date - start_date).days
    for delta in range(n_days):
        sum_by_topic = [0] * num_topics
        today = start_date + pd.Timedelta(days=delta)
        tomorrow = start_date + pd.Timedelta(days=delta+1)
        index_range = data.loc[(data['date'] >= today) & (data['date'] < tomorrow)].index
        for k in index_range:
            for i in range(num_topics):
                sum_by_topic[i] += topics_on_messages[k][i][1]
        sum_by_topic = np.array(sum_by_topic)
        sum_by_topic = sum_by_topic / np.sum(sum_by_topic)

        result.append(sum_by_topic)
    result = np.array(result)

    result3 = []
    days_per_tick = 1

    for i in range(n_days):
        for topic in range(num_topics):
            rows = result[i, topic]
            result3.append([int(i / days_per_tick), np.sum(rows), topic])

    result3 = np.array(result3)

    plt.figure(figsize=(15, 5))

    style = [f"Topic {int(x) + 1}" for x in result3[:,2]]
    ax = sns.lineplot(x=result3[:,0]*days_per_tick, y=result3[:,1], hue=style, style=style)
    ax.set(xlabel='Days', ylabel='Topic importance')
    ax.tick_params(labelsize=14)
    ax.set_title(f"Topic importance over time", fontsize=22)
    ax.set_xlabel("Days", fontsize=18)
    ax.set_ylabel("Topic importance", fontsize=18)
    ax.legend(fontsize=14)

    plt.show()

# %%
plot_topic_importance(corpus_bow, df, lda_model_final, num_topics)
