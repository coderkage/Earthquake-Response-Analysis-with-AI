# %% [markdown]
# ## Setup<div class='tocSkip'/>
#
# Install required libraries.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\users\deepp\appdata\roaming\python\python312\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\deepp\appdata\roaming\python\python312\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\deepp\appdata\roaming\python\python312\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\deepp\appdata\roaming\python\python312\site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\deepp\appdata\roaming\python\python312\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\deepp\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer # type: ignore

# %% [markdown]
# # Vader Sentiment Analyser

# %%
analyser  = SentimentIntensityAnalyzer()

# %%
a = "Yesterday I watched Howl's moving castle movie. It was hilarious but a bit boring so I couldn't finish it in one sitting but till now it seems to be a good one."

# %%
analyser.polarity_scores(a)
# Out:
# {'neg': 0.088, 'neu': 0.743, 'pos': 0.169, 'compound': 0.4118}

# %%
b = "This was the best, most awesome movie EVER MADE!!!"

# %%
analyser.polarity_scores(b)
# Out:
# {'neg': 0.0, 'neu': 0.425, 'pos': 0.575, 'compound': 0.8877}

# %%
c = " This was the WORST movie that has ever disgraced the screen."

# %%
analyser.polarity_scores(c)
# Out:
# {'neg': 0.465, 'neu': 0.535, 'pos': 0.0, 'compound': -0.8331}

# %%
import pandas as pd

# %%
df = pd.read_csv('0mexico.csv')
df = df.rename(columns={'tweet_text': 'text'})


df.sample(10)
# Out:
#           tweet_id       date  \
# 225   9.110000e+17  20_9_2017
# 1220  9.140000e+17  29_9_2017
# 1111  9.130000e+17  27_9_2017
# 705   9.120000e+17  23_9_2017
# 212   9.110000e+17  20_9_2017
# 721   9.120000e+17  23_9_2017
# 256   9.110000e+17  20_9_2017
# 1178  9.130000e+17  28_9_2017
# 845   9.120000e+17  24_9_2017
# 789   9.120000e+17  23_9_2017
#
#                                                    text  text_info_conf  \
# 225   RT @NewsChimp_Aww: Marine Dog getting ready fo...          0.6501
# 1220  Christian young people shot, robbed and raped ...          0.6897
# 1111  Lionel Messi posts emotional tribute to Mexico...          1.0000
# 705   RT @theipaper: â€˜Miracleâ€™ baby born in Mexi...          0.5305
# 212   The Dominican president expresses his â€œmost ...          1.0000
# 721   Denver News Another earthquake hits central Me...          0.6689
# 256   Donations open for earthquake victims in Mexic...          1.0000
# 1178  Small consolations from Mexicoâ€™s terribleÂ e...          0.5250
# 845   RT @EnockAnanda: WHY GOD JUDGED MEXICO SEVEREL...          1.0000
# 789   Earthquake #mexico #hero #dogs #dogsonduty #su...          0.7069
#
#       text_human_conf                              text_human
# 225            0.6501  rescue_volunteering_or_donation_effort
# 1220           0.6897              other_relevant_information
# 1111           1.0000                        not_humanitarian
# 705            0.5305                    affected_individuals
# 212            1.0000                        not_humanitarian
# 721            0.6689              other_relevant_information
# 256            1.0000  rescue_volunteering_or_donation_effort
# 1178           0.5250              other_relevant_information
# 845            1.0000                        not_humanitarian
# 789            0.7069                        not_humanitarian

# %%
unique_values = df['text_human'].unique()

print(unique_values)
# Out:
# ['not_humanitarian' 'injured_or_dead_people'
#  'rescue_volunteering_or_donation_effort'
#  'infrastructure_and_utility_damage' 'other_relevant_information'
#  'vehicle_damage' 'missing_or_found_people' 'affected_individuals']

# %%
sentiment_mapping = {
    'not_humanitarian': 'neut',
    'injured_or_dead_people': 'neg',
    'rescue_volunteering_or_donation_effort': 'pos',
    'infrastructure_and_utility_damage': 'neg',
    'other_relevant_information': 'neut',
    'vehicle_damage': 'neg',
    'missing_or_found_people': 'neg',
    'affected_individuals': 'neut'
}

# %%
# Assign sentiments based on the mapping
df['sentiment'] = df['text_human'].map(sentiment_mapping)

# If there are any values in 'text_human' that are not in the mapping, you may want to handle them separately
# For example, assign them a default sentiment like 'neut'
df['sentiment'].fillna('neut', inplace=True)

# %%
# # Assigning a new [1,0] target class label based on the product rating
# df['sentiment'] = 0
# df.loc[df['overall'] > 3, 'sentiment'] = "pos"
# df.loc[df['overall'] < 3, 'sentiment'] = "neg"

# # Removing unecessary columns to keep the data simple 
# df.drop(columns=[
#     'reviewTime', 'unixReviewTime', 'reviewerID', 'summary', 'asin', 'overall', 'verified'],
#         inplace=True)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# neut    822
# pos     311
# neg     247
# Name: count, dtype: int64

# %%
analyser.polarity_scores(df.iloc[0]['text'])
# Out:
# {'neg': 0.148, 'neu': 0.71, 'pos': 0.142, 'compound': -0.0258}

# %%
df.iloc[0]['text']
# Out:
# 'RT @FCBarcelona: Our solidarity with the victims of the earthquake in Mexico https://t.co/4R52KTn7CB'

# %%
df['scores'] = df['text'].apply(lambda review: analyser.polarity_scores(review))

# %%
df.sample(10)
# Out:
#           tweet_id        date  \
# 468   9.110000e+17   21_9_2017
# 477   9.110000e+17   21_9_2017
# 807   9.120000e+17   24_9_2017
# 284   9.110000e+17   20_9_2017
# 335   9.110000e+17   20_9_2017
# 1307  9.150000e+17  01_10_2017
# 1288  9.140000e+17  01_10_2017
# 674   9.120000e+17   23_9_2017
# 140   9.110000e+17   20_9_2017
# 823   9.120000e+17   24_9_2017
#
#                                                    text  text_info_conf  \
# 468   The #LAGalaxy donned black armbands during #AT...          1.0000
# 477   Aoyin candle factory Pray for the earthquake i...          1.0000
# 807   Moment panicked residents flee as Mexico City ...          0.6765
# 284   Sept. 20, 2017- ALL of today's Prophecy News o...          1.0000
# 335   Skype makes calls free to affected regions of ...          1.0000
# 1307  Today in Mexicoâ€™s Magic Realism... á¼Ÿ2á¼ŸD ...          1.0000
# 1288  .@salmahayek thanks 'soul-sister' #PenelopeCru...          1.0000
# 674   #ArizonaMugshots azfamily: NEW: A 6.2 magnitud...          0.6714
# 140   Earthquake kills dozens in central Mexico http...          0.6657
# 823   Badass Rescue Dog Who Has Rescued 52 Lives Is ...          1.0000
#
#       text_human_conf                              text_human sentiment  \
# 468            1.0000                        not_humanitarian      neut
# 477            1.0000                        not_humanitarian      neut
# 807            0.6765              other_relevant_information      neut
# 284            1.0000                        not_humanitarian      neut
# 335            1.0000                        not_humanitarian      neut
# 1307           1.0000                        not_humanitarian      neut
# 1288           1.0000                        not_humanitarian      neut
# 674            0.6714              other_relevant_information      neut
# 140            0.6657                  injured_or_dead_people       neg
# 823            1.0000  rescue_volunteering_or_donation_effort       pos
#
#                                                  scores
# 468   {'neg': 0.236, 'neu': 0.622, 'pos': 0.142, 'co...
# 477   {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'comp...
# 807   {'neg': 0.16, 'neu': 0.691, 'pos': 0.149, 'com...
# 284   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 335   {'neg': 0.095, 'neu': 0.71, 'pos': 0.195, 'com...
# 1307  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1288  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...
# 674   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 140   {'neg': 0.28, 'neu': 0.72, 'pos': 0.0, 'compou...
# 823   {'neg': 0.15, 'neu': 0.563, 'pos': 0.286, 'com...

# %%
df['compound'] = df['scores'].apply(lambda d: d['compound'])

# %%
df.sample(10)
# Out:
#          tweet_id       date  \
# 496  9.110000e+17  21_9_2017
# 144  9.110000e+17  20_9_2017
# 438  9.110000e+17  21_9_2017
# 459  9.110000e+17  21_9_2017
# 722  9.120000e+17  23_9_2017
# 131  9.110000e+17  20_9_2017
# 416  9.110000e+17  21_9_2017
# 22   9.110000e+17  20_9_2017
# 704  9.120000e+17  23_9_2017
# 659  9.120000e+17  23_9_2017
#
#                                                   text  text_info_conf  \
# 496  RT @KCTV5: Royals' mascot was in Mexico when e...          0.6708
# 144  RT @mattdpearce: .@katelinthicum on the scene ...          1.0000
# 438  RT @SirZaw3: Sky chain too bright in Mexico be...          1.0000
# 459  Man from KC in Mexico City captured these phot...          0.6312
# 722  RT @Newsweek: NASA-produced maps may help spee...          0.6771
# 131  7.1 Magnitude Terremoto Earthquake Mexico 19/0...          1.0000
# 416  S A F E B O Y E S ready to look for people aft...          0.6407
# 22   Foreign Office issues warning following Mexico...          1.0000
# 704  Another earthquake rocks southern Mexico https...          0.7492
# 659  RT @ericgeller: I love dogs so much https://t....          1.0000
#
#      text_human_conf                              text_human sentiment  \
# 496           0.6708                        not_humanitarian      neut
# 144           1.0000                        not_humanitarian      neut
# 438           1.0000                        not_humanitarian      neut
# 459           0.6312                  injured_or_dead_people       neg
# 722           0.6771              other_relevant_information      neut
# 131           1.0000              other_relevant_information      neut
# 416           0.6407  rescue_volunteering_or_donation_effort       pos
# 22            1.0000              other_relevant_information      neut
# 704           0.7492              other_relevant_information      neut
# 659           1.0000                        not_humanitarian      neut
#
#                                                 scores  compound
# 496  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 144  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 438  {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'comp...    0.4404
# 459  {'neg': 0.321, 'neu': 0.679, 'pos': 0.0, 'comp...   -0.7964
# 722  {'neg': 0.0, 'neu': 0.828, 'pos': 0.172, 'comp...    0.4019
# 131  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 416  {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'comp...    0.3612
# 22   {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...   -0.3400
# 704  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 659  {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'comp...    0.6369

# %%
df['comp_score'] = df['compound'].apply(lambda score: 'pos' if score > 0.5 else ('neg' if score < -0.6 else 'neut'))

# %%
df.sample(10)
# Out:
#           tweet_id        date  \
# 537   9.110000e+17   21_9_2017
# 76    9.110000e+17   20_9_2017
# 696   9.120000e+17   23_9_2017
# 462   9.110000e+17   21_9_2017
# 795   9.120000e+17   23_9_2017
# 269   9.110000e+17   20_9_2017
# 1309  9.150000e+17  02_10_2017
# 545   9.110000e+17   21_9_2017
# 411   9.110000e+17   21_9_2017
# 1048  9.120000e+17   25_9_2017
#
#                                                    text  text_info_conf  \
# 537   Mexico 7.1 Earthquake: 'Absolutely Horrific Im...          1.0000
# 76    RT @RSGovUK: Our deepest condolences to #Mexic...          0.5112
# 696   RT @oxfammexico: Earthquake response activated...          0.6902
# 462   Meet frida, helping by looking for trapped peo...          1.0000
# 795   In Jojutla, Mexico, earthquake left hundreds h...          0.5067
# 269   RT @CGTNOfficial: #UPDATE Death toll rises to ...          1.0000
# 1309  Book : "Clash Between Two Kingdoms" By Angela ...          1.0000
# 545   https://t.co/mGqZzz1Mv8 Rescuers in frantic se...          0.6631
# 411   Boy recalls escape from Mexico City school aft...          0.6860
# 1048  After earthquake, Mexico holds out hope for th...          0.6726
#
#       text_human_conf                              text_human sentiment  \
# 537            1.0000              other_relevant_information      neut
# 76             0.5112                  injured_or_dead_people       neg
# 696            0.6902              other_relevant_information      neut
# 462            1.0000  rescue_volunteering_or_donation_effort       pos
# 795            0.5067                    affected_individuals      neut
# 269            1.0000                  injured_or_dead_people       neg
# 1309           1.0000                        not_humanitarian      neut
# 545            0.6631  rescue_volunteering_or_donation_effort       pos
# 411            0.6860              other_relevant_information      neut
# 1048           0.6726              other_relevant_information      neut
#
#                                                  scores  compound comp_score
# 537   {'neg': 0.319, 'neu': 0.681, 'pos': 0.0, 'comp...   -0.6901        neg
# 76    {'neg': 0.101, 'neu': 0.57, 'pos': 0.329, 'com...    0.7345        pos
# 696   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000       neut
# 462   {'neg': 0.173, 'neu': 0.714, 'pos': 0.112, 'co...   -0.2960       neut
# 795   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000       neut
# 269   {'neg': 0.299, 'neu': 0.701, 'pos': 0.0, 'comp...   -0.7506        neg
# 1309  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'comp...    0.5106        pos
# 545   {'neg': 0.244, 'neu': 0.756, 'pos': 0.0, 'comp...   -0.4404       neut
# 411   {'neg': 0.0, 'neu': 0.855, 'pos': 0.145, 'comp...    0.1779       neut
# 1048  {'neg': 0.167, 'neu': 0.69, 'pos': 0.143, 'com...   -0.1280       neut

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print(accuracy_score(df['sentiment'],df['comp_score']))
# Out:
# 0.5992753623188406

# %%
print(classification_report(df['sentiment'],df['comp_score']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.54      0.31      0.40       247
#         neut       0.63      0.81      0.71       822
#          pos       0.45      0.27      0.34       311
#
#     accuracy                           0.60      1380
#    macro avg       0.54      0.46      0.48      1380
# weighted avg       0.58      0.60      0.57      1380

# %%
print(confusion_matrix(df['sentiment'],df['comp_score']))
# Out:
# [[ 77 167   3]
#  [ 58 665  99]
#  [  7 219  85]]

# %% [markdown]
# # Naive Bayes Classifier

# %%
import numpy as np
import pandas as pd
import json, nltk
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('0mexico.csv')
df = df.rename(columns={'tweet_text': 'text'})

df.sample(20)
# Out:
#           tweet_id       date  \
# 52    9.110000e+17  20_9_2017
# 909   9.120000e+17  24_9_2017
# 845   9.120000e+17  24_9_2017
# 893   9.120000e+17  24_9_2017
# 1182  9.130000e+17  28_9_2017
# 683   9.120000e+17  23_9_2017
# 409   9.110000e+17  21_9_2017
# 827   9.120000e+17  24_9_2017
# 132   9.110000e+17  20_9_2017
# 735   9.120000e+17  23_9_2017
# 46    9.110000e+17  20_9_2017
# 459   9.110000e+17  21_9_2017
# 421   9.110000e+17  21_9_2017
# 482   9.110000e+17  21_9_2017
# 531   9.110000e+17  21_9_2017
# 294   9.110000e+17  20_9_2017
# 662   9.120000e+17  23_9_2017
# 511   9.110000e+17  21_9_2017
# 1214  9.140000e+17  29_9_2017
# 817   9.120000e+17  24_9_2017
#
#                                                    text  text_info_conf  \
# 52    In a collapsed Mexico school, a community digs...          0.7179
# 909   Now at PHX airport. Preparing to load plane to...          0.6534
# 845   RT @EnockAnanda: WHY GOD JUDGED MEXICO SEVEREL...          1.0000
# 893   Another Earthquake in Mexico; Revised Travel W...          0.6804
# 1182  Mexico hit by over 5,400 aftershocks after Sep...          0.6541
# 683   RT @mashable: Beer company fills its cans with...          0.5126
# 409   RT @CheetahNews: Updates From Mexico'sâ€‹ Magn...          1.0000
# 827   15 horrifying photos that reveal how bad the #...          0.6828
# 132   âš ï¸ EARTHQUAKE IN MEXICO á¼Ÿ2á¼ŸD PLEASE RT...          1.0000
# 735   @LiamPayne Mexico needs your help now. This co...          1.0000
# 46    RT @ajplus: Mexico City sees major damages to ...          1.0000
# 459   Man from KC in Mexico City captured these phot...          0.6312
# 421   This image always messed me up. https://t.co/8...          1.0000
# 482   Earthquake in Mexico rocks PH Embassy, no Fili...          0.7791
# 531   Those suffering from the #MexicoQuake need you...          0.6839
# 294   Thank you for all your help American friends!!...          1.0000
# 662   Mexico Far Ahead Of California With Earthquake...          1.0000
# 511   Regular people turn anonymous heroes after Mex...          1.0000
# 1214  #Chiapas and #Puebla, #mexicoearthquake : Chai...          0.7069
# 817   Breaking News: Third Large Quake in just over ...          1.0000
#
#       text_human_conf                              text_human
# 52             0.7179       infrastructure_and_utility_damage
# 909            0.6534                        not_humanitarian
# 845            1.0000                        not_humanitarian
# 893            0.6804                        not_humanitarian
# 1182           0.6541              other_relevant_information
# 683            0.5126  rescue_volunteering_or_donation_effort
# 409            1.0000              other_relevant_information
# 827            0.6828       infrastructure_and_utility_damage
# 132            1.0000                        not_humanitarian
# 735            1.0000  rescue_volunteering_or_donation_effort
# 46             1.0000       infrastructure_and_utility_damage
# 459            0.6312                  injured_or_dead_people
# 421            1.0000                        not_humanitarian
# 482            0.7791              other_relevant_information
# 531            0.6839  rescue_volunteering_or_donation_effort
# 294            1.0000                        not_humanitarian
# 662            1.0000              other_relevant_information
# 511            1.0000  rescue_volunteering_or_donation_effort
# 1214           0.7069                        not_humanitarian
# 817            1.0000              other_relevant_information

# %%
with open('./contractions.json', 'r') as f:
    contractions_dict = json.load(f)
contractions = contractions_dict['contractions']

# %%
# Assign sentiments based on the mapping
df['sentiment'] = df['text_human'].map(sentiment_mapping)

# If there are any values in 'text_human' that are not in the mapping, you may want to handle them separately
# For example, assign them a default sentiment like 'neut'
df['sentiment'].fillna('neut', inplace=True)

# %%
df.sample(10)
# Out:
#           tweet_id        date  \
# 1334  9.150000e+17  02_10_2017
# 58    9.110000e+17   20_9_2017
# 452   9.110000e+17   21_9_2017
# 1092  9.120000e+17   26_9_2017
# 268   9.110000e+17   20_9_2017
# 34    9.110000e+17   20_9_2017
# 49    9.110000e+17   20_9_2017
# 1043  9.120000e+17   25_9_2017
# 766   9.120000e+17   23_9_2017
# 679   9.120000e+17   23_9_2017
#
#                                                    text  text_info_conf  \
# 1334  #mexico 7.1 about earthquake. More explantion ...          1.0000
# 58    RT @rmota: Stay Strong #puertorico and #mexico...          1.0000
# 452   It makes me ache: Milwaukee man collects suppl...          1.0000
# 1092  Post-Quake Threats and how to Avoid Them https...          1.0000
# 268   #Mexico Further updates and advice to British ...          0.7165
# 34    RT @CNN: Photos show a magnitude-7.1 earthquak...          0.6842
# 49    Mexico earthquake building collapse: Rescue ca...          0.8331
# 1043  @jk_rowling I don't have otters but here's the...          1.0000
# 766   RT @thejoshuablog: Via @RawStory: Another powe...          1.0000
# 679   RT @etalkCTV: .@ShawnMendes donates $100K to M...          1.0000
#
#       text_human_conf                              text_human sentiment
# 1334           1.0000              other_relevant_information      neut
# 58             1.0000                        not_humanitarian      neut
# 452            1.0000  rescue_volunteering_or_donation_effort       pos
# 1092           1.0000              other_relevant_information      neut
# 268            0.7165                        not_humanitarian      neut
# 34             0.6842       infrastructure_and_utility_damage       neg
# 49             0.8331       infrastructure_and_utility_damage       neg
# 1043           1.0000  rescue_volunteering_or_donation_effort       pos
# 766            1.0000              other_relevant_information      neut
# 679            1.0000  rescue_volunteering_or_donation_effort       pos

# %%
review_data = df.columns.values[2]
sentiment = df.columns.values[6]
review_data, sentiment
# Out:
# ('text', 'sentiment')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1380 entries, 0 to 1379
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         1380 non-null   float64
#  1   date             1380 non-null   object
#  2   text             1380 non-null   object
#  3   text_info_conf   1380 non-null   float64
#  4   text_human_conf  1380 non-null   float64
#  5   text_human       1380 non-null   object
#  6   sentiment        1380 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 75.6+ KB

# %%
def emoji(review_data):
    # Smile -- :), : ), :-), (:, ( :, (-:, :') , :O
    review_data = re.sub(r'(:\s?\)|:-\)|\(\s?:|\(-:|:\'\)|:O)', ' positiveemoji ', review_data)
    # Laugh -- :D, : D, :-D, xD, x-D, XD, X-D
    review_data = re.sub(r'(:\s?D|:-D|x-?D|X-?D)', ' positiveemoji ', review_data)
    # Love -- <3, :*
    review_data = re.sub(r'(<3|:\*)', ' positiveemoji ', review_data)
    # Wink -- ;-), ;), ;-D, ;D, (;,  (-; , @-)
    review_data = re.sub(r'(;-?\)|;-?D|\(-?;|@-\))', ' positiveemoji ', review_data)
    # Sad -- :-(, : (, :(, ):, )-:, :-/ , :-|
    review_data = re.sub(r'(:\s?\(|:-\(|\)\s?:|\)-:|:-/|:-\|)', ' negetiveemoji ', review_data)
    # Cry -- :,(, :'(, :"(
    review_data = re.sub(r'(:,\(|:\'\(|:"\()', ' negetiveemoji ', review_data)
    return review_data

# %%
import re

def process_review_data(review_data):
    review_data = review_data.lower()                                             # Lowercases the string
    review_data = re.sub(r'@[^\s]+', '', review_data)                             # Removes usernames
    review_data = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+))', ' ', review_data)   # Remove URLs
    review_data = re.sub(r"\d+", " ", str(review_data))                           # Removes all digits
    review_data = re.sub(r'&quot;', " ", review_data)                             # Remove (&quot;) 
    review_data = emoji(review_data)                                              # Replaces Emojis
    review_data = re.sub(r"\b[a-zA-Z]\b", "", str(review_data))                   # Removes all single characters
    for word in review_data.split():
        if word.lower() in contractions:
            review_data = review_data.replace(word, contractions[word.lower()])   # Replaces contractions
    review_data = re.sub(r"[^\w\s]", " ", str(review_data))                       # Removes all punctuations
    review_data = re.sub(r'(.)\1+', r'\1\1', review_data)                         # Convert more than 2 letter repetitions to 2
    review_data = re.sub(r"\s+", " ", str(review_data))                           # Replaces double spaces with single space    
    return review_data

# %%
df['processed_text'] = np.vectorize(process_review_data)(df[review_data])

# %%
df.sample(10)
# Out:
#           tweet_id       date  \
# 761   9.120000e+17  23_9_2017
# 524   9.110000e+17  21_9_2017
# 1050  9.120000e+17  25_9_2017
# 370   9.110000e+17  20_9_2017
# 152   9.110000e+17  20_9_2017
# 742   9.120000e+17  23_9_2017
# 946   9.120000e+17  24_9_2017
# 475   9.110000e+17  21_9_2017
# 836   9.120000e+17  24_9_2017
# 1194  9.140000e+17  28_9_2017
#
#                                                    text  text_info_conf  \
# 761   New 6.2-magnitude earthquake interrupts rescue...          0.6669
# 524   #Japan helping #Mexicoá½‰A #earthquake https:/...          0.7960
# 1050  Mexico Earthquake: Citizens Become Heroes Sear...          1.0000
# 370   Walmart Foundation Announces $565,000 towards ...          1.0000
# 152   Volunteers form giant human chain to rescue vi...          1.0000
# 742   á½™0 Hands of Hope á½™0 This lady is doing ama...          0.6438
# 946   In central Mexico, earthquake survivors face e...          0.6410
# 475   Very much disheartened @mexico earthquake http...          1.0000
# 836   A new, 6.1 earthquake sows panic in Mexico Cit...          0.6221
# 1194  EXCLUSIVE: Collapsed school in Mexico earthqua...          1.0000
#
#       text_human_conf                              text_human sentiment  \
# 761            0.6669  rescue_volunteering_or_donation_effort       pos
# 524            0.7960  rescue_volunteering_or_donation_effort       pos
# 1050           1.0000  rescue_volunteering_or_donation_effort       pos
# 370            1.0000  rescue_volunteering_or_donation_effort       pos
# 152            1.0000  rescue_volunteering_or_donation_effort       pos
# 742            0.6438                        not_humanitarian      neut
# 946            0.6410                    affected_individuals      neut
# 475            1.0000              other_relevant_information      neut
# 836            0.6221  rescue_volunteering_or_donation_effort       pos
# 1194           1.0000       infrastructure_and_utility_damage       neg
#
#                                          processed_text
# 761   new magnitude earthquake interrupts rescue eff...
# 524                  japan helping mexicoá½ earthquake
# 1050  mexico earthquake citizens become heroes searc...
# 370   walmart foundation announces towards mexico ea...
# 152   volunteers form giant human chain to rescue vi...
# 742   á½ hands of hope á½ this lady is doing amazing...
# 946   in central mexico earthquake survivors face ex...
# 475                  very much disheartened earthquake
# 836    new earthquake sows panic in mexico city forc...
# 1194  exclusive collapsed school in mexico earthquak...

# %%
sentiments = ['pos', 'neg', 'neut']

counts = [df['sentiment'].value_counts().get(sentiment, 0) for sentiment in sentiments]

# Define colors for the pie chart
colors = ['green', 'red', 'yellow']

# Plot the pie chart
plt.pie(counts, labels=sentiments, colors=colors, startangle=180, shadow=False, autopct='%1.1f%%')
plt.title('Sentiment Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
positive_words =' '.join([text for text in df['processed_text'][df[sentiment] == 'pos']])
wordcloud = WordCloud(width=800, height=500, random_state=21,
            max_font_size=110,background_color="rgba(255, 255, 255, 0)"
            , mode="RGBA").generate(positive_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Used Positive Words")
plt.savefig('./positive_words.png')
plt.show()

# %%
negetive_words =' '.join([text for text in df['processed_text'][df[sentiment] == 'neg']])
wordcloud = WordCloud(width=800, height=500, random_state=21, 
            max_font_size=110,background_color="rgba(255, 255, 255, 0)"
            , mode="RGBA").generate(negetive_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Used Negetive Words")
plt.savefig('./negetive_words.png')
plt.show()

# %%
neutral_words =' '.join([text for text in df['processed_text'][df[sentiment] == 'neut']])
wordcloud = WordCloud(width=800, height=500, random_state=21, 
            max_font_size=110,background_color="rgba(255, 255, 255, 0)"
            , mode="RGBA").generate(neutral_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Used Neutral Words")
plt.savefig('./neutral_words.png')
plt.show()

# %%
 from sklearn.feature_extraction.text import CountVectorizer

 count_vectorizer = CountVectorizer(ngram_range=(1,2))    # Unigram and Bigram
 final_vectorized_data = count_vectorizer.fit_transform(df['processed_text'])  
 final_vectorized_data
# Out:
# <1380x10898 sparse matrix of type '<class 'numpy.int64'>'
# 	with 27862 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 

tf_idf_vectorizer = TfidfVectorizer(use_idf=True,ngram_range=(1,3))
final_vectorized_data = tf_idf_vectorizer.fit_transform(df['processed_text'])

final_vectorized_data
# Out:
# <1380x20227 sparse matrix of type '<class 'numpy.float64'>'
# 	with 39895 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final_vectorized_data, df[sentiment],
                                                    test_size=0.2, random_state=69)

# %%
print("X_train_shape : ",X_train.shape)
print("X_test_shape : ",X_test.shape)
print("y_train_shape : ",y_train.shape)
print("y_test_shape : ",y_test.shape)
# Out:
# X_train_shape :  (1104, 20227)
# X_test_shape :  (276, 20227)
# y_train_shape :  (1104,)
# y_test_shape :  (276,)

# %%
from sklearn.naive_bayes import MultinomialNB  # Naive Bayes Classifier

model_naive = MultinomialNB().fit(X_train, y_train) 
predicted_naive = model_naive.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

plt.figure(dpi=600)
mat = confusion_matrix(y_test, predicted_naive)
sns.heatmap(mat.T, annot=True, fmt='d', cbar=True)

plt.title('Confusion Matrix for Naive Bayes')
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.savefig("./confusion_matrix.png")
plt.show()

# %%
from sklearn.metrics import accuracy_score

score_naive = accuracy_score(predicted_naive, y_test)
print("Accuracy with Naive-bayes: ",score_naive)
# Out:
# Accuracy with Naive-bayes:  0.6268115942028986

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predicted_naive))
# Out:
#               precision    recall  f1-score   support
#
#          neg       1.00      0.19      0.32        58
#         neut       0.61      0.99      0.75       158
#          pos       0.83      0.08      0.15        60
#
#     accuracy                           0.63       276
#    macro avg       0.81      0.42      0.41       276
# weighted avg       0.74      0.63      0.53       276

# %%
# from sklearn.metrics import roc_curve
# from sklearn.metrics import auc

# # calculate the fpr and tpr for all thresholds of the classification
# probs = model_naive.predict_proba(X_test)
# preds = probs[:,1]
# fpr, tpr, threshold = roc_curve(y_test, preds)
# roc_auc = auc(fpr, tpr)
# plt.figure(dpi=600)
# plt.title('Receiver Operating Characteristic')
# plt.plot(fpr, tpr, 'b', label = 'AUC = %0.5f' % roc_auc)
# plt.legend(loc = 'lower right')
# plt.plot([0, 1], [0, 1],'r--')
# plt.ylabel('True Positive Rate', color='g')
# plt.xlabel('False Positive Rate', color='r')
# plt.savefig("./ROC_curve.png")
# plt.show()
