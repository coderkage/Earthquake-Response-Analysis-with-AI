# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import utils1
import utils2
import utils3

# %%
df = pd.read_csv("preprocessed_0f_mexico.csv", low_memory=False)

# %%
df['processed_text'] = df['processed_text'].astype(str)

# %%
df.head()
# Out:
#                                                 text       date  \
# 0  RT @FCBarcelona: Our solidarity with the victi...  20_9_2017
# 1  Mexico earthquake: Many children killed at pri...  20_9_2017
# 2  Obamaâ€™s Response To The Earthquake In #Mexic...  20_9_2017
# 3  RT @AmichaiStein1: #BREAKING: Israel search &a...  20_9_2017
# 4  RT @AmichaiStein1: #BREAKING: Israel search &a...  20_9_2017
#
#                                  category  \
# 0                        not_humanitarian
# 1                  injured_or_dead_people
# 2                        not_humanitarian
# 3  rescue_volunteering_or_donation_effort
# 4  rescue_volunteering_or_donation_effort
#
#                                       processed_text
# 0  rt our solidarity with the victims of the eart...
# 1  mexico earthquake many children killed at prim...
# 2  obamaâ response to the earthquake in mexicocit...
# 3  rt breaking israel search amp rescue mission h...
# 4  rt breaking israel search amp rescue mission h...

# %%
df['date'] = pd.to_datetime(df['date'],format='%d_%m_%Y')

# %%
df.isna().sum()
# Out:
# text              0
# date              0
# category          0
# processed_text    0
# dtype: int64

# %%
all_text = ' '.join(df['text'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import gensim
import nltk
nltk.download('averaged_perceptron_tagger')

pd.options.mode.chained_assignment = None
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
def process_text(text):
    # Step 1: Tokenize and get POS tags
    tokens = nltk.pos_tag(word_tokenize(text))
    # print(colored("Step 1: Tokenize\n", "blue"), "{}\n".format([w[0] for w in tokens]))
    
    # Step 2: Lemmatize each word 
    tokens = [lemmatizer.lemmatize(w[0], utils2.pos_tag_convert(w[1])) for w in tokens]
    # print(colored("Step 2: Lemmatize\n", "blue"), "{}\n".format(tokens))
    
    return tokens

def process_random_message(df):
    # Apply process_text function to each entry in the processed_text column
    df['tokens'] = df['processed_text'].apply(process_text)
    return df

# Process all entries in the processed_text column and add the tokens column in df
df = process_random_message(df)
df
# Out:
#                                                    text       date  \
# 0     RT @FCBarcelona: Our solidarity with the victi... 2017-09-20
# 1     Mexico earthquake: Many children killed at pri... 2017-09-20
# 2     Obamaâ€™s Response To The Earthquake In #Mexic... 2017-09-20
# 3     RT @AmichaiStein1: #BREAKING: Israel search &a... 2017-09-20
# 4     RT @AmichaiStein1: #BREAKING: Israel search &a... 2017-09-20
# ...                                                 ...        ...
# 1375  Carlos santana donates $100k to mexico earthqu... 2017-10-06
# 1376  Seth troxler donates 10k to earthquake relief ... 2017-10-06
# 1377  Entercom/San Francisco Stations Raise Funds Fo... 2017-10-06
# 1378  Mexico Earthquakes | International Medical Cor... 2017-10-06
# 1379  Napa school employee Valentin Fuentes Villanue... 2017-10-06
#
#                                     category  \
# 0                           not_humanitarian
# 1                     injured_or_dead_people
# 2                           not_humanitarian
# 3     rescue_volunteering_or_donation_effort
# 4     rescue_volunteering_or_donation_effort
# ...                                      ...
# 1375  rescue_volunteering_or_donation_effort
# 1376  rescue_volunteering_or_donation_effort
# 1377  rescue_volunteering_or_donation_effort
# 1378              other_relevant_information
# 1379                  injured_or_dead_people
#
#                                          processed_text  \
# 0     rt our solidarity with the victims of the eart...
# 1     mexico earthquake many children killed at prim...
# 2     obamaâ response to the earthquake in mexicocit...
# 3     rt breaking israel search amp rescue mission h...
# 4     rt breaking israel search amp rescue mission h...
# ...                                                 ...
# 1375  carlos santana donates to mexico earthquake re...
# 1376  seth troxler donates to earthquake relief effo...
# 1377  entercom san francisco stations raise funds fo...
# 1378    mexico earthquakes international medical corps
# 1379  napa school employee valentin fuentes villanue...
#
#                                                  tokens
# 0     [rt, our, solidarity, with, the, victim, of, t...
# 1     [mexico, earthquake, many, child, kill, at, pr...
# 2     [obamaâ, response, to, the, earthquake, in, me...
# 3     [rt, break, israel, search, amp, rescue, missi...
# 4     [rt, break, israel, search, amp, rescue, missi...
# ...                                                 ...
# 1375  [carlos, santana, donate, to, mexico, earthqua...
# 1376  [seth, troxler, donate, to, earthquake, relief...
# 1377  [entercom, san, francisco, station, raise, fun...
# 1378  [mexico, earthquake, international, medical, c...
# 1379  [napa, school, employee, valentin, fuentes, vi...
#
# [1380 rows x 5 columns]

# %%
# Count number of words and save as a column
df["num_words"] = df.processed_text.apply(lambda x: len(x.split(" ")))

# Count number of tokens and save as a column
df["num_tokens"] = df.tokens.apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                                 text       date  \
# 0  RT @FCBarcelona: Our solidarity with the victi... 2017-09-20
# 1  Mexico earthquake: Many children killed at pri... 2017-09-20
# 2  Obamaâ€™s Response To The Earthquake In #Mexic... 2017-09-20
# 3  RT @AmichaiStein1: #BREAKING: Israel search &a... 2017-09-20
# 4  RT @AmichaiStein1: #BREAKING: Israel search &a... 2017-09-20
#
#                                  category  \
# 0                        not_humanitarian
# 1                  injured_or_dead_people
# 2                        not_humanitarian
# 3  rescue_volunteering_or_donation_effort
# 4  rescue_volunteering_or_donation_effort
#
#                                       processed_text  \
# 0  rt our solidarity with the victims of the eart...
# 1  mexico earthquake many children killed at prim...
# 2  obamaâ response to the earthquake in mexicocit...
# 3  rt breaking israel search amp rescue mission h...
# 4  rt breaking israel search amp rescue mission h...
#
#                                               tokens  num_words  num_tokens
# 0  [rt, our, solidarity, with, the, victim, of, t...         12          11
# 1  [mexico, earthquake, many, child, kill, at, pr...          9           8
# 2  [obamaâ, response, to, the, earthquake, in, me...         13          12
# 3  [rt, break, israel, search, amp, rescue, missi...         13          12
# 4  [rt, break, israel, search, amp, rescue, missi...         13          12

# %%
# All of the messages in the dataset
corpus = df.tokens

# Create the Dictionary
corpus_dictionary = gensim.corpora.Dictionary(corpus)

print(colored("Before filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")

# Filter for words that occur more than 5 times overall
corpus_dictionary.filter_extremes(no_below=5)

# Create bag of words out of the full corpus
corpus_bow = [corpus_dictionary.doc2bow(doc) for doc in corpus]

print(colored("After filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")
# Out:
# Before filter:  Dictionary contains a total of 2614 unique words
# After filter:  Dictionary contains a total of 423 unique words

# %%
# Convert bag of words back to text format
corpus_text = [[corpus_dictionary[word_id] for word_id, freq in doc] for doc in corpus_bow]

# Flatten the list of lists
corpus_text_flat = [word for sublist in corpus_text for word in sublist]

# Join the words into a single string
corpus_text_combined = ' '.join(corpus_text_flat)

# Generate word cloud
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(corpus_text_combined)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import random
import gensim
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
corpus
# Out:
# 0       [rt, our, solidarity, with, the, victim, of, t...
# 1       [mexico, earthquake, many, child, kill, at, pr...
# 2       [obamaâ, response, to, the, earthquake, in, me...
# 3       [rt, break, israel, search, amp, rescue, missi...
# 4       [rt, break, israel, search, amp, rescue, missi...
#                               ...
# 1375    [carlos, santana, donate, to, mexico, earthqua...
# 1376    [seth, troxler, donate, to, earthquake, relief...
# 1377    [entercom, san, francisco, station, raise, fun...
# 1378    [mexico, earthquake, international, medical, c...
# 1379    [napa, school, employee, valentin, fuentes, vi...
# Name: tokens, Length: 1380, dtype: object

# %%
all_words = list(corpus_dictionary.values())

print(f"Dictionary contains a total of {len(all_words)} unique words")
# Out:
# Dictionary contains a total of 423 unique words

# %%
all_words
# Out:
# ['in',
#  'of',
#  'our',
#  'rt',
#  'the',
#  'victim',
#  'with',
#  'at',
#  'child',
#  'kill',
#  'many',
#  'school',
#  'be',
#  'mexicocity',
#  'president',
#  'real',
#  'response',
#  'to',
#  'what',
#  'after',
#  'amp',
#  'break',
#  'head',
#  'israel',
#  'mission',
#  'rescue',
#  'search',
#  'an',
#  'country',
#  'die',
#  'have',
#  'hit',
#  'include',
#  'least',
#  'news',
#  'people',
#  'building',
#  'cause',
#  'city',
#  'deadly',
#  'shake',
#  'all',
#  'for',
#  'from',
#  'pray',
#  'suffer',
#  'we',
#  'who',
#  'central',
#  'death',
#  'far',
#  'fuerzamexico',
#  'magnitude',
#  'prayformexico',
#  'so',
#  'á½',
#  'a',
#  'dead',
#  'mexicoâ',
#  'strong',
#  'airport',
#  'today',
#  'around',
#  'damage',
#  'via',
#  'more',
#  'negetiveemoji',
#  'rock',
#  'than',
#  'toll',
#  'big',
#  'send',
#  'and',
#  'offer',
#  'those',
#  'by',
#  'devastate',
#  'image',
#  'can',
#  'go',
#  'on',
#  'crew',
#  'survivor',
#  'top',
#  'rescuer',
#  'rubble',
#  'out',
#  'prayer',
#  'thought',
#  'follow',
#  'late',
#  'tragedy',
#  'video',
#  'donation',
#  'mx',
#  'relief',
#  'topos',
#  'powerful',
#  'rise',
#  'topples',
#  'affect',
#  'million',
#  'ï',
#  'help',
#  'race',
#  'drone',
#  'footage',
#  'show',
#  'this',
#  'sismo',
#  'hour',
#  'just',
#  'new',
#  'collapse',
#  'during',
#  'watch',
#  'update',
#  'destruction',
#  'photo',
#  'km',
#  'usgs',
#  'â',
#  'condolence',
#  'my',
#  'where',
#  'donate',
#  'horror',
#  'major',
#  'see',
#  'world',
#  'find',
#  'kid',
#  'pull',
#  'amid',
#  'hand',
#  'huge',
#  'there',
#  'collapsed',
#  'community',
#  'dig',
#  'life',
#  'sign',
#  'socialmedia',
#  'his',
#  'trump',
#  'fan',
#  'mendes',
#  'mexicocityearthquake',
#  'safety',
#  'shawn',
#  'another',
#  'here',
#  'how',
#  'puertorico',
#  'stay',
#  'hundred',
#  'quake',
#  'strike',
#  'end',
#  'yesterday',
#  'again',
#  'day',
#  'home',
#  'september',
#  'emergency',
#  'second',
#  'god',
#  'lose',
#  'your',
#  'continue',
#  'tuesday',
#  'work',
#  'love',
#  'aid',
#  'off',
#  'take',
#  'think',
#  'about',
#  'live',
#  'local',
#  'some',
#  'under',
#  'one',
#  'their',
#  'everyone',
#  'cristiano',
#  'disaster',
#  'ronaldo',
#  'tribute',
#  'miss',
#  'jojutla',
#  'dog',
#  'trap',
#  'share',
#  'support',
#  'over',
#  'cdmx',
#  'resident',
#  'through',
#  'jolt',
#  'moment',
#  'before',
#  'hurricane',
#  'it',
#  'maria',
#  'too',
#  'you',
#  'want',
#  'southern',
#  'that',
#  'xico',
#  'á¼ÿ',
#  'á¼ÿd',
#  'ready',
#  'say',
#  'up',
#  'message',
#  'last',
#  'night',
#  'month',
#  'nation',
#  'family',
#  'friend',
#  'event',
#  'no',
#  'report',
#  'twitter',
#  'great',
#  'still',
#  'please',
#  'âš',
#  'heart',
#  'like',
#  'look',
#  'los',
#  'effort',
#  'but',
#  'street',
#  'scene',
#  'force',
#  'volunteer',
#  'save',
#  'click',
#  'link',
#  'map',
#  'á¼žaá¼ÿaecho',
#  'mã',
#  'do',
#  'recent',
#  'picture',
#  'post',
#  'man',
#  'aftermath',
#  'earthquakeâ',
#  'week',
#  'frida',
#  'she',
#  'need',
#  'unknown',
#  'fall',
#  'matter',
#  'two',
#  'volcano',
#  'near',
#  'pm',
#  'citizen',
#  'safe',
#  'travel',
#  'visit',
#  'recovery',
#  'way',
#  'time',
#  'mexican',
#  'call',
#  'star',
#  'aftershock',
#  'assist',
#  'into',
#  'california',
#  'dá½',
#  'run',
#  'morelos',
#  'they',
#  'massive',
#  'may',
#  'get',
#  'body',
#  'postpone',
#  'chiapas',
#  'coast',
#  'know',
#  'begin',
#  'blog',
#  'he',
#  'not',
#  'keep',
#  'why',
#  'forget',
#  'year',
#  'hero',
#  'stop',
#  'puebla',
#  'japan',
#  'alive',
#  'raise',
#  'these',
#  'cityâ',
#  'hope',
#  'national',
#  'sept',
#  'u',
#  'mexicoearthquake',
#  'will',
#  'make',
#  'article',
#  'check',
#  'house',
#  'team',
#  'bury',
#  'prophecy',
#  'thank',
#  'full',
#  'felt',
#  'thanks',
#  'usrc',
#  'humanitarian',
#  'israeli',
#  'de',
#  'now',
#  'right',
#  'worker',
#  'assistance',
#  'concert',
#  'panic',
#  'thousand',
#  'could',
#  'erupts',
#  'detail',
#  'expert',
#  'if',
#  'free',
#  'come',
#  'together',
#  'when',
#  'hayek',
#  'salma',
#  'me',
#  'face',
#  'fá¼',
#  'or',
#  'church',
#  'supply',
#  'first',
#  'taiwan',
#  'girl',
#  'survive',
#  'woman',
#  'prepare',
#  'tell',
#  'pledge',
#  'recall',
#  'don',
#  'la',
#  'story',
#  'old',
#  'cnn',
#  'baptism',
#  'move',
#  'collect',
#  'ravage',
#  'meet',
#  'much',
#  'very',
#  'factory',
#  'join',
#  'century',
#  'most',
#  'mexicoquake',
#  'leave',
#  'bad',
#  'sismomx',
#  'fundraiser',
#  'destroy',
#  'member',
#  'nbc',
#  'morning',
#  'restaurant',
#  'fund',
#  'good',
#  'young',
#  'californian',
#  'gt',
#  'her',
#  'united',
#  'october',
#  'poster',
#  'oaxaca',
#  'third',
#  'name',
#  'diego',
#  'start',
#  'dozen',
#  'already',
#  'shock',
#  'state',
#  'fulfil',
#  'benefit',
#  'give',
#  'proud',
#  'bring',
#  'cost',
#  'corner',
#  'north',
#  'back',
#  'tomorrow',
#  'reuters',
#  'proceeds',
#  'food',
#  'risk',
#  'center',
#  'welcome',
#  'kardashian',
#  'kim']

# %%
lda_2_topics = utils3.train_lda_model(num_topics=2, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(2, lda_2_topics.model)

# %%
lda_3_topics = utils3.train_lda_model(3, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(3, lda_3_topics.model)

# %%
lda_4_topics = utils3.train_lda_model(4, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(4, lda_4_topics.model)

# %%
real_top_words = utils3.get_top_words_lda(2, lda_2_topics.model, num_words=10)

random_topics = [
    random.sample(all_words, 10),
    random.sample(all_words, 10),    
]

print(f"Top words:")
for word_list in real_top_words:
    print(f"    {word_list}")
print(f"Coherence score for the text using calculated topics is: {utils3.compute_coherence_score(real_top_words, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}\n")

print(f"Random words:")
for word_list in random_topics:
    print(f"    {word_list}")
print(f"Coherence score for the text using random topics is: {utils3.compute_coherence_score(random_topics, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}")
# Out:
# Top words:
#     ['in', 'of', 'mexicoearthquake', 'rt', 'for', 'be', 'after', 'and', 'city', 'hit']
#     ['to', 'the', 'in', 'city', 'of', 'rt', 'after', 'victim', 'be', 'help']
# Coherence score for the text using calculated topics is: -2.148
#
# Random words:
#     ['affect', 'continue', 'local', 'risk', 'frida', 'shake', 'this', 'most', 'top', 'raise']
#     ['socialmedia', 'work', 'big', 'trap', 'man', 'least', 'de', 'postpone', 'help', 'felt']
# Coherence score for the text using random topics is: -20.669

# %%
# Set the number of topics
max_number_of_topics = 10
n_topics_range = range(2, max_number_of_topics + 1)

# Dictionary to save trained models
LDA_models = {}
print(f"Training LDA models from 2 to {max_number_of_topics} topics")

# For number of topics ranging from 2 to max_number_of_topics
for i in n_topics_range:
    # Save model
    LDA_models[i] = utils3.train_lda_model(num_topics=i, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary) # Training all models takes around 2 mins
    print(f"Successfully trained LDA model on {i} topics")
# Out:
# Training LDA models from 2 to 10 topics
# Successfully trained LDA model on 2 topics
# Successfully trained LDA model on 3 topics
# Successfully trained LDA model on 4 topics
# Successfully trained LDA model on 5 topics
# Successfully trained LDA model on 6 topics
# Successfully trained LDA model on 7 topics
# Successfully trained LDA model on 8 topics
# Successfully trained LDA model on 9 topics
# Successfully trained LDA model on 10 topics

# %%
utils3.top_words_plot(LDA_models, max_number_of_topics)
# Out:
# interactive(children=(Dropdown(description='# of topics', options=(2, 3, 4, 5, 6, 7, 8, 9, 10), value=2), Outp…

# %%
# save coherence scores in a list
coherence_scores_lda = [LDA_models[i].coherence_score for i in n_topics_range]

# plot coherence score as a function of number of topics
utils3.plot_coherences_lda(n_topics_range, coherence_scores_lda)

# %%
num_topics = 3

# Select the model from the trained models
lda_model_final = LDA_models[num_topics]

# Plot the top ten words for the selected model again
utils3.plot_top_words_lda(num_topics, lda_model_final.model, num_words=20)

# %%
import seaborn as sns
# import termcolor

# %%
def plot_topic_importance(corpus_bow, data, lda_3_topics, num_topics):
    topics_on_messages = lda_3_topics.model.get_document_topics(corpus_bow, minimum_probability=0.0)

    result = []
    start_date = data['date'].min()  # Minimum date from the DataFrame
    end_date = data['date'].max()  # Maximum date from the DataFrame
    n_days = (end_date - start_date).days
    for delta in range(n_days):
        sum_by_topic = [0] * num_topics
        today = start_date + pd.Timedelta(days=delta)
        tomorrow = start_date + pd.Timedelta(days=delta+1)
        index_range = data.loc[(data['date'] >= today) & (data['date'] < tomorrow)].index
        for k in index_range:
            for i in range(num_topics):
                sum_by_topic[i] += topics_on_messages[k][i][1]
        sum_by_topic = np.array(sum_by_topic)
        sum_by_topic = sum_by_topic / np.sum(sum_by_topic)

        result.append(sum_by_topic)
    result = np.array(result)

    result3 = []
    days_per_tick = 1

    for i in range(n_days):
        for topic in range(num_topics):
            rows = result[i, topic]
            result3.append([int(i / days_per_tick), np.sum(rows), topic])

    result3 = np.array(result3)

    plt.figure(figsize=(15, 5))

    style = [f"Topic {int(x) + 1}" for x in result3[:,2]]
    ax = sns.lineplot(x=result3[:,0]*days_per_tick, y=result3[:,1], hue=style, style=style)
    ax.set(xlabel='Days', ylabel='Topic importance')
    ax.tick_params(labelsize=14)
    ax.set_title(f"Topic importance over time", fontsize=22)
    ax.set_xlabel("Days", fontsize=18)
    ax.set_ylabel("Topic importance", fontsize=18)
    ax.legend(fontsize=14)

    plt.show()

# %%
plot_topic_importance(corpus_bow, df, lda_model_final, num_topics)
