# %%
import pandas as pd
import spacy
from tqdm import tqdm
from spacy.matcher import PhraseMatcher

# %%
csv_file = 'preprocessed_0f_turkey.csv'

# %%
df = pd.read_csv(csv_file)

# %%
df
# Out:
#                                                     text  \
# 0      ❗ DEPREM UYARISI / EARTHQUAKE WARNING for Turk...
# 1      ⚠Preliminary info:  ( about 30 km N of  ( 2 mi...
# 2                                              Gaziantep
# 3      ⚠Preliminary info: M7.2  ( about 30 km N of  (...
# 4                                             Kayseride
# ...                                                  ...
# 73964  Ghanaian record producer, Killbeatz has report...
# 73965  @TheTodayShow @cstanaway @belindarussell_ @Jay...
# 73966  Much love to you Turkey 🇹🇷 \n\n#turkey #TURKEY...
# 73967  Christian Atsu confirmed D£ad, See How Top foo...
# 73968  @ChristianAtsu20 \nRest in peace champ\n#Chris...
#
#                             date  retweets  likes  \
# 0      2023-02-06 01:18:56+00:00       3.0    9.0
# 1      2023-02-06 01:19:42+00:00     136.0  307.0
# 2      2023-02-06 01:20:48+00:00       0.0    0.0
# 3      2023-02-06 01:21:33+00:00      75.0  104.0
# 4      2023-02-06 01:22:05+00:00       0.0    0.0
# ...                          ...       ...    ...
# 73964  2023-02-18 21:57:11+00:00       0.0    3.0
# 73965  2023-02-18 21:58:57+00:00       0.0    0.0
# 73966  2023-02-18 22:00:47+00:00       0.0    2.0
# 73967  2023-02-18 22:04:49+00:00       0.0    0.0
# 73968  2023-02-18 22:04:53+00:00       0.0    0.0
#
#                                                      url  \
# 0      https://twitter.com/BrainstormBot/status/16224...
# 1      https://twitter.com/LastQuake/status/162240463...
# 2      https://twitter.com/mgovcee/status/16224049103...
# 3      https://twitter.com/LastQuake/status/162240509...
# 4      https://twitter.com/gs_ossie_1905/status/16224...
# ...                                                  ...
# 73964                                       Degraft Anti
# 73965                               Judith Kelly 💉💉💉💉💛🤎💜
# 73966                               ℂ𝕠𝕣𝕟𝕚𝕤𝕙𝕂𝕠𝕡𝕚𝕥𝕖𝕁𝟜𝕋𝟡𝟟 🔥
# 73967                                           Abavibes
# 73968                        Akyem Kotoku Royals Rush FC
#
#                                           processed_text
# 0       deprem uyarisi earthquake warning for turkey ...
# 1       preliminary info about km of min ago local ti...
# 2                                              gaziantep
# 3       preliminary info about km of min ago local ti...
# 4                                             kayseride
# ...                                                  ...
# 73964  ghanaian record producer killbeatz has reporte...
# 73965                                       love to see
# 73966  much love to you turkey turkey turkey turkey_e...
# 73967  christian atsu confirmed ad see how top footba...
# 73968   rest in peace champ christianatsu ripchristia...
#
# [73969 rows x 6 columns]

# %%
df1 = df.iloc[:-66969]

# %%
def extract_locations(text):
    nlp = spacy.load("en_core_web_sm")
    matcher = PhraseMatcher(nlp.vocab)
    # Add custom location names to the matcher
    location_patterns = []
    for loc in location_patterns:
        matcher.add("LOCATION", None, nlp(loc))

    doc = nlp(text)
    locations = []
    
    # Extract locations using NER
    for ent in doc.ents:
        if ent.label_ == 'GPE' or ent.label_ == 'LOC':
            locations.append(ent.text)

    # Extract additional locations using the custom matcher
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        locations.append(span.text)
    
    return locations

# %%
all_locations1 = []
for text in tqdm(df1['processed_text'], desc="Extracting Locations", total=len(df1)):
    locations = extract_locations(text)
    all_locations1.extend(locations)

# Print or use the list of all locations
print(all_locations1)
# Out:
# Extracting Locations: 100%|██████████████████████████████████████████████████████| 7000/7000 [1:25:17<00:00,  1.37it/s]
# ['turkey', 'oha', 'turkey', 'israel', 'turkey', 'southeast turkey', 'turkey', 'syria', 'syria', 'israel', 'turkey', 'syria', 'lebanon', 'israel', 'palestine', 'egypt', 'earth', 'turkey', 'the middle east', 'syria', 'turkey', 'hama', 'syria', 'california', 'nabaa', 'turkey', 'middle east', 'middle east', 'syria', 'syria', 'russia', 'turkey', 'syria', 'jordan', 'lebanon', 'iraq', 'armenia', 'syria', 'syria', 'israel', 'gaza', 'syria', 'syria', 'turkey', 'istanbul', 'syria', 'syria', 'turkey', 'mideast', 'iran', 'syria', 'iraq', 'turkey', 'lebanon', 'syria', 'israel', 'georgia', 'egypt', 'iraq', 'jordan', 'jordan', 'syria', 'lebanon', 'syria', 'southeast turkey', 'lebanon', 'syria', 'turkey', 'israel', 'lebanon', 'egypt', 'syria', 'iraq', 'jordan', 'georgia', 'syria', 'turkey', 'adana', 'turkey', 'lebanon', 'syria', 'turkey', 'turkey', 'turkey', 'turkey', 'turkey', 'turkey', 'syria', 'syria', 'turkey', 'turkey', 'turkey', 'turkey', 'turkey', 'turkey', 'pakistan', 'turkey', 'turkey', 'osmaniye governor', 'turkey', 'syria', 'syria', 'south eastern turkey', 'syria', 'lebanon', 'iraq', 'northern governor', 'turkey', 'turkey', 'turkey', 'syria', 'syria', 'turkey', 'syria', 'turkey', 'turkey', 'the middle east', 'syria', 'iraq', 'syria', 'syria', 'hatay province', 'syria', 'gaza', 'beirut', 'adana', 'hama', 'turkey', 'turkey', 'syria', 'the east anatolia fault zone', 'syria', 'syria', 'adana', 'lebanon', 'turkey', 'syria', 'syria', 'turkey', 'america', 'tehran', 'iran', 'caracas venezuela', 'manila', 'south east', 'turkey', 'mexico', 'florida', 'syria', 'syria', 'turkey', 'tel aviv', 'syria', 'israel', 'turkey', 'turkey', 'turkey', 'pakistan', 'lebanon', 'syria', 'turkey pazarcık', 'maras province', 'syria', 'syria', 'syria', 'turkey', 'syria', 'lebanon', 'iraq', 'israel', 'turkey', 'israel', 'japan', 'pakistan', 'adana', 'malatya province', 'syria', 'turkey', 'turkey', 'syria', 'lebanon', 'iraq', 'israel', 'don', 'workturkey', 'syria', 'turkey', 'lebanon', 'syria', 'iraq', 'pakistan', 'turkey', 'turkey', 'turkey', 'southeast turkey', 'syria', 'northern governor', 'turkey', 'turkey', 'georgia', 'syria', 'lebanon', 'muzaffarabad', 'kashmir', 'syria', 'syria', 'istanbul', 'syria', 'palestine', 'turkey', 'damascus', 'syria', 'turkey', 'turkey', 'turkey', 'turkey', 'syria', 'pakistan', 'turkey', 'south eastern', 'south eastern turkey', 'syria', 'turkey', 'turkey', 'syria', 'iraq', 'drprem', 'syria', 'syria', 'lebanon', 'syria', 'syria', 'turkey', 'syria', 'syria', 'turkey', 'syria', 'lebanon', 'iraq', 'israel', 'don', 'workturkey', 'syria', 'turkey', 'malatya province', 'syria', 'turkey', 'syria', 'turkey', 'turkey', 'adana turkey', 'syria', 'northern governor', 'turkey', 'syria', 'syria', 'turkey', 'italy', 'gibi', 'turkey', 'syria', 'lebanon', 'jordan', 'syria', 'southern turkey force area', 'brazil', 'turkey', 'syria', 'turkey', 'syria', 'lebanon', 'syria', 'the united states', 'italy', 'syria', 'beirut', 'turkey', 'syria', 'syria', 'lebanon', 'iraq', 'israel', 'hama', 'syria', 'syria', 'italy', 'turkey', 'turkey', 'syria', 'pakistan', 'lebanon', 'syria', 'turkey', 'syria', 'syria', 'turkey', 'turkey', 'syria', 'lebanon', 'syria', 'malatya province', 'southeast turkey', 'syria', 'malatya province', 'adana', 'syria', 'lebanon', 'turkey', 'turkey', 'turkey', 'turkey', 'south', 'netherlands', 'lebanon', 'syria', 'hama', 'southeast asia', 'hama', 'hatay province', 'turkey', 'syria', 'turkey', 'syria', 'italy', 'don', 'workturkey', 'syria', 'italy', 'turkey', 'south eastern turkey', 'syria', 'us', 'turkey', 'syria', 'syria', 'syria', 'jordan', 'lebanon', 'turkey', 'turkey', 'malatya province', 'turkey', 'syria', 'malatya turkey', 'syria', 'turkey', 'turkey', 'gaziantepmalatyaşanlıurfakahramanmaraşhatayadana', 'turkey', 'south east', 'syria', 'turkey', 'latakia', 'hama', 'turkey', 'adana', 'syria', 'turkish province', 'syria', 'turkey', 'syria', 'turkey', 'syria', 'syria', 'turkey', 'syria', 'lebanon', 'iraq', 'turkey', 'turkey', 'intenaly',  ...

# %%
locations_df1 = pd.DataFrame(all_locations1, columns=['Location'])

# %%
locations_df1
# Out:
#      Location
# 0      turkey
# 1         oha
# 2      turkey
# 3      israel
# 4      turkey
# ...       ...
# 2619    syria
# 2620   turkey
# 2621    syria
# 2622   turkey
# 2623    syria
#
# [2624 rows x 1 columns]

# %%
locations_df1.to_csv('extracted_locations_turkey.csv', index=False)

# %%
from geopy.geocoders import Nominatim

# %%
def get_coordinates(location):
    geolocator = Nominatim(user_agent="location_finder")
    try:
        location_info = geolocator.geocode(location)
        if location_info:
            return location_info.latitude, location_info.longitude
        else:
            return None, None
    except:
        return None, None

# %%
locations_data = []

# %%
unique_locations = set(all_locations1)
for location in tqdm(unique_locations, desc="Geocoding Locations"):
    frequency = all_locations1.count(location)
    latitude, longitude = get_coordinates(location)
    if latitude is not None and longitude is not None:
        locations_data.append({'Location': location, 'Frequency': frequency, 'Latitude': latitude, 'Longitude': longitude})
# Out:
# Geocoding Locations: 100%|███████████████████████████████████████████████████████████| 174/174 [02:36<00:00,  1.11it/s]

# %%
locations_coordinate1 = pd.DataFrame(locations_data)

# %%
locations_coordinate1
# Out:
#             Location  Frequency   Latitude   Longitude
# 0            baghdad          1  33.306170   44.387221
# 1    the middle east          5  35.869605  -84.121049
# 2        middle east          7  39.301416  -76.588848
# 3         al arabiya          1  17.015257   54.093151
# 4         california          4  36.701463 -118.755997
# ..               ...        ...        ...         ...
# 142            japan          5  36.574844  139.239418
# 143             bhai          1  32.057482   76.275716
# 144           rojava          1  24.168196  -13.892143
# 145           canada          4  61.066692 -107.991707
# 146           mexico          1  19.432630  -99.133178
#
# [147 rows x 4 columns]

# %%
locations_coordinate1.to_csv('coordinate_turkey.csv', index=False)
