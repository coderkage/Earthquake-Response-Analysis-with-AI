# %%
import pandas as pd
import spacy
from tqdm import tqdm
from spacy.matcher import PhraseMatcher

# %%
csv_file = 'preprocessed_0f_iraq_iran.csv'

# %%
df1 = pd.read_csv(csv_file)

# %%
df1
# Out:
#                                                   text        date  \
# 0    RT @PressTV: UPDATE: Death toll from Iran’s qu...  13_11_2017
# 1    RT @CAFOD: We pray for all those affected by t...  13_11_2017
# 2    RT @ReutersWorld: JUST IN: Death toll reaches ...  13_11_2017
# 3    RT @LaylaAlhussein: A magnitude 7.2 earthquake...  13_11_2017
# 4    RT @LaylaAlhussein: A magnitude 7.2 earthquake...  13_11_2017
# ..                                                 ...         ...
# 592  Damage proxy maps of 5 cities near the epicent...  18_11_2017
# 593  #Iran Daily: US Treasury Blocks Donations for ...  18_11_2017
# 594  #Kurdish children's situation after the #earth...  18_11_2017
# 595  #IRAN'S #EARTHQUAKE EXPOSES #POLITICAL RIFTS A...  18_11_2017
# 596  Victims of last week's earthquake gather outdo...  18_11_2017
#
#                                    category  \
# 0                    injured_or_dead_people
# 1                          not_humanitarian
# 2                    injured_or_dead_people
# 3                other_relevant_information
# 4                other_relevant_information
# ..                                      ...
# 592       infrastructure_and_utility_damage
# 593  rescue_volunteering_or_donation_effort
# 594                    affected_individuals
# 595              other_relevant_information
# 596                    affected_individuals
#
#                                         processed_text
# 0    rt update death toll from iran quake rises to ...
# 1    rt we pray for all those affected by the earth...
# 2    rt just in death toll reaches in iran earthqua...
# 3    rt magnitude earthquake struck northern iraq i...
# 4    rt magnitude earthquake struck northern iraq i...
# ..                                                 ...
# 592  damage proxy maps of cities near the epicenter...
# 593   iran daily us treasury blocks donations for e...
# 594   kurdish children situation after the earthqua...
# 595   iran earthquake exposes political rifts and i...
# 596  victims of last week earthquake gather outdoor...
#
# [597 rows x 4 columns]

# %%
def extract_locations(text):
    nlp = spacy.load("en_core_web_sm")
    matcher = PhraseMatcher(nlp.vocab)
    # Add custom location names to the matcher
    location_patterns = []
    for loc in location_patterns:
        matcher.add("LOCATION", None, nlp(loc))

    doc = nlp(text)
    locations = []
    
    # Extract locations using NER
    for ent in doc.ents:
        if ent.label_ == 'GPE' or ent.label_ == 'LOC':
            locations.append(ent.text)

    # Extract additional locations using the custom matcher
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        locations.append(span.text)
    
    return locations

# %%
all_locations1 = []
for text in tqdm(df1['processed_text'], desc="Extracting Locations", total=len(df1)):
    locations = extract_locations(text)
    all_locations1.extend(locations)

# Print or use the list of all locations
print(all_locations1)
# Out:
# Extracting Locations: 100%|██████████████████████████████████████████████████████████| 597/597 [05:24<00:00,  1.84it/s]
# ['iran', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'turkey', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'uae', 'iraq', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'najaf', 'iraq', 'iran', 'baghdad', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'pakistan', 'iran', 'iraq', 'kuwait', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'oott', 'iraq', 'halabja', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'bhuj', 'haiti', 'iraq', 'iraq', 'iraq', 'kurdistan', 'kurdistan', 'kurdistan', 'kurdistan', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'the middle east', 'dubai', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iraq', 'iran', 'azerbaijan', 'iran', 'tehran', 'iran', 'tehran', 'iran', 'tehran', 'iran', 'tehran', 'iran', 'turkey', 'iraq', 'iran', 'russia', 'iran', 'iraq', 'iran', 'iran', 'kuwait', 'iraq', 'iran', 'iran', 'iraq', 'kurdistan', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iran', 'kermanshah province', 'iran', 'kermanshah province', 'iran', 'kermanshah province', 'iran', 'iraq', 'iran', 'iraq', 'algeria', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iran', 'iran', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iran', 'kermanshah province', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'middle east', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'kuwait', 'iraq', 'costa rica', 'iraq', 'iran', 'dubai', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iraq', 'iran', 'iran', 'persia', 'iran', 'kermanshah province', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'halabja', 'iran', 'iran', 'kurdistan', 'iran', 'kurdistan', 'iran', 'iran', 'iraq', 'kurdistan', 'kurdistan', 'emsr', 'iraq', 'iraq', 'iran', 'halabja', 'kurdistan', 'halabja', 'kurdistan', 'iran', 'iran', 'iran', 'iran', 'iraq', 'pakistan', 'kuwait', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'pakistan', 'iran', 'iraq', 'iraq', 'iran', 'turkey', 'kurdistan', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'kuwait', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iraq', 'iraq', 'iran', 'iraq', 'algeria', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iraq', 'israel', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iran', 'iran', 'kuwait', 'kuwait', 'kuwait', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iran', 'italy', 'iran', 'iran', 'iran', 'iraq', 'iraq', 'iran', 'japan', 'iran', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iran', 'iran', 'iran', 'iran', 'toronto', 'iraq', 'iran', 'smart city', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'israel', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iraq', 'iran', 'iran', 'iraq', 'iran', 'iraq', 'kuwait', 'iraq', 'ir ...

# %%
locations_df1 = pd.DataFrame(all_locations1, columns=['Location'])

# %%
locations_df1
# Out:
#     Location
# 0       iran
# 1       iraq
# 2       iran
# 3       iran
# 4       iraq
# ..       ...
# 827     iran
# 828     iran
# 829     iran
# 830     iran
# 831     iran
#
# [832 rows x 1 columns]

# %%
locations_df1.to_csv('extracted_locations_iraq_iran.csv', index=False)

# %%
from geopy.geocoders import Nominatim

# %%
def get_coordinates(location):
    geolocator = Nominatim(user_agent="location_finder")
    try:
        location_info = geolocator.geocode(location)
        if location_info:
            return location_info.latitude, location_info.longitude
        else:
            return None, None
    except:
        return None, None

# %%
get_coordinates('raichur')
# Out:
# (16.083333, 77.166667)

# %%
locations_data = []

# %%
unique_locations = set(all_locations1)
for location in tqdm(unique_locations, desc="Geocoding Locations"):
    frequency = all_locations1.count(location)
    latitude, longitude = get_coordinates(location)
    if latitude is not None and longitude is not None:
        locations_data.append({'Location': location, 'Frequency': frequency, 'Latitude': latitude, 'Longitude': longitude})
# Out:
# Geocoding Locations: 100%|█████████████████████████████████████████████████████████████| 41/41 [00:44<00:00,  1.10s/it]

# %%
locations_coordinate1 = pd.DataFrame(locations_data)

# %%
locations_coordinate1
# Out:
#                Location  Frequency   Latitude   Longitude
# 0            smart city          1  47.079588   15.410957
# 1                turkey          3  38.959759   34.924965
# 2            washington          1  38.895037  -77.036543
# 3   kermanshah province          6  34.486732   46.808727
# 4                 japan          1  36.574844  139.239418
# 5               baghdad          1  33.306170   44.387221
# 6               halabja          4  35.179206   45.987368
# 7                 najaf          1  32.001023   44.329993
# 8                israel         11  30.812425   34.859476
# 9       the middle east          1  35.869605  -84.121049
# 10                haiti          1  19.139995  -72.357097
# 11          middle east          2  39.301416  -76.588848
# 12               persia          1  41.579489  -95.568940
# 13              toronto          1  43.653482  -79.383935
# 14              algeria          2  28.000027    2.999983
# 15           costa rica          2  10.273563  -84.073910
# 16               buhari          1  20.970426   73.307916
# 17                italy          2  42.638426   12.674297
# 18                 emsr          1  50.787642    0.285880
# 19                 iraq        281  33.095579   44.174977
# 20               russia          1  64.686314   97.745306
# 21              morocco          1  28.334772  -10.371338
# 22        karzin county          1  28.328420   52.981743
# 23                kabul          1  34.526011   69.177684
# 24               kamran          1  16.497153   44.805204
# 25            iran city          1  -4.014145  -79.214691
# 26                 iran        449  32.647531   54.564352
# 27                   us          2  39.783730 -100.445882
# 28               kuwait         11  29.379653   47.973417
# 29           azerbaijan          2  40.393629   47.787251
# 30               mexico          1  19.432630  -99.133178
# 31                china          1  35.000074  104.999927
# 32               tehran          5  35.689252   51.389600
# 33             pakistan          4  30.330840   71.247499
# 34        al miqdadiyah          1  33.975762   44.970305
# 35                 bhuj          1  23.247245   69.668339
# 36                  uae          2  24.000249   53.999483
# 37                dubai          3  25.074282   55.188539
# 38            kurdistan         15  35.672803   47.012438

# %%
locations_coordinate1.to_csv('coordinate_iraq_iran.csv', index=False)
