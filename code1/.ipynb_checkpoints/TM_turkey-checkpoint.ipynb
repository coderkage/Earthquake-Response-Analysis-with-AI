# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import utils1
import utils2
import utils3

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv("preprocessed_0f_turkey.csv", low_memory=False)

# %%
df['processed_text'] = df['processed_text'].astype(str)

# %%
df.head()
# Out:
#                                                 text  \
# 0  ❗ DEPREM UYARISI / EARTHQUAKE WARNING for Turk...
# 1  ⚠Preliminary info:  ( about 30 km N of  ( 2 mi...
# 2                                          Gaziantep
# 3  ⚠Preliminary info: M7.2  ( about 30 km N of  (...
# 4                                         Kayseride
#
#                         date  retweets  likes  \
# 0  2023-02-06 01:18:56+00:00       3.0    9.0
# 1  2023-02-06 01:19:42+00:00     136.0  307.0
# 2  2023-02-06 01:20:48+00:00       0.0    0.0
# 3  2023-02-06 01:21:33+00:00      75.0  104.0
# 4  2023-02-06 01:22:05+00:00       0.0    0.0
#
#                                                  url  \
# 0  https://twitter.com/BrainstormBot/status/16224...
# 1  https://twitter.com/LastQuake/status/162240463...
# 2  https://twitter.com/mgovcee/status/16224049103...
# 3  https://twitter.com/LastQuake/status/162240509...
# 4  https://twitter.com/gs_ossie_1905/status/16224...
#
#                                       processed_text
# 0   deprem uyarisi earthquake warning for turkey ...
# 1   preliminary info about km of min ago local ti...
# 2                                          gaziantep
# 3   preliminary info about km of min ago local ti...
# 4                                         kayseride

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.isna().sum()
# Out:
# text              0
# date              0
# retweets          1
# likes             1
# url               2
# processed_text    0
# dtype: int64

# %%
all_text = ' '.join(df['text'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import gensim
import nltk
nltk.download('averaged_perceptron_tagger')

pd.options.mode.chained_assignment = None
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# %%
def process_text(text):
    # Step 1: Tokenize and get POS tags
    tokens = nltk.pos_tag(word_tokenize(text))
    # print(colored("Step 1: Tokenize\n", "blue"), "{}\n".format([w[0] for w in tokens]))
    
    # Step 2: Lemmatize each word 
    tokens = [lemmatizer.lemmatize(w[0], utils2.pos_tag_convert(w[1])) for w in tokens if w[0].lower() not in stop_words]
    # print(colored("Step 2: Lemmatize\n", "blue"), "{}\n".format(tokens))
    
    return tokens

def process_random_message(df):
    # Apply process_text function to each entry in the processed_text column
    df['tokens'] = df['processed_text'].apply(process_text)
    return df

# Process all entries in the processed_text column and add the tokens column in df
df = process_random_message(df)
df
# Out:
#                                                     text  \
# 0      ❗ DEPREM UYARISI / EARTHQUAKE WARNING for Turk...
# 1      ⚠Preliminary info:  ( about 30 km N of  ( 2 mi...
# 2                                              Gaziantep
# 3      ⚠Preliminary info: M7.2  ( about 30 km N of  (...
# 4                                             Kayseride
# ...                                                  ...
# 73964  Ghanaian record producer, Killbeatz has report...
# 73965  @TheTodayShow @cstanaway @belindarussell_ @Jay...
# 73966  Much love to you Turkey 🇹🇷 \n\n#turkey #TURKEY...
# 73967  Christian Atsu confirmed D£ad, See How Top foo...
# 73968  @ChristianAtsu20 \nRest in peace champ\n#Chris...
#
#                            date  retweets  likes  \
# 0     2023-02-06 01:18:56+00:00       3.0    9.0
# 1     2023-02-06 01:19:42+00:00     136.0  307.0
# 2     2023-02-06 01:20:48+00:00       0.0    0.0
# 3     2023-02-06 01:21:33+00:00      75.0  104.0
# 4     2023-02-06 01:22:05+00:00       0.0    0.0
# ...                         ...       ...    ...
# 73964 2023-02-18 21:57:11+00:00       0.0    3.0
# 73965 2023-02-18 21:58:57+00:00       0.0    0.0
# 73966 2023-02-18 22:00:47+00:00       0.0    2.0
# 73967 2023-02-18 22:04:49+00:00       0.0    0.0
# 73968 2023-02-18 22:04:53+00:00       0.0    0.0
#
#                                                      url  \
# 0      https://twitter.com/BrainstormBot/status/16224...
# 1      https://twitter.com/LastQuake/status/162240463...
# 2      https://twitter.com/mgovcee/status/16224049103...
# 3      https://twitter.com/LastQuake/status/162240509...
# 4      https://twitter.com/gs_ossie_1905/status/16224...
# ...                                                  ...
# 73964                                       Degraft Anti
# 73965                               Judith Kelly 💉💉💉💉💛🤎💜
# 73966                               ℂ𝕠𝕣𝕟𝕚𝕤𝕙𝕂𝕠𝕡𝕚𝕥𝕖𝕁𝟜𝕋𝟡𝟟 🔥
# 73967                                           Abavibes
# 73968                        Akyem Kotoku Royals Rush FC
#
#                                           processed_text  \
# 0       deprem uyarisi earthquake warning for turkey ...
# 1       preliminary info about km of min ago local ti...
# 2                                              gaziantep
# 3       preliminary info about km of min ago local ti...
# 4                                             kayseride
# ...                                                  ...
# 73964  ghanaian record producer killbeatz has reporte...
# 73965                                       love to see
# 73966  much love to you turkey turkey turkey turkey_e...
# 73967  christian atsu confirmed ad see how top footba...
# 73968   rest in peace champ christianatsu ripchristia...
#
#                                                   tokens
# 0      [deprem, uyarisi, earthquake, warn, turkey, re...
# 1      [preliminary, info, km, min, ago, local, time,...
# 2                                            [gaziantep]
# 3      [preliminary, info, km, min, ago, local, time,...
# 4                                            [kayseride]
# ...                                                  ...
# 73964  [ghanaian, record, producer, killbeatz, report...
# 73965                                        [love, see]
# 73966  [much, love, turkey, turkey, turkey, turkey_ea...
# 73967  [christian, atsu, confirm, ad, see, top, footb...
# 73968  [rest, peace, champ, christianatsu, ripchristi...
#
# [73969 rows x 7 columns]

# %%
# Count number of words and save as a column
df["num_words"] = df.processed_text.apply(lambda x: len(x.split(" ")))

# Count number of tokens and save as a column
df["num_tokens"] = df.tokens.apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                                 text  \
# 0  ❗ DEPREM UYARISI / EARTHQUAKE WARNING for Turk...
# 1  ⚠Preliminary info:  ( about 30 km N of  ( 2 mi...
# 2                                          Gaziantep
# 3  ⚠Preliminary info: M7.2  ( about 30 km N of  (...
# 4                                         Kayseride
#
#                        date  retweets  likes  \
# 0 2023-02-06 01:18:56+00:00       3.0    9.0
# 1 2023-02-06 01:19:42+00:00     136.0  307.0
# 2 2023-02-06 01:20:48+00:00       0.0    0.0
# 3 2023-02-06 01:21:33+00:00      75.0  104.0
# 4 2023-02-06 01:22:05+00:00       0.0    0.0
#
#                                                  url  \
# 0  https://twitter.com/BrainstormBot/status/16224...
# 1  https://twitter.com/LastQuake/status/162240463...
# 2  https://twitter.com/mgovcee/status/16224049103...
# 3  https://twitter.com/LastQuake/status/162240509...
# 4  https://twitter.com/gs_ossie_1905/status/16224...
#
#                                       processed_text  \
# 0   deprem uyarisi earthquake warning for turkey ...
# 1   preliminary info about km of min ago local ti...
# 2                                          gaziantep
# 3   preliminary info about km of min ago local ti...
# 4                                         kayseride
#
#                                               tokens  num_words  num_tokens
# 0  [deprem, uyarisi, earthquake, warn, for, turke...         27          25
# 1  [preliminary, info, about, km, of, min, ago, l...         18          16
# 2                                        [gaziantep]          2           1
# 3  [preliminary, info, about, km, of, min, ago, l...         14          12
# 4                                        [kayseride]          2           1

# %%
# All of the messages in the dataset
corpus = df.tokens

# Create the Dictionary
corpus_dictionary = gensim.corpora.Dictionary(corpus)

print(colored("Before filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")

# Filter for words that occur more than 5 times overall
corpus_dictionary.filter_extremes(no_below=5)

# Create bag of words out of the full corpus
corpus_bow = [corpus_dictionary.doc2bow(doc) for doc in corpus]

print(colored("After filter: ", "blue"), f"Dictionary contains a total of {len(corpus_dictionary)} unique words")
# Out:
# Before filter:  Dictionary contains a total of 28805 unique words
# After filter:  Dictionary contains a total of 7358 unique words

# %%
# Convert bag of words back to text format
corpus_text = [[corpus_dictionary[word_id] for word_id, freq in doc] for doc in corpus_bow]

# Flatten the list of lists
corpus_text_flat = [word for sublist in corpus_text for word in sublist]

# Join the words into a single string
corpus_text_combined = ' '.join(corpus_text_flat)

# Generate word cloud
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate(corpus_text_combined)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
import nltk
nltk.download('averaged_perceptron_tagger')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from termcolor import colored
import random
import gensim
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\deepp\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
corpus
# Out:
# 0        [deprem, uyarisi, earthquake, warn, for, turke...
# 1        [preliminary, info, about, km, of, min, ago, l...
# 2                                              [gaziantep]
# 3        [preliminary, info, about, km, of, min, ago, l...
# 4                                              [kayseride]
#                                ...
# 73964    [ghanaian, record, producer, killbeatz, have, ...
# 73965                                      [love, to, see]
# 73966    [much, love, to, you, turkey, turkey, turkey, ...
# 73967    [christian, atsu, confirm, ad, see, how, top, ...
# 73968    [rest, in, peace, champ, christianatsu, ripchr...
# Name: tokens, Length: 73969, dtype: object

# %%
all_words = list(corpus_dictionary.values())

print(f"Dictionary contains a total of {len(all_words)} unique words")
# Out:
# Dictionary contains a total of 7358 unique words

# %%
all_words
# Out:
# ['alert',
#  'api',
#  'because',
#  'deprem',
#  'earthquake',
#  'end',
#  'for',
#  'free',
#  'it',
#  'my',
#  'near',
#  'note',
#  'profile',
#  'remove',
#  'report',
#  'see',
#  'soon',
#  'turkey',
#  'twitter',
#  'warn',
#  'will',
#  'about',
#  'ago',
#  'at',
#  'available',
#  'info',
#  'km',
#  'local',
#  'magnitude',
#  'min',
#  'not',
#  'of',
#  'positiveemoji',
#  'preliminary',
#  'time',
#  'update',
#  'yet',
#  'gaziantep',
#  'depth',
#  'gfz',
#  'potsdam',
#  'source',
#  'utc',
#  'by',
#  'confirm',
#  'data',
#  'follow',
#  'nw',
#  'seismic',
#  'the',
#  'thread',
#  'mardin',
#  'lastquake',
#  'ne',
#  'te',
#  'and',
#  'central',
#  'country',
#  'felt',
#  'in',
#  'major',
#  'more',
#  'others',
#  'shake',
#  'antep',
#  'affected',
#  'all',
#  'back',
#  'just',
#  'prayer',
#  'strike',
#  'those',
#  'to',
#  'get',
#  'huge',
#  'quake',
#  'abt',
#  'here',
#  'intensity',
#  'likely',
#  'many',
#  'read',
#  'regional',
#  'sadly',
#  'suffer',
#  'tectonics',
#  'aftershock',
#  'already',
#  'as',
#  'away',
#  'be',
#  'describe',
#  'effect',
#  'epicenter',
#  'far',
#  'from',
#  'good',
#  'large',
#  'locate',
#  'most',
#  'occur',
#  'originally',
#  'so',
#  'that',
#  'they',
#  'this',
#  'well',
#  'a',
#  'information',
#  'israel',
#  'your',
#  'son',
#  'story',
#  'yardim',
#  'advice',
#  'any',
#  'anyone',
#  'area',
#  'authority',
#  'close',
#  'especially',
#  'ground',
#  'high',
#  'if',
#  'listen',
#  'move',
#  'on',
#  'radio',
#  'recommend',
#  'sea',
#  'shallow',
#  'shore',
#  'stay',
#  'strong',
#  'television',
#  'turn',
#  'very',
#  'you',
#  'afad',
#  'allah',
#  'hit',
#  'korusun',
#  'powerful',
#  'record',
#  'southern',
#  'usgs',
#  'big',
#  'east',
#  'turkiye',
#  'emsc',
#  'accord',
#  'everyone',
#  'go',
#  'our',
#  'an',
#  'hope',
#  'massive',
#  'okay',
#  'wow',
#  'collapse',
#  'first',
#  'video',
#  'after',
#  'damage',
#  'neighboring',
#  'rock',
#  'affect',
#  'also',
#  'half',
#  'levant',
#  'region',
#  'around',
#  'bed',
#  'dawn',
#  'emerge',
#  'important',
#  'people',
#  'recording',
#  'show',
#  'sleep',
#  'their',
#  'break',
#  'coverage',
#  'live',
#  'news',
#  'have',
#  'almost',
#  'asleep',
#  'bulletin',
#  'catch',
#  'certainly',
#  'early',
#  'global',
#  'hashtag',
#  'home',
#  'mobilization',
#  'need',
#  'night',
#  'or',
#  'photo',
#  'populate',
#  'rescue',
#  'southeast',
#  'team',
#  'again',
#  'appear',
#  'building',
#  'completely',
#  'flatten',
#  'residential',
#  'what',
#  'when',
#  'revision',
#  'footage',
#  'share',
#  'carry',
#  'fine',
#  'god',
#  'house',
#  'kid',
#  'now',
#  'out',
#  'still',
#  'thank',
#  'them',
#  'tremble',
#  'until',
#  'up',
#  'wake',
#  'we',
#  'casualty',
#  'estimate',
#  'negetiveemoji',
#  'anticipate',
#  'death',
#  'give',
#  'simply',
#  'timing',
#  'toll',
#  'never',
#  'camp',
#  'se',
#  'but',
#  'call',
#  'check',
#  'communication',
#  'coordination',
#  'could',
#  'difference',
#  'effective',
#  'emergency',
#  'help',
#  'make',
#  'please',
#  'tag',
#  'yourself',
#  'monday',
#  'morning',
#  'no',
#  'one',
#  'praying',
#  'safety',
#  'apartment',
#  'multiple',
#  'aid',
#  'humanitarian',
#  'idlib',
#  'physician',
#  'syria',
#  'there',
#  'worker',
#  'mediterranean',
#  'expect',
#  'fatality',
#  'injure',
#  'border',
#  'life',
#  'possible',
#  'property',
#  'two',
#  'development',
#  'late',
#  'safe',
#  'send',
#  'thought',
#  'hatay',
#  'across',
#  'clearly',
#  'dark',
#  'effort',
#  'pancake',
#  'structure',
#  'themselves',
#  'underway',
#  'upon',
#  'felaket',
#  'cyprus',
#  'egypt',
#  'least',
#  'lebanon',
#  'other',
#  'palestine',
#  'possibly',
#  'severe',
#  'earth',
#  'develop',
#  'ht',
#  'via',
#  'below',
#  'diyarbakir',
#  'reportedly',
#  'add',
#  'devastation',
#  'horrific',
#  'scale',
#  'heartbroken',
#  'middle',
#  'pray',
#  'recovery',
#  'shook',
#  'swift',
#  'eartquake',
#  'kahramanmaraş',
#  'province',
#  'urgently',
#  'aftermath',
#  'malatya',
#  'city',
#  'destroy',
#  'happen',
#  'several',
#  'side',
#  'disaster',
#  'kahramanmaras',
#  'management',
#  'compassion',
#  'omg',
#  'some',
#  'these',
#  'tweet',
#  'complex',
#  'devastate',
#  'bot',
#  'elsewhere',
#  'event',
#  'initial',
#  'much',
#  'too',
#  'enormous',
#  'explosion',
#  'alot',
#  'demolished',
#  'even',
#  'exactly',
#  'hear',
#  'northern',
#  'realize',
#  'scream',
#  'something',
#  'sure',
#  'weird',
#  'eq',
#  'lot',
#  'condition',
#  'midst',
#  'thousand',
#  'winter',
#  'with',
#  'do',
#  'feel',
#  'mww',
#  'register',
#  'tell',
#  'u',
#  'description',
#  'extreme',
#  'fear',
#  'say',
#  'situation',
#  'three',
#  'trap',
#  'apparently',
#  'best',
#  'combination',
#  'est',
#  'fault',
#  'quite',
#  'slip',
#  'which',
#  'wish',
#  'hour',
#  'last',
#  'within',
#  'heart',
#  'impact',
#  'strength',
#  'continue',
#  'can',
#  'come',
#  'debris',
#  'down',
#  'literally',
#  'mean',
#  'she',
#  'snow',
#  'sob',
#  'street',
#  'woman',
#  'cause',
#  'over',
#  'scene',
#  'serious',
#  'significant',
#  'usually',
#  'fall',
#  'jolt',
#  'medium',
#  'social',
#  'widely',
#  'collapsed',
#  'desperation',
#  'distress',
#  'he',
#  'rubble',
#  'stream',
#  'youtuber',
#  'day',
#  'detail',
#  'eastern',
#  'next',
#  'probability',
#  'radius',
#  '𝗠',
#  '𝘐𝘴𝘴𝘶𝘦𝘥',
#  '𝘰𝘯',
#  'actually',
#  'degrees',
#  'experience',
#  'light',
#  'road',
#  'concerned',
#  'than',
#  'alive',
#  'always',
#  'ameen',
#  'horrible',
#  'may',
#  'protect',
#  'turkish',
#  'friend',
#  'mention',
#  'name',
#  'respond',
#  'ruin',
#  'sitesi',
#  'trapped',
#  'under',
#  'recieved',
#  'hama',
#  'how',
#  'know',
#  'amp',
#  'analysis',
#  'california',
#  'challenge',
#  'collective',
#  'community',
#  'evaluate',
#  'face',
#  'join',
#  'responder',
#  'support',
#  'cnn',
#  'turk',
#  'youtube',
#  'destruction',
#  'due',
#  'tonight',
#  'before',
#  'jesus',
#  'matthew',
#  'off',
#  'consider',
#  'few',
#  'force',
#  'ongoing',
#  'surely',
#  'tough',
#  'tremor',
#  'full',
#  'lunar',
#  'moon',
#  'nation',
#  'period',
#  'trigger',
#  'february',
#  'sw',
#  'absolutely',
#  'ya',
#  'bad',
#  'unfortunately',
#  'block',
#  'old',
#  'provide',
#  'reachable',
#  'transportation',
#  'village',
#  'who',
#  'loss',
#  'surrounding',
#  'demolish',
#  'district',
#  'inside',
#  'storey',
#  'family',
#  'geçmiş',
#  'hard',
#  'herkese',
#  'olsun',
#  'translate',
#  'abc',
#  'epicentre',
#  'population',
#  'shock',
#  'town',
#  'guy',
#  'faultline',
#  'freezing',
#  'outside',
#  'size',
#  'successive',
#  'dead',
#  'hundred',
#  'iskenderun',
#  'numerous',
#  'look',
#  'south',
#  'assad',
#  'bare',
#  'dig',
#  'find',
#  'hand',
#  'helmet',
#  'photographer',
#  'previously',
#  'russia',
#  'survivor',
#  'through',
#  'try',
#  'white',
#  'assist',
#  'benefit',
#  'charity',
#  'heed',
#  'regard',
#  'return',
#  'take',
#  'urgency',
#  'watch',
#  'app',
#  'don',
#  'list',
#  'mobile',
#  'science',
#  'use',
#  'web',
#  'work',
#  'capital',
#  'centre',
#  'kilometer',
#  'mile',
#  'provincial',
#  'asks',
#  'man',
#  'save',
#  'stick',
#  'prays',
#  'red',
#  'release',
#  'armenia',
#  'include',
#  'iraq',
#  'jordan',
#  'mainly',
#  'north',
#  'türkiye',
#  'request',
#  'streaming',
#  'brother',
#  'keep',
#  'sadden',
#  'citizen',
#  'attack',
#  'extensive',
#  'syrian',
#  'image',
#  'rt',
#  'yayi',
#  'panic',
#  'entire',
#  'cold',
#  'wall',
#  'hotel',
#  'earthqauke',
#  'sanliurfa',
#  'retweet',
#  'dear',
#  'gaza',
#  'into',
#  'rise',
#  'aug',
#  'dr',
#  'prof',
#  'since',
#  'appeal',
#  'international',
#  'urgent',
#  'cant',
#  'imagine',
#  'above',
#  'long',
#  'true',
#  'way',
#  'scary',
#  'poor',
#  'relatively',
#  'southeastern',
#  'super',
#  'independent',
#  'range',
#  'mi',
#  'address',
#  'alarm',
#  'degree',
#  'dispatch',
#  'gather',
#  'group',
#  'issue',
#  'level',
#  'relief',
#  'today',
#  'adana',
#  'center',
#  'painful',
#  'sad',
#  'terrible',
#  'predict',
#  'year',
#  'chaos',
#  'during',
#  'yayin',
#  'yayinn',
#  'faulting',
#  'institute',
#  'map',
#  'moment',
#  'motion',
#  'seismological',
#  'tensor',
#  'proof',
#  'governor',
#  'osmaniye',
#  'knock',
#  'assistance',
#  'official',
#  'mayor',
#  'ask',
#  'world',
#  'ah',
#  'bee',
#  'among',
#  'leave',
#  'declare',
#  'four',
#  'interior',
#  'donate',
#  'lose',
#  'love',
#  'injured',
#  'miss',
#  'voice',
#  'aware',
#  'body',
#  'case',
#  'child',
#  'hashtags',
#  'related',
#  'search',
#  'start',
#  'term',
#  'catastrophic',
#  'hate',
#  'kind',
#  'politics',
#  'president',
#  'tragedy',
#  'istanbul',
#  'nd',
#  'nurdağı',
#  'st',
#  'strongly',
#  'narlı',
#  'fire',
#  'heavy',
#  'iran',
#  'frank',
#  'hoogerbeets',
#  'able',
#  'crisis',
#  'reach',
#  'reason',
#  'service',
#  'stricken',
#  'approximately',
#  'arab',
#  'georgia',
#  'republic',
#  'shaking',
#  'wrap',
#  'ℹevent',
#  'account',
#  'fund',
#  'hack',
#  'steal',
#  'wallet',
#  'ensue',
#  'operation',
#  'should',
#  'google',
#  'play',
#  'store',
#  'mb',
#  'moderate',
#  'only',
#  'second',
#  'solace',
#  'such',
#  'bir',
#  'right',
#  'violent',
#  'where',
#  'yeni',
#  'le',
#  'action',
#  'immediate',
#  'northwest',
#  'belowfollow',
#  'helpuse',
#  'police',
#  'spot',
#  'gmt',
#  'inc',
#  'kilometre',
#  'pazarcik',
#  'care',
#  'continuously',
#  'health',
#  'remember',
#  'sakarya',
#  'tent',
#  'potential',
#  'seismologist',
#  'chance',
#  'hey',
#  'satellite',
#  'shortage',
#  'starlink',
#  'think',
#  'connection',
#  'cut',
#  'electricity',
#  'internet',
#  'learnt',
#  'relative',
#  'weather',
#  'wound',
#  'everywhere',
#  'accurate',
#  'claim',
#  'expert',
#  'floor',
#  'safer',
#  'top',
#  'sister',
#  'statement',
#  'statistic',
#  'base',
#  'member',
#  'military',
#  'along',
#  'desperately',
#  'dozen',
#  'his',
#  'frighten',
#  'cctv',
#  'new',
#  'populated',
#  'access',
#  'charge',
#  'gsm',
#  'quickly',
#  'compilation',
#  'surround',
#  'automatic',
#  'crowdsourced',
#  'detection',
#  'sec',
#  'seismically',
#  'verify',
#  'aleppo',
#  'ready',
#  'state',
#  'struck',
#  'amin',
#  'fourth',
#  'adıyaman',
#  'agency',
#  'gölbaşı',
#  'pipeline',
#  'unconfirmed',
#  've',
#  'hr',
#  'american',
#  'prepare',
#  'couple',
#  'prediction',
#  'pack',
#  'race',
#  'smoke',
#  'campaign',
#  'crypto',
#  'heartbreaking',
#  'launch',
#  'lead',
#  'let',
#  'together',
#  'nizip',
#  'every',
#  'glad',
#  'greek',
#  'natural',
#  'nearly',
#  'really',
#  'control',
#  'gas',
#  'response',
#  'saw',
#  'seem',
#  'while',
#  'amaze',
#  'communicate',
#  'conduct',
#  'finding',
#  'research',
#  'wonder',
#  'victim',
#  'experienced',
#  'kill',
#  'me',
#  'army',
#  'film',
#  'airport',
#  'visual',
#  'concern',
#  'dam',
#  'naci',
#  'amik',
#  'burst',
#  'field',
#  'medias',
#  'netizens',
#  'plain',
#  'publish',
#  'spread',
#  'additional',
#  'build',
#  'result',
#  'ese',
#  'gut',
#  'like',
#  'won',
#  'wrench',
#  'empty',
#  'terrify',
#  'document',
#  'amount',
#  'car',
#  'sent',
#  'spend',
#  'blood',
#  'crescent',
#  'kızılay',
#  'relieve',
#  'spacex',
#  'confirmedturkey',
#  'mass',
#  'hopefully',
#  'line',
#  'nuclear',
#  'plant',
#  'power',
#  'russian',
#  'definitely',
#  'extremely',
#  'require',
#  'sadness',
#  'thanks',
#  'word',
#  'raise',
#  'cancel',
#  'flight',
#  'exact',
#  'location',
#  'difficult',
#  'pakistan',
#  'int',
#  'minister',
#  'soylu',
#  'message',
#  'reading',
#  'enter',
#  'same',
#  'five',
#  'yilmaz',
#  'kahraman',
#  'maraş',
#  're',
#  'richter',
#  'beloved',
#  'ceyhan',
#  'girl',
#  'sorry',
#  'injury',
#  'number',
#  'anything',
#  'doesn',
#  'hell',
#  'page',
#  'trend',
#  'trending',
#  'trust',
#  'want',
#  'why',
#  'explodes',
#  'afp',
#  'infrastructure',
#  'oil',
#  'afrin',
#  'critical',
#  'aci',
#  'hop',
#  'civilian',
#  'ability',
#  'humanity',
#  'sake',
#  'whole',
#  'jenderes',
#  'mercy',
#  'kizilay',
#  'reliable',
#  'maybe',
#  'onal',
#  'great',
#  'solidarity',
#  'stand',
#  'person',
#  'rehem',
#  'activate',
#  'network',
#  'outage',
#  'short',
#  'telephone',
#  'atleast',
#  'anatolian',
#  'increase',
#  'necessary',
#  'urge',
#  'arm',
#  'besides',
#  'both',
#  'isi',
#  'laugh',
#  'breaking',
#  'ataturk',
#  'samandag',
#  'forum',
#  'million',
#  'planning',
#  'relate',
#  'serve',
#  'immediately',
#  'another',
#  'atm',
#  'hurt',
#  'isn',
#  'urfa',
#  'diyarbakır',
#  'tv',
#  'truly',
#  'bro',
#  ...]

# %%
lda_2_topics = utils3.train_lda_model(num_topics=2, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(2, lda_2_topics.model)

# %%
lda_3_topics = utils3.train_lda_model(3, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(3, lda_3_topics.model)

# %%
lda_4_topics = utils3.train_lda_model(4, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary)
utils3.plot_top_words_lda(4, lda_4_topics.model)

# %%
real_top_words = utils3.get_top_words_lda(2, lda_2_topics.model, num_words=10)

random_topics = [
    random.sample(all_words, 10),
    random.sample(all_words, 10),    
]

print(f"Top words:")
for word_list in real_top_words:
    print(f"    {word_list}")
print(f"Coherence score for the text using calculated topics is: {utils3.compute_coherence_score(real_top_words, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}\n")

print(f"Random words:")
for word_list in random_topics:
    print(f"    {word_list}")
print(f"Coherence score for the text using random topics is: {utils3.compute_coherence_score(random_topics, dictionary=corpus_dictionary, texts=corpus.values, corpus=corpus_bow):.3f}")
# Out:
# Top words:
#     ['the', 'in', 'of', 'be', 'to', 'turkey', 'earthquake', 'and', 'from', 'rescue']
#     ['the', 'turkeyearthquake', 'be', 'to', 'turkey', 'and', 'for', 'in', 'earthquake', 'you']
# Coherence score for the text using calculated topics is: -1.358
#
# Random words:
#     ['madonna', 'theft', 'wound', 'frightening', 'niluferland', 'weigh', 'evidence', 'vids', 'jump', 'cope']
#     ['reny', 'widely', 'absence', 'tür', 'updated', 'secure', 'potential', 'uzbekistan', 'increase', 'counter']
# Coherence score for the text using random topics is: -18.654

# %%
# Set the number of topics
max_number_of_topics = 10
n_topics_range = range(2, max_number_of_topics + 1)

# Dictionary to save trained models
LDA_models = {}
print(f"Training LDA models from 2 to {max_number_of_topics} topics")

# For number of topics ranging from 2 to max_number_of_topics
for i in n_topics_range:
    # Save model
    LDA_models[i] = utils3.train_lda_model(num_topics=i, corpus_bow=corpus_bow, corpus=corpus, corpus_dictionary=corpus_dictionary) # Training all models takes around 2 mins
    print(f"Successfully trained LDA model on {i} topics")
# Out:
# Training LDA models from 2 to 10 topics
# Successfully trained LDA model on 2 topics
# Successfully trained LDA model on 3 topics
# Successfully trained LDA model on 4 topics
# Successfully trained LDA model on 5 topics
# Successfully trained LDA model on 6 topics
# Successfully trained LDA model on 7 topics
# Successfully trained LDA model on 8 topics
# Successfully trained LDA model on 9 topics
# Successfully trained LDA model on 10 topics

# %%
utils3.top_words_plot(LDA_models, max_number_of_topics)
# Out:
# interactive(children=(Dropdown(description='# of topics', options=(2, 3, 4, 5, 6, 7, 8, 9, 10), value=2), Outp…

# %%
# save coherence scores in a list
coherence_scores_lda = [LDA_models[i].coherence_score for i in n_topics_range]

# plot coherence score as a function of number of topics
utils3.plot_coherences_lda(n_topics_range, coherence_scores_lda)

# %%
num_topics = 3

# Select the model from the trained models
lda_model_final = LDA_models[num_topics]

# Plot the top ten words for the selected model again
utils3.plot_top_words_lda(num_topics, lda_model_final.model, num_words=20)

# %%
import seaborn as sns
# import termcolor

# %%
def plot_topic_importance(corpus_bow, data, lda_3_topics, num_topics):
    topics_on_messages = lda_3_topics.model.get_document_topics(corpus_bow, minimum_probability=0.0)

    result = []
    start_date = data['date'].min()  # Minimum date from the DataFrame
    end_date = data['date'].max()  # Maximum date from the DataFrame
    n_days = (end_date - start_date).days
    for delta in range(n_days):
        sum_by_topic = [0] * num_topics
        today = start_date + pd.Timedelta(days=delta)
        tomorrow = start_date + pd.Timedelta(days=delta+1)
        index_range = data.loc[(data['date'] >= today) & (data['date'] < tomorrow)].index
        for k in index_range:
            for i in range(num_topics):
                sum_by_topic[i] += topics_on_messages[k][i][1]
        sum_by_topic = np.array(sum_by_topic)
        sum_by_topic = sum_by_topic / np.sum(sum_by_topic)

        result.append(sum_by_topic)
    result = np.array(result)

    result3 = []
    days_per_tick = 4

    for i in range(n_days):
        for topic in range(num_topics):
            rows = result[i, topic]
            result3.append([int(i / days_per_tick), np.sum(rows), topic])

    result3 = np.array(result3)

    plt.figure(figsize=(15, 5))

    style = [f"Topic {int(x) + 1}" for x in result3[:,2]]
    ax = sns.lineplot(x=result3[:,0]*days_per_tick, y=result3[:,1], hue=style, style=style)
    ax.set(xlabel='Days', ylabel='Topic importance')
    ax.tick_params(labelsize=14)
    ax.set_title(f"Topic importance over time", fontsize=22)
    ax.set_xlabel("Days", fontsize=18)
    ax.set_ylabel("Topic importance", fontsize=18)
    ax.legend(fontsize=14)

    plt.show()

# %%
plot_topic_importance(corpus_bow, df, lda_model_final, num_topics)
